# %%
import os
import cv2
import dlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tabulate import tabulate
import pandas as pd
import shutil
np.set_printoptions(threshold=np.inf)

# %%
# Import module yang digunakan
from preprocessing.scarpping_component import extract_component_by_images
from feature_extraction.poc import POC
from feature_extraction.vektor import Vektor
from feature_extraction.quadran import Quadran

# load model dan shape predictor untuk deteksi wajah
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")

components_setup = {
    'mulut': {
        'object_name': 'mouth',
        'object_rectangle': {"x_right": 54, "x_left": 48, "y_highest": 52, "y_lowest": 57},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 5},
        'object_dimension': {'width': 140, 'height': 40}
    },
    'mata_kiri': {
        'object_name': 'eye_left',
        'object_rectangle': {"x_right": 39, "x_left": 36, "y_highest": 38, "y_lowest": 41},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'mata_kanan': {
        'object_name': 'eye_right',
        'object_rectangle': {"x_right": 45, "x_left": 42, "y_highest": 43, "y_lowest": 47},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'alis_kiri': {
        'object_name': 'eyebrow_left',
        'object_rectangle': {"x_right": 21, "x_left": 17, "y_highest": 18, "y_lowest": 21},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
    'alis_kanan': {
        'object_name': 'eyebrow_right',
        'object_rectangle': {"x_right": 26, "x_left": 22, "y_highest": 25, "y_lowest": 22},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
    'hidung_kanan': {
        'object_name': 'nose_right',
        'object_rectangle': {"x_right": 31, "x_left": 40, "y_highest": 40, "y_lowest": 48},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": -25},
        'object_dimension': {'width': 70, 'height': 40}
    }
}

# Inisialisasi variabel untuk path url dan blok size
blockSize = 5
pathDirectory = {
    "base_path_dataset": "dataset",
    "base_dataset_input" : "dataset/casme_custom/",
    "result_dataset" : "output", 
    "component_image" : "component_to_images", 
    "video_frame" :"video_to_images",
    "dir_output_image" : "output_image_{blockSize}x{blockSize}",
}

# Print Image + arrow
printImage = False # True or False

# Inisialisasi variabel untuk menyimpan data dari masing-masing komponen
frames_data_quadran = []
frames_data_all_component = []
frames_data_quadran_column = ['sumX', 'sumY', 'Tetha', 'Magnitude', 'JumlahQuadran']
quadran_dimensions = ['Q1', 'Q2', 'Q3', 'Q4']
frames_data = {component_name: [] for component_name in components_setup}
total_blocks_components = {component_name: 0 for component_name in components_setup}
data_blocks_first_image = {component_name: None for component_name in components_setup}
index = {component_name: 0 for component_name in components_setup}

# Hitung total blok dari masing-masing komponen lalu disetup kedalam total_blocks_components
for component_name, component_info in components_setup.items():
    total_blocks_components[component_name] = int((component_info['object_dimension']['width'] / blockSize) * (component_info['object_dimension']['height'] / blockSize))

# Loop melalui setiap kunci dan nilai di pathDirectory dan hapus direktorinya
for key, value in pathDirectory.items():
    # Jika tidak mengandung base, hapus direktori sesuai dengan nilai yang ada
    if not "base" in key:
        shutil.rmtree(value, ignore_errors=True)

# Looping folder label didalam base_dataset_input
for foldername_label in os.listdir(pathDirectory['base_dataset_input']):
    foldername_label_join_basepath = os.path.join(pathDirectory['base_dataset_input'], foldername_label)
    # Jika folder nya tidak ada skip looping ini
    if not os.path.isdir(foldername_label_join_basepath):
        continue
    
    # Looping folder label didalam foldername_label_join_basepath 
    for foldername in os.listdir(foldername_label_join_basepath):
        foldername_join_basepath = os.path.join(foldername_label_join_basepath, foldername)
        # Jika folder nya tidak ada skip looping ini
        if not os.path.isdir(foldername_join_basepath):
            continue

        # Reset variabel setiap kali mulai looping folder baru
        data_blocks_first_image = {component_name: None for component_name in components_setup}
        index = {component_name: 0 for component_name in components_setup}

        # looping semua file yang ada didalam
        for filename in os.listdir(foldername_join_basepath):
            if filename.endswith(".jpg") or filename.endswith(".png"): 

                # Read path sesuai dengan foldername_join_basepath dijoin path dengan filename
                image = cv2.imread(os.path.join(foldername_join_basepath, filename))
                # Resize image ke ukuran yang diinginkan
                image = cv2.resize(image, (600, 500))
                # Cpmvert image ke grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Deteksi shape muka didalam grayscale image
                rects = detector(gray)

                if not index[component_name] == 0:
                    # Buat variabel frames_data_all_component untuk menampung data current frame
                    frame_data_all_component = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}
                    # Buat variabel frame_data_quadran untuk menampung data current frame
                    frame_data_quadran = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                # Memproses rects untuk setiap bentuk wajah yang terdeteksi
                for rect in rects:
                    # Ambil bentuk wajah dalam bentuk shape sesuai dengan model predictor
                    shape = predictor(gray, rect)
                    # Memproses setiap komponen wajah
                    for component_name, component_info in components_setup.items():
                        print(f"\n{foldername}-{filename.split('.')[0]}-{component_info['object_name']}:")
                        # Inisialisasi variabel sum_data_by_quadran untuk menyimpan data hasil quadran
                        sum_data_by_quadran = {}
                        # Buat variabel frame_data untuk menampung data current frame
                        frame_data = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                        # Looping untuk setiap atribut dalam frames_data_quadran_column
                        for column in frames_data_quadran_column:
                            # Inisialisasi sub-dictionary untuk setiap atribut dalam frames_data_quadran_column yang defaultnya 0
                            sum_data_by_quadran[column] = {quadrant: 0 for quadrant in quadran_dimensions}

                        # Ambil data blok image dari return fungsi extract_component_by_images
                        data_blocks_image_current = extract_component_by_images(
                            image=image,
                            shape=shape,
                            frameName=filename.split(".")[0],
                            objectName=component_info['object_name'],
                            objectRectangle=component_info['object_rectangle'],
                            pixelShifting=component_info['pixel_shifting'],
                            objectDimension=component_info['object_dimension']
                        )
                        
                        # Ambil frame pertama dari perulangan lalu simpan di variabel dan skip (lanjutkan ke frame berikut)
                        if data_blocks_first_image[component_name] is None:
                            # --- Setup bagian 4qmv Dataset ---
                            # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                            # for quadrant in quadran_dimensions:
                            #     for feature in frames_data_quadran_column:
                            #         # Buat nama kolom dengan menggunakan template yang diberikan
                            #         column_name = f"{component_name}_{feature}_{quadrant}"
                            #         # Set value sum_data_by_quadran[feature][quadrant] ke frame_data_quadran sesuai column_name nya
                            #         frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadrant]

                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Inisialisasi data untuk setiap blok
                            # for i in range(total_blocks_components[component_name]):
                                # Tambahkan data ke frame_data sesuai dengan indexnya
                                # frame_data[f'X{i+1}'] = 0
                                # frame_data[f'Y{i+1}'] = 0
                                # frame_data[f'Tetha{i+1}'] = 0
                                # frame_data[f'Magnitude{i+1}'] = 0
                                # # Tambahkan data ke frame_data_all_component sesuai dengan indexnya
                                # frame_data_all_component[f'{component_name}-X{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Y{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Tetha{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = 0

                            # Append data frame ke list frames_data sesuai dengan component_name
                            frames_data[component_name].append(frame_data)
                            # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                            frame_data['Folder Path'] = foldername
                            # Tambahkan kolom "Label" dengan nilai label saat ini
                            frame_data['Label'] = foldername_label
                            # Set value data_blocks_first_image[component_name] ke data_blocks_image_current
                            data_blocks_first_image[component_name] = data_blocks_image_current
                            # Skip looping nya ke looping selanjutnya
                            continue

                        # Tampilkan data block image current ke matplotlib
                        plt.imshow(np.uint8(data_blocks_image_current), cmap="gray")

                        # Inisiasi class POC
                        initPOC = POC(data_blocks_first_image[component_name], data_blocks_image_current, blockSize) 
                        # Pemanggilan fungsi pocCalc() untuk menghitung nilai POC disetiap gambar
                        valPOC = initPOC.getPOC() 

                        # Pemanggilan class dan method untuk menampilkan quiver / gambar panah
                        initQuiv = Vektor(valPOC, blockSize)
                        quivData = initQuiv.getVektor() 

                        if printImage:
                            plt.imshow(np.uint8(data_blocks_image_current), cmap="gray")
                            plt.quiver(quivData[:, 0], quivData[:, 1], quivData[:, 2], quivData[:, 3], scale=1, scale_units='xy', angles='xy', color="g")  

                            # Hapus Directory jika sudah ada sesuai directory yang diinginkan
                            dir_imaget = pathDirectory['dir_output_image'].format(blockSize=blockSize)

                            # if os.path.exists(f"output_image_5x5/{component_name}/{foldername_label}"):
                            #     shutil.rmtree(f"output_image_5x5/{component_name}/{foldername_label}", ignore_errors=True)
                                 
                            
                            # Gunakan os untuk membuat folder baru dan hapus jika sudah ada
                            os.makedirs(f"{dir_imaget}/{component_name}/{foldername_label}", exist_ok=True)

                            # Simpan gambar ke dalam folder output_image_5x5/{component_name}/{foldername_label}/nama frame ke-i.png
                            plt.savefig(f"{dir_imaget}/{component_name}/{foldername_label}/{filename.split('.')[0]}.png")

                            # Hapus plot
                            plt.clf()

                        # plt.quiver(quivData[:, 0], quivData[:, 1], quivData[:, 2], quivData[:, 3], scale=1, scale_units='xy', angles='xy', color="r")    

                        # # num = 0
                        # for rect_def in valPOC[2]:
                        #     x, y, width, height = rect_def
                            
                        #     rects = patches.Rectangle((x,y), width,height, edgecolor='r', facecolor='none') 
                        #     plt.gca().add_patch(rects)
                            
                        #     # plt.text(x,y,f'({num})', color="blue") 
                        #     # num += 1

                        # print(tabulate(quadran, headers=['Blok Ke', 'X', 'Y', 'Tetha', 'Magnitude', 'Quadran Ke']))
                        # plt.axis('on') 
                        # plt.show() 

                        # Pemanggilan class untuk mengeluarkan nilai karakteristik vektor
                        # blok ke, x,y,tetha, magnitude, dan quadran ke
                        initQuadran = Quadran(quivData) 
                        quadran = initQuadran.getQuadran()


                        # Update frame_data dengan data quadran
                        for i, quad in enumerate(quadran):
                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Set data kedalam frame_data sesuai column nya
                            frame_data[f'X{i+1}'] = quad[1]
                            frame_data[f'Y{i+1}'] = quad[2]
                            frame_data[f'Tetha{i+1}'] = quad[3]
                            frame_data[f'Magnitude{i+1}'] = quad[4]

                            # Set data kedalam frame_data_all_component sesuai columnnya
                            frame_data_all_component[f'{component_name}-X{i+1}'] = quad[1]
                            frame_data_all_component[f'{component_name}-Y{i+1}'] = quad[2]
                            frame_data_all_component[f'{component_name}-Tetha{i+1}'] = quad[3]
                            frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = quad[4]

                            # --- Setup bagian 4qmv Dataset ---
                            # Cek apakah quad[5] ada didalam array quadran_dimensions
                            if quad[5] in quadran_dimensions:
                                # Tambahkan nilai quad[1] ke sumX pada kuadran yang sesuai
                                sum_data_by_quadran['sumX'][quad[5]] += quad[1]
                                # Tambahkan nilai quad[2] ke sumY pada kuadran yang sesuai
                                sum_data_by_quadran['sumY'][quad[5]] += quad[2]
                                # Tambahkan nilai quad[3] ke Tetha pada kuadran yang sesuai
                                sum_data_by_quadran['Tetha'][quad[5]] += quad[3]
                                # Tambahkan nilai quad[4] ke Magnitude pada kuadran yang sesuai
                                sum_data_by_quadran['Magnitude'][quad[5]] += quad[4]
                                # Tambahkan jumlah quadran sesuai dengan quad[5] ke JumlahQuadran pada kuadran yang sesuai
                                sum_data_by_quadran['JumlahQuadran'][quad[5]] += 1
                        
                        # --- Setup bagian Nilai Fitur Dataset ---
                        # Append data frame ke list
                        frames_data[component_name].append(frame_data)
                        # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                        frame_data['Folder Path'] = foldername
                        # Tambahkan kolom "Label" dengan nilai label saat ini
                        frame_data['Label'] = foldername_label

                        # --- Setup bagian 4qmv Dataset ---
                        # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                        for quadran in quadran_dimensions:
                            for feature in frames_data_quadran_column:
                                # Buat nama kolom dengan menggunakan template yang diberikan
                                column_name = f"{component_name}_{feature}_{quadran}"
                                # Set value sum_data_by_quadran[feature][quadran] ke frame_data_quadran sesuai column_name nya
                                frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadran]

                # --- Setup bagian 4qmv Dataset ---
                if not index[component_name] == 0:
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_quadran.append(frame_data_quadran)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_quadran['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_quadran['Label'] = foldername_label

                if not index[component_name] == 0:
                    # --- Setup bagian frames data all component Dataset ---
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_all_component.append(frame_data_all_component)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_all_component['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_all_component['Label'] = foldername_label

                # Update index per component_name
                index[component_name] += 1

# Membuat direktori jika belum ada untuk outputnya
output_csv_dir = os.path.join(pathDirectory['result_dataset'], 'csv')
output_excel_dir = os.path.join(pathDirectory['result_dataset'], 'excel')
os.makedirs(output_csv_dir, exist_ok=True)
os.makedirs(output_excel_dir, exist_ok=True)

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (Nilai fitur)
for component_name in components_setup:
    csv_file_path = os.path.join(pathDirectory['result_dataset'], 'csv', f'{component_name}.csv')
    xlsx_file_path = os.path.join(pathDirectory['result_dataset'], 'excel', f'{component_name}.xlsx')
    if os.path.exists(csv_file_path):
        os.remove(csv_file_path)
    if os.path.exists(xlsx_file_path):
        os.remove(xlsx_file_path)

# Export dataframe ke dalam file csv dan xlsx sesuai dengan masing-masing component untuk fitur ekstrasi biasa
for component_name, data_frame in frames_data.items():
    # Initialisasi dataframe dengan pandas
    df = pd.DataFrame(data_frame)
    
    # Simpan ke file CSV
    nama_file_csv = f'{output_csv_dir}/{component_name}.csv'
    df.to_csv(nama_file_csv, index=False, float_format=None)
    
    # Simpan ke file Excel
    nama_file_xlsx = f'{output_excel_dir}/{component_name}.xlsx'
    df.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_quadran untuk fitur ekstraksi 4qmv
# Initialisasi dataframe dengan pandas
# df_4qmv = pd.DataFrame(frames_data_quadran)

# # Inisialisasi nama file untuk dataset 4qmv
# nama_file_csv = f'{output_csv_dir}/4qmv-all-component.csv'
# nama_file_xlsx = f'{output_excel_dir}/4qmv-all-component.xlsx'

# # Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
# if os.path.exists(nama_file_csv):
#     os.remove(nama_file_csv)
# if os.path.exists(nama_file_xlsx):
#     os.remove(nama_file_xlsx)

# # Simpan ke file CSV
# df_4qmv.to_csv(nama_file_csv, index=False, float_format=None)

# # Simpan ke file Excel
# df_4qmv.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_all_component untuk fitur ekstraksi nilai fiturnya
# Initialisasi dataframe dengan pandas
df_fitur_all = pd.DataFrame(frames_data_all_component)

# Inisialisasi nama file untuk dataset 4qmv
nama_file_csv = f'{output_csv_dir}/nilai-fitur-all-component.csv'
nama_file_xlsx = f'{output_excel_dir}/nilai-fitur-all-component.xlsx'

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
if os.path.exists(nama_file_csv):
    os.remove(nama_file_csv)
if os.path.exists(nama_file_xlsx):
    os.remove(nama_file_xlsx)

# Simpan ke file CSV
df_fitur_all.to_csv(nama_file_csv, index=False, float_format=None)

# Simpan ke file Excel
df_fitur_all.to_excel(nama_file_xlsx, index=False, float_format=None)
# Out:
# 03_EP19_08-img101-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img101-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img101-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img101-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img101-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img101-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img102-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img102-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img102-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img102-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img102-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img102-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img103-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img103-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img103-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img103-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img103-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img103-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img104-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img104-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img104-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img104-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img104-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img104-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img105-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img105-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img105-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img105-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img105-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img105-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img106-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img106-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img106-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img106-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img106-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img106-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img107-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img107-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img107-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img107-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img107-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img107-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img108-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img108-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img108-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img108-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img108-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img108-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img109-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img109-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img109-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img109-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img109-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img109-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img110-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img110-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img110-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img110-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img110-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img110-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img111-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img111-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img111-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img111-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img111-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img111-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img112-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img112-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img112-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img112-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img112-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img112-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img113-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img113-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img113-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img113-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img113-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img113-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img114-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img114-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img114-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img114-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img114-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img114-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img115-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img115-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img115-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img115-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img115-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img115-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img116-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img116-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img116-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img116-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img116-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img116-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img117-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img117-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img117-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img117-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img117-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img117-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img118-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img118-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img118-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img118-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img118-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img118-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img119-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img119-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img119-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img119-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img119-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img119-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img120-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img120-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img120-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img120-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img120-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img120-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img121-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img121-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img121-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img121-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img121-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img121-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img122-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img122-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img122-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img122-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img122-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img122-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img123-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img123-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img123-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img123-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img123-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img123-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img124-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img124-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img124-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img124-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img124-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img124-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img125-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img125-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img125-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img125-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img125-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img125-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img126-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img126-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img126-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img126-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img126-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img126-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img127-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img127-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img127-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img127-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img127-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img127-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img128-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img128-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img128-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img128-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img128-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img128-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img129-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img129-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img129-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img129-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img129-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img129-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img130-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img130-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img130-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img130-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img130-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img130-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img131-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img131-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img131-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img131-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img131-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img131-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img132-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img132-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img132-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img132-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img132-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img132-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img133-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img133-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img133-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img133-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img133-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img133-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img134-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img134-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img134-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img134-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img134-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img134-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img135-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img135-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img135-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img135-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img135-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img135-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img136-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img136-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img136-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img136-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img136-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img136-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img137-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img137-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img137-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img137-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img137-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img137-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img138-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img138-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img138-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img138-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img138-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img138-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img139-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img139-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img139-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img139-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img139-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img139-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img140-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img140-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img140-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img140-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img140-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img140-nose_right:
# width_object: 70, height_object: 40
#
# 03_EP19_08-img141-mouth:
# width_object: 140, height_object: 40
#
# 03_EP19_08-img141-eye_left:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img141-eye_right:
# width_object: 90, height_object: 55
#
# 03_EP19_08-img141-eyebrow_left:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img141-eyebrow_right:
# width_object: 110, height_object: 40
#
# 03_EP19_08-img141-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img100-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img100-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img100-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img100-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img100-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img100-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img101-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img101-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img101-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img101-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img101-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img101-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img102-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img102-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img102-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img102-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img102-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img102-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img103-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img103-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img103-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img103-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img103-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img103-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img104-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img104-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img104-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img104-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img104-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img104-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img105-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img105-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img105-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img105-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img105-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img105-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img106-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img106-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img106-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img106-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img106-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img106-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img107-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img107-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img107-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img107-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img107-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img107-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img108-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img108-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img108-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img108-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img108-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img108-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img109-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img109-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img109-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img109-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img109-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img109-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img110-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img110-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img110-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img110-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img110-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img110-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img111-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img111-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img111-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img111-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img111-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img111-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img112-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img112-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img112-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img112-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img112-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img112-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img113-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img113-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img113-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img113-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img113-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img113-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img114-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img114-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img114-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img114-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img114-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img114-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img115-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img115-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img115-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img115-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img115-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img115-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img116-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img116-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img116-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img116-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img116-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img116-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img117-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img117-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img117-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img117-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img117-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img117-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img118-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img118-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img118-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img118-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img118-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img118-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img119-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img119-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img119-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img119-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img119-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img119-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img120-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img120-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img120-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img120-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img120-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img120-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img121-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img121-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img121-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img121-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img121-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img121-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img86-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img86-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img86-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img86-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img86-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img86-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img87-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img87-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img87-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img87-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img87-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img87-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img88-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img88-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img88-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img88-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img88-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img88-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img89-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img89-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img89-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img89-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img89-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img89-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img90-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img90-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img90-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img90-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img90-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img90-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img91-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img91-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img91-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img91-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img91-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img91-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img92-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img92-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img92-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img92-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img92-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img92-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img93-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img93-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img93-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img93-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img93-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img93-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img94-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img94-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img94-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img94-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img94-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img94-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img95-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img95-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img95-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img95-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img95-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img95-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img96-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img96-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img96-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img96-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img96-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img96-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img97-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img97-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img97-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img97-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img97-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img97-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img98-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img98-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img98-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img98-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img98-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img98-nose_right:
# width_object: 70, height_object: 40
#
# 17_EP13_04-img99-mouth:
# width_object: 140, height_object: 40
#
# 17_EP13_04-img99-eye_left:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img99-eye_right:
# width_object: 90, height_object: 55
#
# 17_EP13_04-img99-eyebrow_left:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img99-eyebrow_right:
# width_object: 110, height_object: 40
#
# 17_EP13_04-img99-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img100-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img100-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img100-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img100-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img100-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img100-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img101-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img101-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img101-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img101-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img101-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img101-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img61-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img61-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img61-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img61-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img61-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img61-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img62-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img62-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img62-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img62-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img62-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img62-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img63-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img63-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img63-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img63-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img63-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img63-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img64-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img64-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img64-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img64-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img64-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img64-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img65-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img65-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img65-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img65-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img65-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img65-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img66-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img66-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img66-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img66-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img66-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img66-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img67-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img67-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img67-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img67-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img67-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img67-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img68-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img68-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img68-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img68-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img68-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img68-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img69-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img69-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img69-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img69-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img69-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img69-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img70-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img70-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img70-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img70-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img70-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img70-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img71-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img71-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img71-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img71-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img71-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img71-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img72-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img72-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img72-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img72-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img72-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img72-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img73-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img73-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img73-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img73-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img73-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img73-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img74-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img74-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img74-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img74-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img74-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img74-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img75-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img75-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img75-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img75-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img75-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img75-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img76-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img76-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img76-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img76-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img76-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img76-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img77-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img77-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img77-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img77-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img77-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img77-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img78-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img78-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img78-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img78-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img78-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img78-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img79-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img79-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img79-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img79-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img79-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img79-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img80-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img80-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img80-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img80-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img80-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img80-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img81-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img81-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img81-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img81-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img81-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img81-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img82-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img82-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img82-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img82-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img82-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img82-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img83-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img83-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img83-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img83-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img83-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img83-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img84-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img84-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img84-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img84-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img84-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img84-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img85-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img85-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img85-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img85-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img85-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img85-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img86-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img86-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img86-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img86-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img86-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img86-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img87-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img87-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img87-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img87-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img87-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img87-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img88-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img88-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img88-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img88-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img88-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img88-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img89-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img89-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img89-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img89-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img89-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img89-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img90-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img90-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img90-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img90-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img90-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img90-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img91-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img91-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img91-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img91-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img91-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img91-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img92-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img92-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img92-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img92-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img92-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img92-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img93-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img93-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img93-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img93-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img93-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img93-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img94-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img94-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img94-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img94-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img94-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img94-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img95-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img95-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img95-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img95-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img95-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img95-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img96-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img96-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img96-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img96-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img96-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img96-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img97-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img97-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img97-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img97-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img97-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img97-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img98-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img98-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img98-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img98-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img98-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img98-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP16_02-img99-mouth:
# width_object: 140, height_object: 40
#
# 19_EP16_02-img99-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img99-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP16_02-img99-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img99-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP16_02-img99-nose_right:
# width_object: 70, height_object: 40
#
# 20_EP06_03-img31-mouth:
# width_object: 140, height_object: 40
#
# 20_EP06_03-img31-eye_left:
# width_object: 90, height_object: 55
#
# 20_EP06_03-img31-eye_right:
# width_object: 90, height_object: 55
#
# 20_EP06_03-img31-eyebrow_left:
# width_object: 110, height_object: 40
#
# 20_EP06_03-img31-eyebrow_right:
# width_object: 110, height_object: 40
#
# 20_EP06_03-img31-nose_right:
# width_object: 70, height_object: 40
#
# 20_EP06_03-img32-mouth:
# width_object: 140, height_object: 40
#
# 20_EP06_03-img32-eye_left:
# width_object: 90, height_object: 55
#
# 20_EP06_03-img32-eye_right:
# width_object: 90, height_object: 55
#
# 20_EP06_03-img32-eyebrow_left:
# width_object: 110, height_object: 40
#
# 20_EP06_03-img32-eyebrow_right:
# width_object: 110, height_object: 40
#
# 20_EP06_03-img32-nose_right:
# width_object: 70, height_object: 40
#
# 20_EP06_03-img33-mouth:
# width_object: 140, height_object: 40
#
# 20_EP06_03-img33-eye_left:
# ...
# width_object: 110, height_object: 40
#
# 19_EP19_02-img147-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP19_02-img148-mouth:
# width_object: 140, height_object: 40
#
# 19_EP19_02-img148-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img148-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img148-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img148-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img148-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP19_02-img149-mouth:
# width_object: 140, height_object: 40
#
# 19_EP19_02-img149-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img149-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img149-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img149-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img149-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP19_02-img150-mouth:
# width_object: 140, height_object: 40
#
# 19_EP19_02-img150-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img150-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img150-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img150-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img150-nose_right:
# width_object: 70, height_object: 40
#
# 19_EP19_02-img151-mouth:
# width_object: 140, height_object: 40
#
# 19_EP19_02-img151-eye_left:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img151-eye_right:
# width_object: 90, height_object: 55
#
# 19_EP19_02-img151-eyebrow_left:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img151-eyebrow_right:
# width_object: 110, height_object: 40
#
# 19_EP19_02-img151-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img53-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img53-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img53-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img53-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img53-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img53-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img54-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img54-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img54-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img54-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img54-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img54-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img55-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img55-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img55-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img55-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img55-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img55-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img56-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img56-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img56-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img56-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img56-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img56-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img57-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img57-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img57-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img57-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img57-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img57-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img58-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img58-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img58-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img58-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img58-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img58-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img59-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img59-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img59-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img59-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img59-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img59-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img60-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img60-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img60-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img60-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img60-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img60-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img61-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img61-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img61-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img61-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img61-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img61-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img62-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img62-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img62-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img62-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img62-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img62-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img63-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img63-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img63-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img63-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img63-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img63-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img64-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img64-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img64-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img64-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img64-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img64-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img65-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img65-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img65-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img65-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img65-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img65-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img66-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img66-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img66-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img66-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img66-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img66-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img67-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img67-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img67-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img67-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img67-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img67-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img68-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img68-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img68-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img68-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img68-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img68-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img69-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img69-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img69-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img69-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img69-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img69-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img70-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img70-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img70-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img70-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img70-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img70-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img71-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img71-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img71-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img71-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img71-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img71-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img72-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img72-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img72-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img72-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img72-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img72-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img73-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img73-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img73-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img73-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img73-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img73-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img74-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img74-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img74-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img74-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img74-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img74-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img75-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img75-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img75-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img75-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img75-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img75-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img76-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img76-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img76-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img76-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img76-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img76-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img77-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img77-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img77-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img77-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img77-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img77-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img78-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img78-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img78-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img78-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img78-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img78-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img79-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img79-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img79-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img79-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img79-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img79-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img80-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img80-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img80-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img80-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img80-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img80-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img81-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img81-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img81-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img81-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img81-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img81-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img82-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img82-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img82-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img82-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img82-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img82-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img83-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img83-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img83-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img83-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img83-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img83-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img84-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img84-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img84-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img84-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img84-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img84-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img85-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img85-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img85-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img85-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img85-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img85-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img86-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img86-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img86-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img86-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img86-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img86-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img87-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img87-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img87-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img87-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img87-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img87-nose_right:
# width_object: 70, height_object: 40
#
# 24_EP18_03-img88-mouth:
# width_object: 140, height_object: 40
#
# 24_EP18_03-img88-eye_left:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img88-eye_right:
# width_object: 90, height_object: 55
#
# 24_EP18_03-img88-eyebrow_left:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img88-eyebrow_right:
# width_object: 110, height_object: 40
#
# 24_EP18_03-img88-nose_right:
# width_object: 70, height_object: 40

# %%
from clasification.svm import SVMClassifier

# Load the dataset and initialize the classifier
# dataset_file = 'test-output/4qmv-all-component.csv'
# dataset_file = 'test-output/nilai-fitur-all-component.csv'
# dataset_file = 'output/csv/4qmv-all-component.csv'
dataset_file = 'output/csv/nilai-fitur-all-component.csv'
label_column = 'Label'
except_feature_columns = ['Frame', 'Folder Path', 'Label']  # Columns to exclude

# Initialize the classifier
classifier = SVMClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)

# Load, split, train, evaluate and save the model
classifier.load_data()
classifier.split_data(test_size=0.2)
# Train with auto parameter tuning
# classifier.train_model(C=1, kernel='poly', gamma='scale')
classifier.train_model(autoParams=True)
classifier.evaluate_model()
# classifier.save_model('svm_model.joblib')
# Out:
# output/csv/nilai-fitur-all-component.csv
#
# Best combination found:
# {'C': 0.1, 'kernel': 'sigmoid', 'gamma': 'scale'}
# Best accuracy: 0.9063829787234042
# Accuracy: 0.9063829787234042
#
# Confusion Matrix:
# [[32  6  0  4]
#  [ 0 71  0  0]
#  [ 0  6 39  6]
#  [ 0  0  0 71]]

# %%
from clasification.svm import SVMClassifier

# Load the dataset and initialize the classifier
# dataset_file = 'test-output/4qmv-all-component.csv'
# dataset_file = 'test-output/nilai-fitur-all-component.csv'
dataset_file = 'output/csv/4qmv-all-component.csv'
label_column = 'Label'
except_feature_columns = ['Frame', 'Folder Path', 'Label']  # Columns to exclude

# Initialize the classifier
classifier = SVMClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)

# Load, split, train, evaluate and save the model
classifier.load_data()
classifier.split_data(test_size=0.2)
# Train with auto parameter tuning
# classifier.train_model(C=1, kernel='poly', gamma='scale')
classifier.train_model(autoParams=True)
classifier.evaluate_model()
# classifier.save_model('svm_model.joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 classifier = SVMClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)
#      13 # Load, split, train, evaluate and save the model
# ---> 14 classifier.load_data()
#      15 classifier.split_data(test_size=0.2)
#      16 # Train with auto parameter tuning
#      17 # classifier.train_model(C=1, kernel='poly', gamma='scale')
#
# File d:\PCVK-DLIB-KNN\clasification\svm.py:24, in SVMClassifier.load_data(self)
#      23 def load_data(self):
# ---> 24     data = pd.read_csv(self.dataset_file)
#      25     print(self.dataset_file)
#      27     if self.feature_column is None and (self.except_feature_column is None or self.except_feature_column == [None]):
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/csv/4qmv-all-component.csv'

# %%
from clasification.knn import KNNClassifier

# Load the dataset and initialize the classifier
# dataset_file = 'test-output/4qmv-all-component.csv'
dataset_file = 'output-baru-tanpa-hidung/csv/nilai-fitur-all-component.csv'
label_column = 'Label'
except_feature_columns = ['Frame', 'Folder Path', 'Label']  # Columns to exclude

# Initialize the classifier
classifier = KNNClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)

# Load, split, train, evaluate and save the model
classifier.load_data()
classifier.split_data(test_size=0.2)
# Train with auto parameter tuning
# classifier.train_model(autoParams=False, n_neighbors=5, metric='minkowski', p=1)
classifier.train_model(autoParams=True)
classifier.evaluate_model()
classifier.save_model('knn_model_5x5.joblib')
# Out:
# Loaded dataset from output-baru/csv/nilai-fitur-all-component.csv
#
# Best hyperparameters: {'metric': 'minkowski', 'n_neighbors': 3, 'p': 1}
# Number of neighbors (K): 3
# Model Evaluation:
# Test Accuracy: 0.9994
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Disgust       1.00      1.00      1.00       401
#    Happiness       1.00      1.00      1.00       308
#      Sadness       1.00      1.00      1.00       579
#     Surprise       1.00      1.00      1.00       287
#
#     accuracy                           1.00      1575
#    macro avg       1.00      1.00      1.00      1575
# weighted avg       1.00      1.00      1.00      1575
#
# Model saved to models\knn_model_5x5.joblib
# Label encoder saved to models\label_encoder.joblib
