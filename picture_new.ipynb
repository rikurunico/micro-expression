# %%
import cv2
import dlib

# load the face detector and shape predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")

# %%
import os
import numpy as np
np.set_printoptions(threshold=np.inf)


# Import module yang digunkaan untuk ekstrak gambar
from preprocessing.input_to_image import get_frames_by_input_video
from preprocessing.scarpping_component import extract_component_by_images
# from preprocessing.feature_extraction import  block_matching

pathDatasetImage = "dataset/video_to_images"
get_frames_by_input_video(pathInputVideo="dataset/video/EP02_01f.avi", pathOutputImage=pathDatasetImage, framePerSecond=60)

# looping semua file yang ada didalam
for filename in os.listdir(pathDatasetImage):
    if filename.endswith(".jpg") or filename.endswith(".png"): 
        # Create the directory if it doesn't exist
        image = cv2.imread(os.path.join(pathDatasetImage, filename))
        image = cv2.resize(image, (600, 500))
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # detect the faces
        rects = detector(gray)

        # go through the face bounding boxes
        for rect in rects:
            # apply the shape predictor to the face ROI
            shape = predictor(gray, rect)

            # X itu kiri ke kanan
            # Y itu atas ke bawah

            # Mata Kiri
            data_blocks = np.array(extract_component_by_images(
                image=image, 
                shape=shape, 
                frameName=filename.split(".")[0],
                objectName="eye_left", 
                objectRectangle={"x_right": 39, "x_left": 36, "y_highest": 38, "y_lowest": 41}, 
                pixelShifting={"pixel_x": 25, "pixel_y": 25},
            ))
            # print(data_blocks)

            # # Mata Kanan
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="eye_right", 
            #     objectRectangle={"x_right": 45, "x_left": 42, "y_highest": 43, "y_lowest": 47}, 
            #     pixelShifting={"pixel_x": 25, "pixel_y": 25}
            # )

            # # Alis Kiri
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="eyebrow_left", 
            #     objectRectangle={"x_right": 21, "x_left": 17, "y_highest": 18, "y_lowest": 21}, 
            #     pixelShifting={"pixel_x": 15, "pixel_y": 15}
            # )

            # # Alis Kanan
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="eyebrow_right", 
            #     objectRectangle={"x_right": 26, "x_left": 22, "y_highest": 25, "y_lowest": 22}, 
            #     pixelShifting={"pixel_x": 15, "pixel_y": 15}
            # )

            # # Mulut
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="mouth", 
            #     objectRectangle={"x_right": 54, "x_left": 48, "y_highest": 52, "y_lowest": 57}, 
            #     pixelShifting={"pixel_x": 25, "pixel_y": 5}
            # )

            # # Hidung Kanan
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="nose_right", 
            #     objectRectangle={"x_right": 31, "x_left": 40, "y_highest": 40, "y_lowest": 48}, 
            #     pixelShifting={"pixel_x": 15, "pixel_y": -25}
            # )

            # # Hidung Kiri
            # extract_component_by_images(
            #     image=image, 
            #     shape=shape, 
            #     frameName=filename.split(".")[0],
            #     objectName="nose_left", 
            #     objectRectangle={"x_right": 47, "x_left": 35, "y_highest": 47, "y_lowest": 54}, 
            #     pixelShifting={"pixel_x": 15, "pixel_y": -25}
            # )
            
            # tambah component disini

# cv2.imshow("Frame", image)
# cv2.waitKey(0)
# Out:
# frame1-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame1-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame1-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame1-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame1-Mouth
# width_object: 143, height_object: 44
# Print after resize 140 42
#
# frame1-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame1-Nose_left
# width_object: 50, height_object: 87
# Print after resize 49 84
#
# frame10-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame10-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame10-Eyebrow_left
# width_object: 126, height_object: 44
# Print after resize 126 42
#
# frame10-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame10-Mouth
# width_object: 143, height_object: 44
# Print after resize 140 42
#
# frame10-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame10-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame11-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame11-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame11-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame11-Eyebrow_right
# width_object: 120, height_object: 54
# Print after resize 119 49
#
# frame11-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame11-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame11-Nose_left
# width_object: 50, height_object: 87
# Print after resize 49 84
#
# frame12-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame12-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame12-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame12-Eyebrow_right
# width_object: 120, height_object: 54
# Print after resize 119 49
#
# frame12-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame12-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame12-Nose_left
# width_object: 50, height_object: 87
# Print after resize 49 84
#
# frame13-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame13-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame13-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame13-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame13-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame13-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame13-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame14-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame14-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame14-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame14-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame14-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame14-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame14-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame15-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame15-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame15-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame15-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame15-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame15-Nose_right
# width_object: 60, height_object: 85
# Print after resize 56 84
#
# frame15-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame16-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame16-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame16-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame16-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame16-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame16-Nose_right
# width_object: 60, height_object: 85
# Print after resize 56 84
#
# frame16-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame17-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame17-Eye_right
# width_object: 95, height_object: 63
# Print after resize 91 63
#
# frame17-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame17-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame17-Mouth
# width_object: 146, height_object: 46
# Print after resize 140 42
#
# frame17-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame17-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame18-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame18-Eye_right
# width_object: 95, height_object: 63
# Print after resize 91 63
#
# frame18-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame18-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame18-Mouth
# width_object: 146, height_object: 46
# Print after resize 140 42
#
# frame18-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame18-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame19-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame19-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame19-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame19-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame19-Mouth
# width_object: 146, height_object: 46
# Print after resize 140 42
#
# frame19-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame19-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame2-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame2-Eye_right
# width_object: 95, height_object: 64
# Print after resize 91 63
#
# frame2-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame2-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame2-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame2-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame2-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame20-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame20-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame20-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame20-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame20-Mouth
# width_object: 146, height_object: 46
# Print after resize 140 42
#
# frame20-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame20-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame21-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame21-Eye_right
# width_object: 97, height_object: 64
# Print after resize 91 63
#
# frame21-Eyebrow_left
# width_object: 126, height_object: 44
# Print after resize 126 42
#
# frame21-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame21-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame21-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame21-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame22-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame22-Eye_right
# width_object: 97, height_object: 64
# Print after resize 91 63
#
# frame22-Eyebrow_left
# width_object: 126, height_object: 44
# Print after resize 126 42
#
# frame22-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame22-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame22-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame22-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame23-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame23-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame23-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame23-Eyebrow_right
# width_object: 119, height_object: 52
# Print after resize 119 49
#
# frame23-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame23-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame23-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame24-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame24-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame24-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame24-Eyebrow_right
# width_object: 119, height_object: 52
# Print after resize 119 49
#
# frame24-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame24-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame24-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame25-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame25-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame25-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame25-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame25-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame25-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame25-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame26-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame26-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame26-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame26-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame26-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame26-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame26-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame27-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame27-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame27-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame27-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame27-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame27-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame27-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame28-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame28-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame28-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame28-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame28-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame28-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame28-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame29-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame29-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame29-Eyebrow_left
# width_object: 125, height_object: 44
# Print after resize 119 42
#
# frame29-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame29-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame29-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame29-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame3-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame3-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame3-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame3-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame3-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame3-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame3-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame30-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame30-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame30-Eyebrow_left
# width_object: 125, height_object: 44
# Print after resize 119 42
#
# frame30-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame30-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame30-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame30-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame31-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame31-Eye_right
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame31-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame31-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame31-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame31-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame31-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame32-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame32-Eye_right
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame32-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame32-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame32-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame32-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame32-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame33-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame33-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame33-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame33-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame33-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame33-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame33-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame34-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame34-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame34-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame34-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame34-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame34-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame34-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame35-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame35-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame35-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame35-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame35-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame35-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame35-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame36-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame36-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame36-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame36-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame36-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame36-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame36-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame37-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame37-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame37-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame37-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame37-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame37-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame37-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame38-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame38-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame38-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame38-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame38-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame38-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame38-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame39-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame39-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame39-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame39-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame39-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame39-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame39-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame4-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame4-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame4-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame4-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame4-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame4-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame4-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame40-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame40-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame40-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame40-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame40-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame40-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame40-Nose_left
# width_object: 52, height_object: 87
# Print after resize 49 84
#
# frame41-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame41-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame41-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame41-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame41-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame41-Nose_right
# width_object: 63, height_object: 86
# Print after resize 63 84
#
# frame41-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame42-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame42-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame42-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame42-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame42-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame42-Nose_right
# width_object: 63, height_object: 86
# Print after resize 63 84
#
# frame42-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame43-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame43-Eye_right
# width_object: 95, height_object: 64
# Print after resize 91 63
#
# frame43-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame43-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame43-Mouth
# width_object: 143, height_object: 46
# Print after resize 140 42
#
# frame43-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame43-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame44-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame44-Eye_right
# width_object: 95, height_object: 64
# Print after resize 91 63
#
# frame44-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame44-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame44-Mouth
# width_object: 143, height_object: 46
# Print after resize 140 42
#
# frame44-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame44-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame45-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame45-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame45-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame45-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame45-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame45-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame45-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame46-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame46-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame46-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame46-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame46-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame46-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame46-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame47-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame47-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame47-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame47-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame47-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame47-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame47-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame48-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame48-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame48-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame48-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame48-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame48-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame48-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame49-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame49-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame49-Eyebrow_left
# width_object: 122, height_object: 45
# Print after resize 119 42
#
# frame49-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame49-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame49-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame49-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame5-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame5-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame5-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame5-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame5-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame5-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame5-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame50-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame50-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame50-Eyebrow_left
# width_object: 122, height_object: 45
# Print after resize 119 42
#
# frame50-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame50-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame50-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame50-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame51-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame51-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame51-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame51-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame51-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame51-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame51-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame52-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame52-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame52-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame52-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame52-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame52-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame52-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame53-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame53-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame53-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame53-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame53-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame53-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame53-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame54-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame54-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame54-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame54-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame54-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame54-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame54-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame55-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame55-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame55-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame55-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame55-Mouth
# width_object: 142, height_object: 44
# Print after resize 140 42
#
# frame55-Nose_right
# width_object: 63, height_object: 86
# Print after resize 63 84
#
# frame55-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame56-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame56-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame56-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame56-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame56-Mouth
# width_object: 142, height_object: 44
# Print after resize 140 42
#
# frame56-Nose_right
# width_object: 63, height_object: 86
# Print after resize 63 84
#
# frame56-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame57-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame57-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame57-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame57-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame57-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame57-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame57-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame58-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame58-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame58-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame58-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame58-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame58-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame58-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame59-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame59-Eye_right
# width_object: 95, height_object: 63
# Print after resize 91 63
#
# frame59-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame59-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame59-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame59-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame59-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame6-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame6-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame6-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame6-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame6-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame6-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame6-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame60-Eye_left
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame60-Eye_right
# width_object: 95, height_object: 63
# Print after resize 91 63
#
# frame60-Eyebrow_left
# width_object: 123, height_object: 44
# Print after resize 119 42
#
# frame60-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame60-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame60-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame60-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame61-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame61-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame61-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame61-Eyebrow_right
# width_object: 119, height_object: 52
# Print after resize 119 49
#
# frame61-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame61-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame61-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame62-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame62-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame62-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame62-Eyebrow_right
# width_object: 119, height_object: 52
# Print after resize 119 49
#
# frame62-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame62-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame62-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame63-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame63-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame63-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame63-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame63-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame63-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame63-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame64-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame64-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame64-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame64-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame64-Mouth
# width_object: 143, height_object: 45
# Print after resize 140 42
#
# frame64-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame64-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame65-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame65-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame65-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame65-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame65-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame65-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame65-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame66-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame66-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame66-Eyebrow_left
# width_object: 124, height_object: 46
# Print after resize 119 42
#
# frame66-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame66-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame66-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame66-Nose_left
# width_object: 51, height_object: 87
# Print after resize 49 84
#
# frame67-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame67-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame67-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame67-Eyebrow_right
# width_object: 120, height_object: 54
# Print after resize 119 49
#
# frame67-Mouth
# width_object: 146, height_object: 45
# Print after resize 140 42
#
# frame67-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame67-Nose_left
# width_object: 50, height_object: 87
# Print after resize 49 84
#
# frame68-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame68-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame68-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame68-Eyebrow_right
# width_object: 120, height_object: 54
# Print after resize 119 49
#
# frame68-Mouth
# width_object: 146, height_object: 45
# Print after resize 140 42
#
# frame68-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame68-Nose_left
# width_object: 50, height_object: 87
# Print after resize 49 84
#
# frame69-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame69-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame69-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame69-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame69-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame69-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame69-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame7-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame7-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame7-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame7-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame7-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame7-Nose_right
# width_object: 60, height_object: 86
# Print after resize 56 84
#
# frame7-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame70-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame70-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame70-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame70-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame70-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame70-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame70-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame71-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame71-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame71-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame71-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame71-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame71-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame71-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame72-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame72-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame72-Eyebrow_left
# width_object: 125, height_object: 45
# Print after resize 119 42
#
# frame72-Eyebrow_right
# width_object: 119, height_object: 53
# Print after resize 119 49
#
# frame72-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame72-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame72-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame73-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame73-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame73-Eyebrow_left
# width_object: 124, height_object: 44
# Print after resize 119 42
#
# frame73-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame73-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame73-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame73-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame74-Eye_left
# width_object: 98, height_object: 63
# Print after resize 98 63
#
# frame74-Eye_right
# width_object: 96, height_object: 63
# Print after resize 91 63
#
# frame74-Eyebrow_left
# width_object: 124, height_object: 44
# Print after resize 119 42
#
# frame74-Eyebrow_right
# width_object: 121, height_object: 53
# Print after resize 119 49
#
# frame74-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame74-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame74-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame75-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame75-Eye_right
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame75-Eyebrow_left
# width_object: 124, height_object: 44
# Print after resize 119 42
#
# frame75-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame75-Mouth
# width_object: 143, height_object: 46
# Print after resize 140 42
#
# frame75-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame75-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame76-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame76-Eye_right
# width_object: 97, height_object: 62
# Print after resize 91 56
#
# frame76-Eyebrow_left
# width_object: 124, height_object: 44
# Print after resize 119 42
#
# frame76-Eyebrow_right
# width_object: 122, height_object: 53
# Print after resize 119 49
#
# frame76-Mouth
# width_object: 143, height_object: 46
# Print after resize 140 42
#
# frame76-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame76-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame77-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame77-Eye_right
# width_object: 95, height_object: 62
# Print after resize 91 56
#
# frame77-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame77-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame77-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame77-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame77-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame78-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame78-Eye_right
# width_object: 95, height_object: 62
# Print after resize 91 56
#
# frame78-Eyebrow_left
# width_object: 123, height_object: 45
# Print after resize 119 42
#
# frame78-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame78-Mouth
# width_object: 145, height_object: 45
# Print after resize 140 42
#
# frame78-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame78-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
#
# frame79-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame79-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame79-Eyebrow_left
# width_object: 122, height_object: 45
# Print after resize 119 42
#
# frame79-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame79-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame79-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame79-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame8-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame8-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame8-Eyebrow_left
# width_object: 126, height_object: 45
# Print after resize 126 42
#
# frame8-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame8-Mouth
# width_object: 144, height_object: 45
# Print after resize 140 42
#
# frame8-Nose_right
# width_object: 60, height_object: 86
# Print after resize 56 84
#
# frame8-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame80-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame80-Eye_right
# width_object: 96, height_object: 64
# Print after resize 91 63
#
# frame80-Eyebrow_left
# width_object: 122, height_object: 45
# Print after resize 119 42
#
# frame80-Eyebrow_right
# width_object: 120, height_object: 52
# Print after resize 119 49
#
# frame80-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame80-Nose_right
# width_object: 61, height_object: 85
# Print after resize 56 84
#
# frame80-Nose_left
# width_object: 51, height_object: 85
# Print after resize 49 84
#
# frame81-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame81-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame81-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame81-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame81-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame81-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame81-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame82-Eye_left
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame82-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame82-Eyebrow_left
# width_object: 124, height_object: 45
# Print after resize 119 42
#
# frame82-Eyebrow_right
# width_object: 120, height_object: 53
# Print after resize 119 49
#
# frame82-Mouth
# width_object: 145, height_object: 44
# Print after resize 140 42
#
# frame82-Nose_right
# width_object: 62, height_object: 86
# Print after resize 56 84
#
# frame82-Nose_left
# width_object: 52, height_object: 86
# Print after resize 49 84
#
# frame83-Eye_left
# width_object: 98, height_object: 61
# Print after resize 98 56
#
# frame83-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame83-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame83-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame83-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame83-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame83-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame84-Eye_left
# width_object: 98, height_object: 61
# Print after resize 98 56
#
# frame84-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame84-Eyebrow_left
# width_object: 126, height_object: 46
# Print after resize 126 42
#
# frame84-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame84-Mouth
# width_object: 144, height_object: 46
# Print after resize 140 42
#
# frame84-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame84-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame85-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame85-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame85-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame85-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame85-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame85-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame85-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame86-Eye_left
# width_object: 98, height_object: 62
# Print after resize 98 56
#
# frame86-Eye_right
# width_object: 96, height_object: 62
# Print after resize 91 56
#
# frame86-Eyebrow_left
# width_object: 125, height_object: 46
# Print after resize 119 42
#
# frame86-Eyebrow_right
# width_object: 121, height_object: 54
# Print after resize 119 49
#
# frame86-Mouth
# width_object: 144, height_object: 44
# Print after resize 140 42
#
# frame86-Nose_right
# width_object: 62, height_object: 85
# Print after resize 56 84
#
# frame86-Nose_left
# width_object: 50, height_object: 86
# Print after resize 49 84
#
# frame9-Eye_left
# width_object: 98, height_object: 64
# Print after resize 98 63
#
# frame9-Eye_right
# width_object: 97, height_object: 63
# Print after resize 91 63
#
# frame9-Eyebrow_left
# width_object: 126, height_object: 44
# Print after resize 126 42
#
# frame9-Eyebrow_right
# width_object: 122, height_object: 54
# Print after resize 119 49
#
# frame9-Mouth
# width_object: 143, height_object: 44
# Print after resize 140 42
#
# frame9-Nose_right
# width_object: 61, height_object: 86
# Print after resize 56 84
#
# frame9-Nose_left
# width_object: 51, height_object: 86
# Print after resize 49 84
