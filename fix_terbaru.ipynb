# %%
import os
import cv2
import shutil

# Path utama
base_input_folder = 'dataset/casme_custom/'
base_output_folder = 'dataset/casme_dua_terbaru'

# Bersihkan folder output jika ada
if os.path.exists(base_output_folder):
    shutil.rmtree(base_output_folder)

# Loop melalui folder dan file dalam folder input
for folder1 in os.listdir(base_input_folder):
    folder1_path = os.path.join(base_input_folder, folder1)
    
    print(f"Memeriksa folder1: {folder1_path}")
    
    if os.path.isdir(folder1_path):
        for filename in os.listdir(folder1_path):
            file_path = os.path.join(folder1_path, filename)
            
            # Cek apakah file adalah file .avi
            if filename.lower().endswith('.avi') and os.path.isfile(file_path):
                print(f"Menemukan file AVI: {file_path}")

                # Buat folder output sesuai nama folder
                output_folder = os.path.join(base_output_folder, folder1, filename[:-4])  # Hapus ekstensi '.avi' dari nama folder
                os.makedirs(output_folder, exist_ok=True)

                # Buka video menggunakan OpenCV
                vidcap = cv2.VideoCapture(file_path)

                # Ambil frame rate dari video
                framePerSecond = vidcap.get(cv2.CAP_PROP_FPS)

                # Variabel untuk menghitung nomor frame
                count = 1

                while vidcap.isOpened():
                    success, image = vidcap.read()  # Baca frame
                    if not success:
                        break  # Jika tidak ada frame yang dibaca, keluar dari loop

                    # Simpan gambar ke folder output dengan nama imgX.jpg
                    img_name = f'img{count}.jpg'
                    img_path = os.path.join(output_folder, img_name)
                    cv2.imwrite(img_path, image)  # Simpan gambar

                    count += 1

                # Lepas video setelah selesai
                vidcap.release()
                print(f"Extraction complete for {filename}, saved {count-1} frames to {output_folder}")
# Out:
# Memeriksa folder1: dataset/casme_custom/Disgust
# Menemukan file AVI: dataset/casme_custom/Disgust/24_EP02_02f.avi
# Extraction complete for 24_EP02_02f.avi, saved 488 frames to dataset/casme_dua_terbaru/Disgust/24_EP02_02f
# Menemukan file AVI: dataset/casme_custom/Disgust/19_EP16_02.avi
# Extraction complete for 19_EP16_02.avi, saved 266 frames to dataset/casme_dua_terbaru/Disgust/19_EP16_02
# Menemukan file AVI: dataset/casme_custom/Disgust/03_EP19_08.avi
# Extraction complete for 03_EP19_08.avi, saved 291 frames to dataset/casme_dua_terbaru/Disgust/03_EP19_08
# Menemukan file AVI: dataset/casme_custom/Disgust/25_EP18_04f.avi
# Extraction complete for 25_EP18_04f.avi, saved 448 frames to dataset/casme_dua_terbaru/Disgust/25_EP18_04f
# Menemukan file AVI: dataset/casme_custom/Disgust/20_EP06_03.avi
# Extraction complete for 20_EP06_03.avi, saved 173 frames to dataset/casme_dua_terbaru/Disgust/20_EP06_03
# Menemukan file AVI: dataset/casme_custom/Disgust/17_EP13_04.avi
# Extraction complete for 17_EP13_04.avi, saved 174 frames to dataset/casme_dua_terbaru/Disgust/17_EP13_04
# Menemukan file AVI: dataset/casme_custom/Disgust/25_EP09_02.avi
# Extraction complete for 25_EP09_02.avi, saved 232 frames to dataset/casme_dua_terbaru/Disgust/25_EP09_02
# Memeriksa folder1: dataset/casme_custom/Happiness
# Menemukan file AVI: dataset/casme_custom/Happiness/17_EP06_07.avi
# Extraction complete for 17_EP06_07.avi, saved 360 frames to dataset/casme_dua_terbaru/Happiness/17_EP06_07
# Menemukan file AVI: dataset/casme_custom/Happiness/09_EP15_05.avi
# Extraction complete for 09_EP15_05.avi, saved 200 frames to dataset/casme_dua_terbaru/Happiness/09_EP15_05
# Menemukan file AVI: dataset/casme_custom/Happiness/01_EP02_01f.avi
# Extraction complete for 01_EP02_01f.avi, saved 290 frames to dataset/casme_dua_terbaru/Happiness/01_EP02_01f
# Menemukan file AVI: dataset/casme_custom/Happiness/05_EP03_01.avi
# Extraction complete for 05_EP03_01.avi, saved 218 frames to dataset/casme_dua_terbaru/Happiness/05_EP03_01
# Menemukan file AVI: dataset/casme_custom/Happiness/14_EP09_03.avi
# Extraction complete for 14_EP09_03.avi, saved 51 frames to dataset/casme_dua_terbaru/Happiness/14_EP09_03
# Menemukan file AVI: dataset/casme_custom/Happiness/06_EP01_01.avi
# Extraction complete for 06_EP01_01.avi, saved 236 frames to dataset/casme_dua_terbaru/Happiness/06_EP01_01
# Menemukan file AVI: dataset/casme_custom/Happiness/09_EP05_05.avi
# Extraction complete for 09_EP05_05.avi, saved 169 frames to dataset/casme_dua_terbaru/Happiness/09_EP05_05
# Memeriksa folder1: dataset/casme_custom/Sadness
# Menemukan file AVI: dataset/casme_custom/Sadness/24_EP07_04f.avi
# Extraction complete for 24_EP07_04f.avi, saved 442 frames to dataset/casme_dua_terbaru/Sadness/24_EP07_04f
# Menemukan file AVI: dataset/casme_custom/Sadness/26_EP15_01.avi
# Extraction complete for 26_EP15_01.avi, saved 127 frames to dataset/casme_dua_terbaru/Sadness/26_EP15_01
# Menemukan file AVI: dataset/casme_custom/Sadness/19_EP19_04.avi
# Extraction complete for 19_EP19_04.avi, saved 163 frames to dataset/casme_dua_terbaru/Sadness/19_EP19_04
# Menemukan file AVI: dataset/casme_custom/Sadness/24_EP07_01.avi
# Extraction complete for 24_EP07_01.avi, saved 119 frames to dataset/casme_dua_terbaru/Sadness/24_EP07_01
# Menemukan file AVI: dataset/casme_custom/Sadness/17_EP15_01.avi
# Extraction complete for 17_EP15_01.avi, saved 403 frames to dataset/casme_dua_terbaru/Sadness/17_EP15_01
# Menemukan file AVI: dataset/casme_custom/Sadness/17_EP15_03.avi
# Extraction complete for 17_EP15_03.avi, saved 658 frames to dataset/casme_dua_terbaru/Sadness/17_EP15_03
# Menemukan file AVI: dataset/casme_custom/Sadness/24_EP10_03.avi
# Extraction complete for 24_EP10_03.avi, saved 876 frames to dataset/casme_dua_terbaru/Sadness/24_EP10_03
# Memeriksa folder1: dataset/casme_custom/Surprise
# Menemukan file AVI: dataset/casme_custom/Surprise/05_EP04_05.avi
# Extraction complete for 05_EP04_05.avi, saved 69 frames to dataset/casme_dua_terbaru/Surprise/05_EP04_05
# Menemukan file AVI: dataset/casme_custom/Surprise/05_EP03_06.avi
# Extraction complete for 05_EP03_06.avi, saved 173 frames to dataset/casme_dua_terbaru/Surprise/05_EP03_06
# Menemukan file AVI: dataset/casme_custom/Surprise/24_EP18_03.avi
# Extraction complete for 24_EP18_03.avi, saved 321 frames to dataset/casme_dua_terbaru/Surprise/24_EP18_03
# Menemukan file AVI: dataset/casme_custom/Surprise/19_EP19_02.avi
# Extraction complete for 19_EP19_02.avi, saved 385 frames to dataset/casme_dua_terbaru/Surprise/19_EP19_02
# Menemukan file AVI: dataset/casme_custom/Surprise/05_EP12_03f.avi
# Extraction complete for 05_EP12_03f.avi, saved 93 frames to dataset/casme_dua_terbaru/Surprise/05_EP12_03f
# Menemukan file AVI: dataset/casme_custom/Surprise/06_EP02_31.avi
# Extraction complete for 06_EP02_31.avi, saved 276 frames to dataset/casme_dua_terbaru/Surprise/06_EP02_31
# Menemukan file AVI: dataset/casme_custom/Surprise/02_EP14_01.avi
# Extraction complete for 02_EP14_01.avi, saved 200 frames to dataset/casme_dua_terbaru/Surprise/02_EP14_01

# %%
import os
import cv2
import dlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tabulate import tabulate
import pandas as pd
import shutil
np.set_printoptions(threshold=np.inf)

# %%
# Import module yang digunakan
from preprocessing.scarpping_component import extract_component_by_images
from feature_extraction.poc import POC
from feature_extraction.vektor import Vektor
from feature_extraction.quadran import Quadran
import re

def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split('(\d+)', s)]

# load model dan shape predictor untuk deteksi wajah
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")

components_setup = {
    'mulut': {
        'object_name': 'mouth',
        'object_rectangle': {"x_right": 54, "x_left": 48, "y_highest": 52, "y_lowest": 57},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 5},
        'object_dimension': {'width': 140, 'height': 40}
    },
    'mata_kiri': {
        'object_name': 'eye_left',
        'object_rectangle': {"x_right": 39, "x_left": 36, "y_highest": 38, "y_lowest": 41},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'mata_kanan': {
        'object_name': 'eye_right',
        'object_rectangle': {"x_right": 45, "x_left": 42, "y_highest": 43, "y_lowest": 47},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'alis_kiri': {
        'object_name': 'eyebrow_left',
        'object_rectangle': {"x_right": 21, "x_left": 17, "y_highest": 18, "y_lowest": 21},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
    'alis_kanan': {
        'object_name': 'eyebrow_right',
        'object_rectangle': {"x_right": 26, "x_left": 22, "y_highest": 25, "y_lowest": 22},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
    'hidung_kanan': {
        'object_name': 'nose_right',
        'object_rectangle': {"x_right": 31, "x_left": 40, "y_highest": 40, "y_lowest": 48},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": -25},
        'object_dimension': {'width': 70, 'height': 40}
    },
    'hidung_kiri': {
        'object_name': 'nose_left',
        'object_rectangle': {"x_right": 47, "x_left": 35, "y_highest": 47, "y_lowest": 54},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": -25},
        'object_dimension': {'width': 70, 'height': 40}
    }
}

# Inisialisasi variabel untuk path url dan blok size
blockSize = 5
pathDirectory = {
    "base_path_dataset": "dataset",
    # "base_dataset_input" : "dataset/casme_custom_from_one",
    "base_dataset_input" : "dataset/casme_dua_terbaru",
    "result_dataset" : "output-baru-dengan-hidung", 
    "component_image" : "component_to_images", 
    "video_frame" :"video_to_images"
}

# Inisialisasi variabel untuk menyimpan data dari masing-masing komponen
frames_data_quadran = []
frames_data_all_component = []
frames_data_quadran_column = ['sumX', 'sumY', 'Tetha', 'Magnitude', 'JumlahQuadran']
quadran_dimensions = ['Q1', 'Q2', 'Q3', 'Q4']
frames_data = {component_name: [] for component_name in components_setup}
total_blocks_components = {component_name: 0 for component_name in components_setup}
data_blocks_first_image = {component_name: None for component_name in components_setup}
index = {component_name: 0 for component_name in components_setup}

# Hitung total blok dari masing-masing komponen lalu disetup kedalam total_blocks_components
for component_name, component_info in components_setup.items():
    total_blocks_components[component_name] = int((component_info['object_dimension']['width'] / blockSize) * (component_info['object_dimension']['height'] / blockSize))

# Loop melalui setiap kunci dan nilai di pathDirectory dan hapus direktorinya
for key, value in pathDirectory.items():
    # Jika tidak mengandung base, hapus direktori sesuai dengan nilai yang ada
    if not "base" in key:
        shutil.rmtree(value, ignore_errors=True)

# Looping folder label didalam base_dataset_input
for foldername_label in os.listdir(pathDirectory['base_dataset_input']):
    foldername_label_join_basepath = os.path.join(pathDirectory['base_dataset_input'], foldername_label)
    # Jika folder nya tidak ada skip looping ini
    if not os.path.isdir(foldername_label_join_basepath):
        continue
    
    # Looping folder label didalam foldername_label_join_basepath 
    for foldername in os.listdir(foldername_label_join_basepath):
        foldername_join_basepath = os.path.join(foldername_label_join_basepath, foldername)
        # Jika folder nya tidak ada skip looping ini
        if not os.path.isdir(foldername_join_basepath):
            continue

        # Reset variabel setiap kali mulai looping folder baru
        data_blocks_first_image = {component_name: None for component_name in components_setup}
        index = {component_name: 0 for component_name in components_setup}

        # looping semua file yang ada didalam
        for filename in sorted(os.listdir(foldername_join_basepath), key=natural_sort_key):
            if filename.endswith(".jpg") or filename.endswith(".png"): 

                # Read path sesuai dengan foldername_join_basepath dijoin path dengan filename
                image = cv2.imread(os.path.join(foldername_join_basepath, filename))
                # Resize image ke ukuran yang diinginkan
                # image = cv2.resize(image, (600, 500))
                # Cpmvert image ke grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Deteksi shape muka didalam grayscale image
                rects = detector(gray)

                if not index[component_name] == 0:
                    # Buat variabel frames_data_all_component untuk menampung data current frame
                    frame_data_all_component = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}
                    # Buat variabel frame_data_quadran untuk menampung data current frame
                    frame_data_quadran = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                # Memproses rects untuk setiap bentuk wajah yang terdeteksi
                for rect in rects:
                    # Ambil bentuk wajah dalam bentuk shape sesuai dengan model predictor
                    shape = predictor(gray, rect)
                    # Memproses setiap komponen wajah
                    for component_name, component_info in components_setup.items():
                        # print(f"\n{foldername}-{filename.split('.')[0]}-{component_info['object_name']}:")
                        # Inisialisasi variabel sum_data_by_quadran untuk menyimpan data hasil quadran
                        sum_data_by_quadran = {}
                        # Buat variabel frame_data untuk menampung data current frame
                        frame_data = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                        # Looping untuk setiap atribut dalam frames_data_quadran_column
                        for column in frames_data_quadran_column:
                            # Inisialisasi sub-dictionary untuk setiap atribut dalam frames_data_quadran_column yang defaultnya 0
                            sum_data_by_quadran[column] = {quadrant: 0 for quadrant in quadran_dimensions}

                        # Ambil data blok image dari return fungsi extract_component_by_images
                        data_blocks_image_current = extract_component_by_images(
                            image=image,
                            shape=shape,
                            frameName=filename.split(".")[0],
                            objectName=component_info['object_name'],
                            objectRectangle=component_info['object_rectangle'],
                            pixelShifting=component_info['pixel_shifting'],
                            objectDimension=component_info['object_dimension']
                        )
                        
                        # Ambil frame pertama dari perulangan lalu simpan di variabel dan skip (lanjutkan ke frame berikut)
                        if data_blocks_first_image[component_name] is None:
                            # --- Setup bagian 4qmv Dataset ---
                            # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                            # for quadrant in quadran_dimensions:
                            #     for feature in frames_data_quadran_column:
                            #         # Buat nama kolom dengan menggunakan template yang diberikan
                            #         column_name = f"{component_name}_{feature}_{quadrant}"
                            #         # Set value sum_data_by_quadran[feature][quadrant] ke frame_data_quadran sesuai column_name nya
                            #         frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadrant]

                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Inisialisasi data untuk setiap blok
                            # for i in range(total_blocks_components[component_name]):
                                # Tambahkan data ke frame_data sesuai dengan indexnya
                                # frame_data[f'X{i+1}'] = 0
                                # frame_data[f'Y{i+1}'] = 0
                                # frame_data[f'Tetha{i+1}'] = 0
                                # frame_data[f'Magnitude{i+1}'] = 0
                                # # Tambahkan data ke frame_data_all_component sesuai dengan indexnya
                                # frame_data_all_component[f'{component_name}-X{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Y{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Tetha{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = 0

                            # Append data frame ke list frames_data sesuai dengan component_name
                            frames_data[component_name].append(frame_data)
                            # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                            frame_data['Folder Path'] = foldername
                            # Tambahkan kolom "Label" dengan nilai label saat ini
                            frame_data['Label'] = foldername_label
                            # Set value data_blocks_first_image[component_name] ke data_blocks_image_current
                            data_blocks_first_image[component_name] = data_blocks_image_current
                            # Skip looping nya ke looping selanjutnya
                            continue

                        # # Tampilkan data block image current ke matplotlib
                        # plt.imshow(np.uint8(data_blocks_image_current), cmap="gray")

                        # Inisiasi class POC
                        initPOC = POC(data_blocks_first_image[component_name], data_blocks_image_current, blockSize) 
                        # Pemanggilan fungsi pocCalc() untuk menghitung nilai POC disetiap gambar
                        valPOC = initPOC.getPOC() 

                        # Pemanggilan class dan method untuk menampilkan quiver / gambar panah
                        initQuiv = Vektor(valPOC, blockSize)
                        quivData = initQuiv.getVektor() 

                        # plt.quiver(quivData[:, 0], quivData[:, 1], quivData[:, 2], quivData[:, 3], scale=1, scale_units='xy', angles='xy', color="r")    

                        # # num = 0
                        # for rect_def in valPOC[2]:
                        #     x, y, width, height = rect_def
                            
                        #     rects = patches.Rectangle((x,y), width,height, edgecolor='r', facecolor='none') 
                        #     plt.gca().add_patch(rects)
                            
                        #     # plt.text(x,y,f'({num})', color="blue") 
                        #     # num += 1

                        # Pemanggilan class untuk mengeluarkan nilai karakteristik vektor
                        # blok ke, x,y,tetha, magnitude, dan quadran ke
                        initQuadran = Quadran(quivData) 
                        quadran = initQuadran.getQuadran()

                        # print(tabulate(quadran, headers=['Blok Ke', 'X', 'Y', 'Tetha', 'Magnitude', 'Quadran Ke']))
                        # plt.axis('on') 
                        # plt.show() 

                        # Update frame_data dengan data quadran
                        for i, quad in enumerate(quadran):
                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Set data kedalam frame_data sesuai column nya
                            frame_data[f'X{i+1}'] = quad[1]
                            frame_data[f'Y{i+1}'] = quad[2]
                            frame_data[f'Tetha{i+1}'] = quad[3]
                            frame_data[f'Magnitude{i+1}'] = quad[4]

                            # Set data kedalam frame_data_all_component sesuai columnnya
                            frame_data_all_component[f'{component_name}-X{i+1}'] = quad[1]
                            frame_data_all_component[f'{component_name}-Y{i+1}'] = quad[2]
                            frame_data_all_component[f'{component_name}-Tetha{i+1}'] = quad[3]
                            frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = quad[4]

                            # --- Setup bagian 4qmv Dataset ---
                            # Cek apakah quad[5] ada didalam array quadran_dimensions
                            if quad[5] in quadran_dimensions:
                                # Tambahkan nilai quad[1] ke sumX pada kuadran yang sesuai
                                sum_data_by_quadran['sumX'][quad[5]] += quad[1]
                                # Tambahkan nilai quad[2] ke sumY pada kuadran yang sesuai
                                sum_data_by_quadran['sumY'][quad[5]] += quad[2]
                                # Tambahkan nilai quad[3] ke Tetha pada kuadran yang sesuai
                                sum_data_by_quadran['Tetha'][quad[5]] += quad[3]
                                # Tambahkan nilai quad[4] ke Magnitude pada kuadran yang sesuai
                                sum_data_by_quadran['Magnitude'][quad[5]] += quad[4]
                                # Tambahkan jumlah quadran sesuai dengan quad[5] ke JumlahQuadran pada kuadran yang sesuai
                                sum_data_by_quadran['JumlahQuadran'][quad[5]] += 1
                        
                        # --- Setup bagian Nilai Fitur Dataset ---
                        # Append data frame ke list
                        frames_data[component_name].append(frame_data)
                        # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                        frame_data['Folder Path'] = foldername
                        # Tambahkan kolom "Label" dengan nilai label saat ini
                        frame_data['Label'] = foldername_label

                        # --- Setup bagian 4qmv Dataset ---
                        # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                        for quadran in quadran_dimensions:
                            for feature in frames_data_quadran_column:
                                # Buat nama kolom dengan menggunakan template yang diberikan
                                column_name = f"{component_name}_{feature}_{quadran}"
                                # Set value sum_data_by_quadran[feature][quadran] ke frame_data_quadran sesuai column_name nya
                                frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadran]

                # --- Setup bagian 4qmv Dataset ---
                if not index[component_name] == 0:
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_quadran.append(frame_data_quadran)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_quadran['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_quadran['Label'] = foldername_label

                if not index[component_name] == 0:
                    # --- Setup bagian frames data all component Dataset ---
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_all_component.append(frame_data_all_component)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_all_component['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_all_component['Label'] = foldername_label

                # Update index per component_name
                index[component_name] += 1

# Membuat direktori jika belum ada untuk outputnya
output_csv_dir = os.path.join(pathDirectory['result_dataset'], 'csv')
output_excel_dir = os.path.join(pathDirectory['result_dataset'], 'excel')
os.makedirs(output_csv_dir, exist_ok=True)
os.makedirs(output_excel_dir, exist_ok=True)

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (Nilai fitur)
for component_name in components_setup:
    csv_file_path = os.path.join(pathDirectory['result_dataset'], 'csv', f'{component_name}.csv')
    xlsx_file_path = os.path.join(pathDirectory['result_dataset'], 'excel', f'{component_name}.xlsx')
    if os.path.exists(csv_file_path):
        os.remove(csv_file_path)
    if os.path.exists(xlsx_file_path):
        os.remove(xlsx_file_path)

# Export dataframe ke dalam file csv dan xlsx sesuai dengan masing-masing component untuk fitur ekstrasi biasa
for component_name, data_frame in frames_data.items():
    # Initialisasi dataframe dengan pandas
    df = pd.DataFrame(data_frame)
    
    # Simpan ke file CSV
    nama_file_csv = f'{output_csv_dir}/{component_name}.csv'
    df.to_csv(nama_file_csv, index=False, float_format=None)
    
    # Simpan ke file Excel
    nama_file_xlsx = f'{output_excel_dir}/{component_name}.xlsx'
    # df.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_quadran untuk fitur ekstraksi 4qmv
# Initialisasi dataframe dengan pandas
df_4qmv = pd.DataFrame(frames_data_quadran)

# Inisialisasi nama file untuk dataset 4qmv
nama_file_csv = f'{output_csv_dir}/4qmv-all-component.csv'
nama_file_xlsx = f'{output_excel_dir}/4qmv-all-component.xlsx'

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
if os.path.exists(nama_file_csv):
    os.remove(nama_file_csv)
if os.path.exists(nama_file_xlsx):
    os.remove(nama_file_xlsx)

# Simpan ke file CSV
df_4qmv.to_csv(nama_file_csv, index=False, float_format=None)

# Simpan ke file Excel
# df_4qmv.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_all_component untuk fitur ekstraksi nilai fiturnya
# Initialisasi dataframe dengan pandas
df_fitur_all = pd.DataFrame(frames_data_all_component)

# Inisialisasi nama file untuk dataset 4qmv
nama_file_csv = f'{output_csv_dir}/nilai-fitur-all-component.csv'
nama_file_xlsx = f'{output_excel_dir}/nilai-fitur-all-component.xlsx'

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
if os.path.exists(nama_file_csv):
    os.remove(nama_file_csv)
if os.path.exists(nama_file_xlsx):
    os.remove(nama_file_xlsx)

# Simpan ke file CSV
df_fitur_all.to_csv(nama_file_csv, index=False, float_format=None)

# Simpan ke file Excel
# df_fitur_all.to_excel(nama_file_xlsx, index=False, float_format=None)
# Out:
# 25_EP09_02-img1-mouth:
#
# 25_EP09_02-img1-eye_left:
#
# 25_EP09_02-img1-eye_right:
#
# 25_EP09_02-img1-eyebrow_left:
#
# 25_EP09_02-img1-eyebrow_right:
#
# 25_EP09_02-img1-nose_right:
#
# 25_EP09_02-img1-nose_left:
#
# 25_EP09_02-img2-mouth:
#
# 25_EP09_02-img2-eye_left:
#
# 25_EP09_02-img2-eye_right:
#
# 25_EP09_02-img2-eyebrow_left:
#
# 25_EP09_02-img2-eyebrow_right:
#
# 25_EP09_02-img2-nose_right:
#
# 25_EP09_02-img2-nose_left:
#
# 25_EP09_02-img3-mouth:
#
# 25_EP09_02-img3-eye_left:
#
# 25_EP09_02-img3-eye_right:
#
# 25_EP09_02-img3-eyebrow_left:
#
# 25_EP09_02-img3-eyebrow_right:
#
# 25_EP09_02-img3-nose_right:
#
# 25_EP09_02-img3-nose_left:
#
# 25_EP09_02-img4-mouth:
#
# 25_EP09_02-img4-eye_left:
#
# 25_EP09_02-img4-eye_right:
#
# 25_EP09_02-img4-eyebrow_left:
#
# 25_EP09_02-img4-eyebrow_right:
#
# 25_EP09_02-img4-nose_right:
#
# 25_EP09_02-img4-nose_left:
#
# 25_EP09_02-img5-mouth:
#
# 25_EP09_02-img5-eye_left:
#
# 25_EP09_02-img5-eye_right:
#
# 25_EP09_02-img5-eyebrow_left:
#
# 25_EP09_02-img5-eyebrow_right:
#
# 25_EP09_02-img5-nose_right:
#
# 25_EP09_02-img5-nose_left:
#
# 25_EP09_02-img6-mouth:
#
# 25_EP09_02-img6-eye_left:
#
# 25_EP09_02-img6-eye_right:
#
# 25_EP09_02-img6-eyebrow_left:
#
# 25_EP09_02-img6-eyebrow_right:
#
# 25_EP09_02-img6-nose_right:
#
# 25_EP09_02-img6-nose_left:
#
# 25_EP09_02-img7-mouth:
#
# 25_EP09_02-img7-eye_left:
#
# 25_EP09_02-img7-eye_right:
#
# 25_EP09_02-img7-eyebrow_left:
#
# 25_EP09_02-img7-eyebrow_right:
#
# 25_EP09_02-img7-nose_right:
#
# 25_EP09_02-img7-nose_left:
#
# 25_EP09_02-img8-mouth:
#
# 25_EP09_02-img8-eye_left:
#
# 25_EP09_02-img8-eye_right:
#
# 25_EP09_02-img8-eyebrow_left:
#
# 25_EP09_02-img8-eyebrow_right:
#
# 25_EP09_02-img8-nose_right:
#
# 25_EP09_02-img8-nose_left:
#
# 25_EP09_02-img9-mouth:
#
# 25_EP09_02-img9-eye_left:
#
# 25_EP09_02-img9-eye_right:
#
# 25_EP09_02-img9-eyebrow_left:
#
# 25_EP09_02-img9-eyebrow_right:
#
# 25_EP09_02-img9-nose_right:
#
# 25_EP09_02-img9-nose_left:
#
# 25_EP09_02-img10-mouth:
#
# 25_EP09_02-img10-eye_left:
#
# 25_EP09_02-img10-eye_right:
#
# 25_EP09_02-img10-eyebrow_left:
#
# 25_EP09_02-img10-eyebrow_right:
#
# 25_EP09_02-img10-nose_right:
#
# 25_EP09_02-img10-nose_left:
#
# 25_EP09_02-img11-mouth:
#
# 25_EP09_02-img11-eye_left:
#
# 25_EP09_02-img11-eye_right:
#
# 25_EP09_02-img11-eyebrow_left:
#
# 25_EP09_02-img11-eyebrow_right:
#
# 25_EP09_02-img11-nose_right:
#
# 25_EP09_02-img11-nose_left:
#
# 25_EP09_02-img12-mouth:
#
# 25_EP09_02-img12-eye_left:
#
# 25_EP09_02-img12-eye_right:
#
# 25_EP09_02-img12-eyebrow_left:
#
# 25_EP09_02-img12-eyebrow_right:
#
# 25_EP09_02-img12-nose_right:
#
# 25_EP09_02-img12-nose_left:
#
# 25_EP09_02-img13-mouth:
#
# 25_EP09_02-img13-eye_left:
#
# 25_EP09_02-img13-eye_right:
#
# 25_EP09_02-img13-eyebrow_left:
#
# 25_EP09_02-img13-eyebrow_right:
#
# 25_EP09_02-img13-nose_right:
#
# 25_EP09_02-img13-nose_left:
#
# 25_EP09_02-img14-mouth:
#
# 25_EP09_02-img14-eye_left:
#
# 25_EP09_02-img14-eye_right:
#
# 25_EP09_02-img14-eyebrow_left:
#
# 25_EP09_02-img14-eyebrow_right:
#
# 25_EP09_02-img14-nose_right:
#
# 25_EP09_02-img14-nose_left:
#
# 25_EP09_02-img15-mouth:
#
# 25_EP09_02-img15-eye_left:
#
# 25_EP09_02-img15-eye_right:
#
# 25_EP09_02-img15-eyebrow_left:
#
# 25_EP09_02-img15-eyebrow_right:
#
# 25_EP09_02-img15-nose_right:
#
# 25_EP09_02-img15-nose_left:
#
# 25_EP09_02-img16-mouth:
#
# 25_EP09_02-img16-eye_left:
#
# 25_EP09_02-img16-eye_right:
#
# 25_EP09_02-img16-eyebrow_left:
#
# 25_EP09_02-img16-eyebrow_right:
#
# 25_EP09_02-img16-nose_right:
#
# 25_EP09_02-img16-nose_left:
#
# 25_EP09_02-img17-mouth:
#
# 25_EP09_02-img17-eye_left:
#
# 25_EP09_02-img17-eye_right:
#
# 25_EP09_02-img17-eyebrow_left:
#
# 25_EP09_02-img17-eyebrow_right:
#
# 25_EP09_02-img17-nose_right:
#
# 25_EP09_02-img17-nose_left:
#
# 25_EP09_02-img18-mouth:
#
# 25_EP09_02-img18-eye_left:
#
# 25_EP09_02-img18-eye_right:
#
# 25_EP09_02-img18-eyebrow_left:
#
# 25_EP09_02-img18-eyebrow_right:
#
# 25_EP09_02-img18-nose_right:
#
# 25_EP09_02-img18-nose_left:
#
# 25_EP09_02-img19-mouth:
#
# 25_EP09_02-img19-eye_left:
#
# 25_EP09_02-img19-eye_right:
#
# 25_EP09_02-img19-eyebrow_left:
#
# 25_EP09_02-img19-eyebrow_right:
#
# 25_EP09_02-img19-nose_right:
#
# 25_EP09_02-img19-nose_left:
#
# 25_EP09_02-img20-mouth:
#
# 25_EP09_02-img20-eye_left:
#
# 25_EP09_02-img20-eye_right:
#
# 25_EP09_02-img20-eyebrow_left:
#
# 25_EP09_02-img20-eyebrow_right:
#
# 25_EP09_02-img20-nose_right:
#
# 25_EP09_02-img20-nose_left:
#
# 25_EP09_02-img21-mouth:
#
# 25_EP09_02-img21-eye_left:
#
# 25_EP09_02-img21-eye_right:
#
# 25_EP09_02-img21-eyebrow_left:
#
# 25_EP09_02-img21-eyebrow_right:
#
# 25_EP09_02-img21-nose_right:
#
# 25_EP09_02-img21-nose_left:
#
# 25_EP09_02-img22-mouth:
#
# 25_EP09_02-img22-eye_left:
#
# 25_EP09_02-img22-eye_right:
#
# 25_EP09_02-img22-eyebrow_left:
#
# 25_EP09_02-img22-eyebrow_right:
#
# 25_EP09_02-img22-nose_right:
#
# 25_EP09_02-img22-nose_left:
#
# 25_EP09_02-img23-mouth:
#
# 25_EP09_02-img23-eye_left:
#
# 25_EP09_02-img23-eye_right:
#
# 25_EP09_02-img23-eyebrow_left:
#
# 25_EP09_02-img23-eyebrow_right:
#
# 25_EP09_02-img23-nose_right:
#
# 25_EP09_02-img23-nose_left:
#
# 25_EP09_02-img24-mouth:
#
# 25_EP09_02-img24-eye_left:
#
# 25_EP09_02-img24-eye_right:
#
# 25_EP09_02-img24-eyebrow_left:
#
# 25_EP09_02-img24-eyebrow_right:
#
# 25_EP09_02-img24-nose_right:
#
# 25_EP09_02-img24-nose_left:
#
# 25_EP09_02-img25-mouth:
#
# 25_EP09_02-img25-eye_left:
#
# 25_EP09_02-img25-eye_right:
#
# 25_EP09_02-img25-eyebrow_left:
#
# 25_EP09_02-img25-eyebrow_right:
#
# 25_EP09_02-img25-nose_right:
#
# 25_EP09_02-img25-nose_left:
#
# 25_EP09_02-img26-mouth:
#
# 25_EP09_02-img26-eye_left:
#
# 25_EP09_02-img26-eye_right:
#
# 25_EP09_02-img26-eyebrow_left:
#
# 25_EP09_02-img26-eyebrow_right:
#
# 25_EP09_02-img26-nose_right:
#
# 25_EP09_02-img26-nose_left:
#
# 25_EP09_02-img27-mouth:
#
# 25_EP09_02-img27-eye_left:
#
# 25_EP09_02-img27-eye_right:
#
# 25_EP09_02-img27-eyebrow_left:
#
# 25_EP09_02-img27-eyebrow_right:
#
# 25_EP09_02-img27-nose_right:
#
# 25_EP09_02-img27-nose_left:
#
# 25_EP09_02-img28-mouth:
#
# 25_EP09_02-img28-eye_left:
#
# 25_EP09_02-img28-eye_right:
#
# 25_EP09_02-img28-eyebrow_left:
#
# 25_EP09_02-img28-eyebrow_right:
#
# 25_EP09_02-img28-nose_right:
#
# 25_EP09_02-img28-nose_left:
#
# 25_EP09_02-img29-mouth:
#
# 25_EP09_02-img29-eye_left:
#
# 25_EP09_02-img29-eye_right:
#
# 25_EP09_02-img29-eyebrow_left:
#
# 25_EP09_02-img29-eyebrow_right:
#
# 25_EP09_02-img29-nose_right:
#
# 25_EP09_02-img29-nose_left:
#
# 25_EP09_02-img30-mouth:
#
# 25_EP09_02-img30-eye_left:
#
# 25_EP09_02-img30-eye_right:
#
# 25_EP09_02-img30-eyebrow_left:
#
# 25_EP09_02-img30-eyebrow_right:
#
# 25_EP09_02-img30-nose_right:
#
# 25_EP09_02-img30-nose_left:
#
# 25_EP09_02-img31-mouth:
#
# 25_EP09_02-img31-eye_left:
#
# 25_EP09_02-img31-eye_right:
#
# 25_EP09_02-img31-eyebrow_left:
#
# 25_EP09_02-img31-eyebrow_right:
#
# 25_EP09_02-img31-nose_right:
#
# 25_EP09_02-img31-nose_left:
#
# 25_EP09_02-img32-mouth:
#
# 25_EP09_02-img32-eye_left:
#
# 25_EP09_02-img32-eye_right:
#
# 25_EP09_02-img32-eyebrow_left:
#
# 25_EP09_02-img32-eyebrow_right:
#
# 25_EP09_02-img32-nose_right:
#
# 25_EP09_02-img32-nose_left:
#
# 25_EP09_02-img33-mouth:
#
# 25_EP09_02-img33-eye_left:
#
# 25_EP09_02-img33-eye_right:
#
# 25_EP09_02-img33-eyebrow_left:
#
# 25_EP09_02-img33-eyebrow_right:
#
# 25_EP09_02-img33-nose_right:
#
# 25_EP09_02-img33-nose_left:
#
# 25_EP09_02-img34-mouth:
#
# 25_EP09_02-img34-eye_left:
#
# 25_EP09_02-img34-eye_right:
#
# 25_EP09_02-img34-eyebrow_left:
#
# 25_EP09_02-img34-eyebrow_right:
#
# 25_EP09_02-img34-nose_right:
#
# 25_EP09_02-img34-nose_left:
#
# 25_EP09_02-img35-mouth:
#
# 25_EP09_02-img35-eye_left:
#
# 25_EP09_02-img35-eye_right:
#
# 25_EP09_02-img35-eyebrow_left:
#
# 25_EP09_02-img35-eyebrow_right:
#
# 25_EP09_02-img35-nose_right:
#
# 25_EP09_02-img35-nose_left:
#
# 25_EP09_02-img36-mouth:
#
# 25_EP09_02-img36-eye_left:
#
# 25_EP09_02-img36-eye_right:
#
# 25_EP09_02-img36-eyebrow_left:
#
# 25_EP09_02-img36-eyebrow_right:
#
# 25_EP09_02-img36-nose_right:
#
# 25_EP09_02-img36-nose_left:
#
# 25_EP09_02-img37-mouth:
#
# 25_EP09_02-img37-eye_left:
#
# 25_EP09_02-img37-eye_right:
#
# 25_EP09_02-img37-eyebrow_left:
#
# 25_EP09_02-img37-eyebrow_right:
#
# 25_EP09_02-img37-nose_right:
#
# 25_EP09_02-img37-nose_left:
#
# 25_EP09_02-img38-mouth:
#
# 25_EP09_02-img38-eye_left:
#
# 25_EP09_02-img38-eye_right:
#
# 25_EP09_02-img38-eyebrow_left:
#
# 25_EP09_02-img38-eyebrow_right:
#
# 25_EP09_02-img38-nose_right:
#
# 25_EP09_02-img38-nose_left:
#
# 25_EP09_02-img39-mouth:
#
# 25_EP09_02-img39-eye_left:
#
# 25_EP09_02-img39-eye_right:
#
# 25_EP09_02-img39-eyebrow_left:
#
# 25_EP09_02-img39-eyebrow_right:
#
# 25_EP09_02-img39-nose_right:
#
# 25_EP09_02-img39-nose_left:
#
# 25_EP09_02-img40-mouth:
#
# 25_EP09_02-img40-eye_left:
#
# 25_EP09_02-img40-eye_right:
#
# 25_EP09_02-img40-eyebrow_left:
#
# 25_EP09_02-img40-eyebrow_right:
#
# 25_EP09_02-img40-nose_right:
#
# 25_EP09_02-img40-nose_left:
#
# 25_EP09_02-img41-mouth:
#
# 25_EP09_02-img41-eye_left:
#
# 25_EP09_02-img41-eye_right:
#
# 25_EP09_02-img41-eyebrow_left:
#
# 25_EP09_02-img41-eyebrow_right:
#
# 25_EP09_02-img41-nose_right:
#
# 25_EP09_02-img41-nose_left:
#
# 25_EP09_02-img42-mouth:
#
# 25_EP09_02-img42-eye_left:
#
# 25_EP09_02-img42-eye_right:
#
# 25_EP09_02-img42-eyebrow_left:
#
# 25_EP09_02-img42-eyebrow_right:
#
# 25_EP09_02-img42-nose_right:
#
# 25_EP09_02-img42-nose_left:
#
# 25_EP09_02-img43-mouth:
#
# 25_EP09_02-img43-eye_left:
#
# 25_EP09_02-img43-eye_right:
#
# 25_EP09_02-img43-eyebrow_left:
#
# 25_EP09_02-img43-eyebrow_right:
#
# 25_EP09_02-img43-nose_right:
#
# 25_EP09_02-img43-nose_left:
#
# 25_EP09_02-img44-mouth:
#
# 25_EP09_02-img44-eye_left:
#
# 25_EP09_02-img44-eye_right:
#
# 25_EP09_02-img44-eyebrow_left:
#
# 25_EP09_02-img44-eyebrow_right:
#
# 25_EP09_02-img44-nose_right:
#
# 25_EP09_02-img44-nose_left:
#
# 25_EP09_02-img45-mouth:
#
# 25_EP09_02-img45-eye_left:
#
# 25_EP09_02-img45-eye_right:
#
# 25_EP09_02-img45-eyebrow_left:
#
# 25_EP09_02-img45-eyebrow_right:
#
# 25_EP09_02-img45-nose_right:
#
# 25_EP09_02-img45-nose_left:
#
# 25_EP09_02-img46-mouth:
#
# 25_EP09_02-img46-eye_left:
#
# 25_EP09_02-img46-eye_right:
#
# 25_EP09_02-img46-eyebrow_left:
#
# 25_EP09_02-img46-eyebrow_right:
#
# 25_EP09_02-img46-nose_right:
#
# 25_EP09_02-img46-nose_left:
#
# 25_EP09_02-img47-mouth:
#
# 25_EP09_02-img47-eye_left:
#
# 25_EP09_02-img47-eye_right:
#
# 25_EP09_02-img47-eyebrow_left:
#
# 25_EP09_02-img47-eyebrow_right:
#
# 25_EP09_02-img47-nose_right:
#
# 25_EP09_02-img47-nose_left:
#
# 25_EP09_02-img48-mouth:
#
# 25_EP09_02-img48-eye_left:
#
# 25_EP09_02-img48-eye_right:
#
# 25_EP09_02-img48-eyebrow_left:
#
# 25_EP09_02-img48-eyebrow_right:
#
# 25_EP09_02-img48-nose_right:
#
# 25_EP09_02-img48-nose_left:
#
# 25_EP09_02-img49-mouth:
#
# 25_EP09_02-img49-eye_left:
#
# 25_EP09_02-img49-eye_right:
#
# 25_EP09_02-img49-eyebrow_left:
#
# 25_EP09_02-img49-eyebrow_right:
#
# 25_EP09_02-img49-nose_right:
#
# 25_EP09_02-img49-nose_left:
#
# 25_EP09_02-img50-mouth:
#
# 25_EP09_02-img50-eye_left:
#
# 25_EP09_02-img50-eye_right:
#
# 25_EP09_02-img50-eyebrow_left:
#
# 25_EP09_02-img50-eyebrow_right:
#
# 25_EP09_02-img50-nose_right:
#
# 25_EP09_02-img50-nose_left:
#
# 25_EP09_02-img51-mouth:
#
# 25_EP09_02-img51-eye_left:
#
# 25_EP09_02-img51-eye_right:
#
# 25_EP09_02-img51-eyebrow_left:
#
# 25_EP09_02-img51-eyebrow_right:
#
# 25_EP09_02-img51-nose_right:
#
# 25_EP09_02-img51-nose_left:
#
# 25_EP09_02-img52-mouth:
#
# 25_EP09_02-img52-eye_left:
#
# 25_EP09_02-img52-eye_right:
#
# 25_EP09_02-img52-eyebrow_left:
#
# 25_EP09_02-img52-eyebrow_right:
#
# 25_EP09_02-img52-nose_right:
#
# 25_EP09_02-img52-nose_left:
#
# 25_EP09_02-img53-mouth:
#
# 25_EP09_02-img53-eye_left:
#
# 25_EP09_02-img53-eye_right:
#
# 25_EP09_02-img53-eyebrow_left:
#
# 25_EP09_02-img53-eyebrow_right:
#
# 25_EP09_02-img53-nose_right:
#
# 25_EP09_02-img53-nose_left:
#
# 25_EP09_02-img54-mouth:
#
# 25_EP09_02-img54-eye_left:
#
# 25_EP09_02-img54-eye_right:
#
# 25_EP09_02-img54-eyebrow_left:
#
# 25_EP09_02-img54-eyebrow_right:
#
# 25_EP09_02-img54-nose_right:
#
# 25_EP09_02-img54-nose_left:
#
# 25_EP09_02-img55-mouth:
#
# 25_EP09_02-img55-eye_left:
#
# 25_EP09_02-img55-eye_right:
#
# 25_EP09_02-img55-eyebrow_left:
#
# 25_EP09_02-img55-eyebrow_right:
#
# 25_EP09_02-img55-nose_right:
#
# 25_EP09_02-img55-nose_left:
#
# 25_EP09_02-img56-mouth:
#
# 25_EP09_02-img56-eye_left:
#
# 25_EP09_02-img56-eye_right:
#
# 25_EP09_02-img56-eyebrow_left:
#
# 25_EP09_02-img56-eyebrow_right:
#
# 25_EP09_02-img56-nose_right:
#
# 25_EP09_02-img56-nose_left:
#
# 25_EP09_02-img57-mouth:
#
# 25_EP09_02-img57-eye_left:
#
# 25_EP09_02-img57-eye_right:
#
# 25_EP09_02-img57-eyebrow_left:
#
# 25_EP09_02-img57-eyebrow_right:
#
# 25_EP09_02-img57-nose_right:
#
# 25_EP09_02-img57-nose_left:
#
# 25_EP09_02-img58-mouth:
#
# 25_EP09_02-img58-eye_left:
#
# 25_EP09_02-img58-eye_right:
#
# 25_EP09_02-img58-eyebrow_left:
#
# 25_EP09_02-img58-eyebrow_right:
#
# 25_EP09_02-img58-nose_right:
#
# 25_EP09_02-img58-nose_left:
#
# 25_EP09_02-img59-mouth:
#
# 25_EP09_02-img59-eye_left:
#
# 25_EP09_02-img59-eye_right:
#
# 25_EP09_02-img59-eyebrow_left:
#
# 25_EP09_02-img59-eyebrow_right:
#
# 25_EP09_02-img59-nose_right:
#
# 25_EP09_02-img59-nose_left:
#
# 25_EP09_02-img60-mouth:
#
# 25_EP09_02-img60-eye_left:
#
# 25_EP09_02-img60-eye_right:
#
# 25_EP09_02-img60-eyebrow_left:
#
# 25_EP09_02-img60-eyebrow_right:
#
# 25_EP09_02-img60-nose_right:
#
# 25_EP09_02-img60-nose_left:
#
# 25_EP09_02-img61-mouth:
#
# 25_EP09_02-img61-eye_left:
#
# 25_EP09_02-img61-eye_right:
#
# 25_EP09_02-img61-eyebrow_left:
#
# 25_EP09_02-img61-eyebrow_right:
#
# 25_EP09_02-img61-nose_right:
#
# 25_EP09_02-img61-nose_left:
#
# 25_EP09_02-img62-mouth:
#
# 25_EP09_02-img62-eye_left:
#
# 25_EP09_02-img62-eye_right:
#
# 25_EP09_02-img62-eyebrow_left:
#
# 25_EP09_02-img62-eyebrow_right:
#
# 25_EP09_02-img62-nose_right:
#
# 25_EP09_02-img62-nose_left:
#
# 25_EP09_02-img63-mouth:
#
# 25_EP09_02-img63-eye_left:
#
# 25_EP09_02-img63-eye_right:
#
# 25_EP09_02-img63-eyebrow_left:
#
# 25_EP09_02-img63-eyebrow_right:
#
# 25_EP09_02-img63-nose_right:
#
# 25_EP09_02-img63-nose_left:
#
# 25_EP09_02-img64-mouth:
#
# 25_EP09_02-img64-eye_left:
#
# 25_EP09_02-img64-eye_right:
#
# 25_EP09_02-img64-eyebrow_left:
#
# 25_EP09_02-img64-eyebrow_right:
#
# 25_EP09_02-img64-nose_right:
#
# 25_EP09_02-img64-nose_left:
#
# 25_EP09_02-img65-mouth:
#
# 25_EP09_02-img65-eye_left:
#
# 25_EP09_02-img65-eye_right:
#
# 25_EP09_02-img65-eyebrow_left:
#
# 25_EP09_02-img65-eyebrow_right:
#
# 25_EP09_02-img65-nose_right:
#
# 25_EP09_02-img65-nose_left:
#
# 25_EP09_02-img66-mouth:
#
# 25_EP09_02-img66-eye_left:
#
# 25_EP09_02-img66-eye_right:
#
# 25_EP09_02-img66-eyebrow_left:
#
# 25_EP09_02-img66-eyebrow_right:
#
# 25_EP09_02-img66-nose_right:
#
# 25_EP09_02-img66-nose_left:
#
# 25_EP09_02-img67-mouth:
#
# 25_EP09_02-img67-eye_left:
#
# 25_EP09_02-img67-eye_right:
#
# 25_EP09_02-img67-eyebrow_left:
#
# 25_EP09_02-img67-eyebrow_right:
#
# 25_EP09_02-img67-nose_right:
#
# 25_EP09_02-img67-nose_left:
#
# 25_EP09_02-img68-mouth:
#
# 25_EP09_02-img68-eye_left:
#
# 25_EP09_02-img68-eye_right:
#
# 25_EP09_02-img68-eyebrow_left:
#
# 25_EP09_02-img68-eyebrow_right:
#
# 25_EP09_02-img68-nose_right:
#
# 25_EP09_02-img68-nose_left:
#
# 25_EP09_02-img69-mouth:
#
# 25_EP09_02-img69-eye_left:
#
# 25_EP09_02-img69-eye_right:
#
# 25_EP09_02-img69-eyebrow_left:
#
# 25_EP09_02-img69-eyebrow_right:
#
# 25_EP09_02-img69-nose_right:
#
# 25_EP09_02-img69-nose_left:
#
# 25_EP09_02-img70-mouth:
#
# 25_EP09_02-img70-eye_left:
#
# 25_EP09_02-img70-eye_right:
#
# 25_EP09_02-img70-eyebrow_left:
#
# 25_EP09_02-img70-eyebrow_right:
#
# 25_EP09_02-img70-nose_right:
#
# 25_EP09_02-img70-nose_left:
#
# 25_EP09_02-img71-mouth:
#
# 25_EP09_02-img71-eye_left:
#
# 25_EP09_02-img71-eye_right:
#
# 25_EP09_02-img71-eyebrow_left:
#
# 25_EP09_02-img71-eyebrow_right:
#
# 25_EP09_02-img71-nose_right:
#
# 25_EP09_02-img71-nose_left:
#
# 25_EP09_02-img72-mouth:
#
# 25_EP09_02-img72-eye_left:
#
# 25_EP09_02-img72-eye_right:
#
# 25_EP09_02-img72-eyebrow_left:
#
# 25_EP09_02-img72-eyebrow_right:
#
# 25_EP09_02-img72-nose_right:
#
# 25_EP09_02-img72-nose_left:
#
# 25_EP09_02-img73-mouth:
#
# 25_EP09_02-img73-eye_left:
#
# 25_EP09_02-img73-eye_right:
#
# 25_EP09_02-img73-eyebrow_left:
#
# 25_EP09_02-img73-eyebrow_right:
#
# 25_EP09_02-img73-nose_right:
#
# 25_EP09_02-img73-nose_left:
#
# 25_EP09_02-img74-mouth:
#
# 25_EP09_02-img74-eye_left:
#
# 25_EP09_02-img74-eye_right:
#
# 25_EP09_02-img74-eyebrow_left:
#
# 25_EP09_02-img74-eyebrow_right:
#
# 25_EP09_02-img74-nose_right:
#
# 25_EP09_02-img74-nose_left:
#
# 25_EP09_02-img75-mouth:
#
# 25_EP09_02-img75-eye_left:
#
# 25_EP09_02-img75-eye_right:
#
# 25_EP09_02-img75-eyebrow_left:
#
# 25_EP09_02-img75-eyebrow_right:
#
# 25_EP09_02-img75-nose_right:
#
# 25_EP09_02-img75-nose_left:
#
# 25_EP09_02-img76-mouth:
#
# 25_EP09_02-img76-eye_left:
#
# 25_EP09_02-img76-eye_right:
#
# 25_EP09_02-img76-eyebrow_left:
#
# 25_EP09_02-img76-eyebrow_right:
#
# 25_EP09_02-img76-nose_right:
#
# 25_EP09_02-img76-nose_left:
#
# 25_EP09_02-img77-mouth:
#
# 25_EP09_02-img77-eye_left:
#
# 25_EP09_02-img77-eye_right:
#
# 25_EP09_02-img77-eyebrow_left:
#
# 25_EP09_02-img77-eyebrow_right:
#
# 25_EP09_02-img77-nose_right:
#
# 25_EP09_02-img77-nose_left:
#
# 25_EP09_02-img78-mouth:
#
# 25_EP09_02-img78-eye_left:
#
# 25_EP09_02-img78-eye_right:
#
# 25_EP09_02-img78-eyebrow_left:
#
# 25_EP09_02-img78-eyebrow_right:
#
# 25_EP09_02-img78-nose_right:
#
# 25_EP09_02-img78-nose_left:
#
# 25_EP09_02-img79-mouth:
#
# 25_EP09_02-img79-eye_left:
#
# 25_EP09_02-img79-eye_right:
#
# 25_EP09_02-img79-eyebrow_left:
#
# 25_EP09_02-img79-eyebrow_right:
#
# 25_EP09_02-img79-nose_right:
#
# 25_EP09_02-img79-nose_left:
#
# 25_EP09_02-img80-mouth:
#
# 25_EP09_02-img80-eye_left:
#
# 25_EP09_02-img80-eye_right:
#
# 25_EP09_02-img80-eyebrow_left:
#
# 25_EP09_02-img80-eyebrow_right:
#
# 25_EP09_02-img80-nose_right:
#
# 25_EP09_02-img80-nose_left:
#
# 25_EP09_02-img81-mouth:
#
# 25_EP09_02-img81-eye_left:
#
# 25_EP09_02-img81-eye_right:
#
# 25_EP09_02-img81-eyebrow_left:
#
# 25_EP09_02-img81-eyebrow_right:
#
# 25_EP09_02-img81-nose_right:
#
# 25_EP09_02-img81-nose_left:
#
# 25_EP09_02-img82-mouth:
#
# 25_EP09_02-img82-eye_left:
#
# 25_EP09_02-img82-eye_right:
#
# 25_EP09_02-img82-eyebrow_left:
#
# 25_EP09_02-img82-eyebrow_right:
#
# 25_EP09_02-img82-nose_right:
#
# 25_EP09_02-img82-nose_left:
#
# 25_EP09_02-img83-mouth:
#
# 25_EP09_02-img83-eye_left:
#
# 25_EP09_02-img83-eye_right:
#
# 25_EP09_02-img83-eyebrow_left:
#
# 25_EP09_02-img83-eyebrow_right:
#
# 25_EP09_02-img83-nose_right:
#
# 25_EP09_02-img83-nose_left:
#
# 25_EP09_02-img84-mouth:
#
# 25_EP09_02-img84-eye_left:
#
# 25_EP09_02-img84-eye_right:
#
# 25_EP09_02-img84-eyebrow_left:
#
# 25_EP09_02-img84-eyebrow_right:
#
# 25_EP09_02-img84-nose_right:
#
# 25_EP09_02-img84-nose_left:
#
# 25_EP09_02-img85-mouth:
#
# 25_EP09_02-img85-eye_left:
#
# 25_EP09_02-img85-eye_right:
#
# 25_EP09_02-img85-eyebrow_left:
#
# 25_EP09_02-img85-eyebrow_right:
#
# 25_EP09_02-img85-nose_right:
#
# 25_EP09_02-img85-nose_left:
#
# 25_EP09_02-img86-mouth:
#
# 25_EP09_02-img86-eye_left:
#
# 25_EP09_02-img86-eye_right:
#
# 25_EP09_02-img86-eyebrow_left:
#
# 25_EP09_02-img86-eyebrow_right:
#
# 25_EP09_02-img86-nose_right:
#
# 25_EP09_02-img86-nose_left:
#
# 25_EP09_02-img87-mouth:
#
# 25_EP09_02-img87-eye_left:
#
# 25_EP09_02-img87-eye_right:
#
# 25_EP09_02-img87-eyebrow_left:
#
# 25_EP09_02-img87-eyebrow_right:
#
# 25_EP09_02-img87-nose_right:
#
# 25_EP09_02-img87-nose_left:
#
# 25_EP09_02-img88-mouth:
#
# 25_EP09_02-img88-eye_left:
#
# 25_EP09_02-img88-eye_right:
#
# 25_EP09_02-img88-eyebrow_left:
#
# 25_EP09_02-img88-eyebrow_right:
#
# 25_EP09_02-img88-nose_right:
#
# 25_EP09_02-img88-nose_left:
#
# 25_EP09_02-img89-mouth:
#
# 25_EP09_02-img89-eye_left:
#
# 25_EP09_02-img89-eye_right:
#
# 25_EP09_02-img89-eyebrow_left:
#
# 25_EP09_02-img89-eyebrow_right:
#
# 25_EP09_02-img89-nose_right:
#
# 25_EP09_02-img89-nose_left:
#
# 25_EP09_02-img90-mouth:
#
# 25_EP09_02-img90-eye_left:
#
# 25_EP09_02-img90-eye_right:
#
# 25_EP09_02-img90-eyebrow_left:
#
# 25_EP09_02-img90-eyebrow_right:
#
# 25_EP09_02-img90-nose_right:
#
# 25_EP09_02-img90-nose_left:
#
# 25_EP09_02-img91-mouth:
#
# 25_EP09_02-img91-eye_left:
#
# 25_EP09_02-img91-eye_right:
#
# 25_EP09_02-img91-eyebrow_left:
#
# 25_EP09_02-img91-eyebrow_right:
#
# 25_EP09_02-img91-nose_right:
#
# 25_EP09_02-img91-nose_left:
#
# 25_EP09_02-img92-mouth:
#
# 25_EP09_02-img92-eye_left:
#
# 25_EP09_02-img92-eye_right:
#
# 25_EP09_02-img92-eyebrow_left:
#
# 25_EP09_02-img92-eyebrow_right:
#
# 25_EP09_02-img92-nose_right:
#
# 25_EP09_02-img92-nose_left:
#
# 25_EP09_02-img93-mouth:
#
# 25_EP09_02-img93-eye_left:
#
# 25_EP09_02-img93-eye_right:
#
# 25_EP09_02-img93-eyebrow_left:
#
# 25_EP09_02-img93-eyebrow_right:
#
# 25_EP09_02-img93-nose_right:
#
# 25_EP09_02-img93-nose_left:
#
# 25_EP09_02-img94-mouth:
#
# 25_EP09_02-img94-eye_left:
#
# 25_EP09_02-img94-eye_right:
#
# 25_EP09_02-img94-eyebrow_left:
#
# 25_EP09_02-img94-eyebrow_right:
#
# 25_EP09_02-img94-nose_right:
#
# 25_EP09_02-img94-nose_left:
#
# 25_EP09_02-img95-mouth:
#
# 25_EP09_02-img95-eye_left:
#
# 25_EP09_02-img95-eye_right:
#
# 25_EP09_02-img95-eyebrow_left:
#
# 25_EP09_02-img95-eyebrow_right:
#
# 25_EP09_02-img95-nose_right:
#
# 25_EP09_02-img95-nose_left:
#
# 25_EP09_02-img96-mouth:
#
# 25_EP09_02-img96-eye_left:
#
# 25_EP09_02-img96-eye_right:
#
# 25_EP09_02-img96-eyebrow_left:
#
# 25_EP09_02-img96-eyebrow_right:
#
# 25_EP09_02-img96-nose_right:
#
# 25_EP09_02-img96-nose_left:
#
# 25_EP09_02-img97-mouth:
#
# 25_EP09_02-img97-eye_left:
#
# 25_EP09_02-img97-eye_right:
#
# 25_EP09_02-img97-eyebrow_left:
#
# 25_EP09_02-img97-eyebrow_right:
#
# 25_EP09_02-img97-nose_right:
#
# 25_EP09_02-img97-nose_left:
#
# 25_EP09_02-img98-mouth:
#
# 25_EP09_02-img98-eye_left:
#
# 25_EP09_02-img98-eye_right:
#
# 25_EP09_02-img98-eyebrow_left:
#
# 25_EP09_02-img98-eyebrow_right:
#
# 25_EP09_02-img98-nose_right:
#
# 25_EP09_02-img98-nose_left:
#
# 25_EP09_02-img99-mouth:
#
# 25_EP09_02-img99-eye_left:
#
# 25_EP09_02-img99-eye_right:
#
# 25_EP09_02-img99-eyebrow_left:
#
# 25_EP09_02-img99-eyebrow_right:
#
# 25_EP09_02-img99-nose_right:
#
# 25_EP09_02-img99-nose_left:
#
# 25_EP09_02-img100-mouth:
#
# 25_EP09_02-img100-eye_left:
#
# 25_EP09_02-img100-eye_right:
#
# 25_EP09_02-img100-eyebrow_left:
#
# 25_EP09_02-img100-eyebrow_right:
#
# 25_EP09_02-img100-nose_right:
#
# 25_EP09_02-img100-nose_left:
#
# 25_EP09_02-img101-mouth:
#
# 25_EP09_02-img101-eye_left:
#
# 25_EP09_02-img101-eye_right:
#
# 25_EP09_02-img101-eyebrow_left:
#
# 25_EP09_02-img101-eyebrow_right:
#
# 25_EP09_02-img101-nose_right:
#
# 25_EP09_02-img101-nose_left:
#
# 25_EP09_02-img102-mouth:
#
# 25_EP09_02-img102-eye_left:
#
# 25_EP09_02-img102-eye_right:
#
# 25_EP09_02-img102-eyebrow_left:
#
# 25_EP09_02-img102-eyebrow_right:
#
# 25_EP09_02-img102-nose_right:
#
# 25_EP09_02-img102-nose_left:
#
# 25_EP09_02-img103-mouth:
#
# 25_EP09_02-img103-eye_left:
#
# 25_EP09_02-img103-eye_right:
#
# 25_EP09_02-img103-eyebrow_left:
#
# 25_EP09_02-img103-eyebrow_right:
#
# 25_EP09_02-img103-nose_right:
#
# 25_EP09_02-img103-nose_left:
#
# 25_EP09_02-img104-mouth:
#
# 25_EP09_02-img104-eye_left:
#
# 25_EP09_02-img104-eye_right:
#
# 25_EP09_02-img104-eyebrow_left:
#
# 25_EP09_02-img104-eyebrow_right:
#
# 25_EP09_02-img104-nose_right:
#
# 25_EP09_02-img104-nose_left:
#
# 25_EP09_02-img105-mouth:
#
# 25_EP09_02-img105-eye_left:
#
# 25_EP09_02-img105-eye_right:
#
# 25_EP09_02-img105-eyebrow_left:
#
# 25_EP09_02-img105-eyebrow_right:
#
# 25_EP09_02-img105-nose_right:
#
# 25_EP09_02-img105-nose_left:
#
# 25_EP09_02-img106-mouth:
#
# 25_EP09_02-img106-eye_left:
#
# 25_EP09_02-img106-eye_right:
#
# 25_EP09_02-img106-eyebrow_left:
#
# 25_EP09_02-img106-eyebrow_right:
#
# 25_EP09_02-img106-nose_right:
#
# 25_EP09_02-img106-nose_left:
#
# 25_EP09_02-img107-mouth:
#
# 25_EP09_02-img107-eye_left:
#
# 25_EP09_02-img107-eye_right:
#
# 25_EP09_02-img107-eyebrow_left:
#
# 25_EP09_02-img107-eyebrow_right:
#
# 25_EP09_02-img107-nose_right:
#
# 25_EP09_02-img107-nose_left:
#
# 25_EP09_02-img108-mouth:
#
# 25_EP09_02-img108-eye_left:
#
# 25_EP09_02-img108-eye_right:
#
# 25_EP09_02-img108-eyebrow_left:
#
# 25_EP09_02-img108-eyebrow_right:
#
# 25_EP09_02-img108-nose_right:
#
# 25_EP09_02-img108-nose_left:
#
# 25_EP09_02-img109-mouth:
#
# 25_EP09_02-img109-eye_left:
#
# 25_EP09_02-img109-eye_right:
#
# 25_EP09_02-img109-eyebrow_left:
#
# 25_EP09_02-img109-eyebrow_right:
#
# 25_EP09_02-img109-nose_right:
#
# 25_EP09_02-img109-nose_left:
#
# 25_EP09_02-img110-mouth:
#
# 25_EP09_02-img110-eye_left:
#
# 25_EP09_02-img110-eye_right:
#
# 25_EP09_02-img110-eyebrow_left:
#
# 25_EP09_02-img110-eyebrow_right:
#
# 25_EP09_02-img110-nose_right:
#
# 25_EP09_02-img110-nose_left:
#
# 25_EP09_02-img111-mouth:
#
# 25_EP09_02-img111-eye_left:
#
# 25_EP09_02-img111-eye_right:
#
# 25_EP09_02-img111-eyebrow_left:
#
# 25_EP09_02-img111-eyebrow_right:
#
# 25_EP09_02-img111-nose_right:
#
# 25_EP09_02-img111-nose_left:
#
# 25_EP09_02-img112-mouth:
#
# 25_EP09_02-img112-eye_left:
#
# 25_EP09_02-img112-eye_right:
#
# 25_EP09_02-img112-eyebrow_left:
#
# 25_EP09_02-img112-eyebrow_right:
#
# 25_EP09_02-img112-nose_right:
#
# 25_EP09_02-img112-nose_left:
#
# 25_EP09_02-img113-mouth:
#
# 25_EP09_02-img113-eye_left:
#
# 25_EP09_02-img113-eye_right:
#
# 25_EP09_02-img113-eyebrow_left:
#
# 25_EP09_02-img113-eyebrow_right:
#
# 25_EP09_02-img113-nose_right:
#
# 25_EP09_02-img113-nose_left:
#
# 25_EP09_02-img114-mouth:
#
# 25_EP09_02-img114-eye_left:
#
# 25_EP09_02-img114-eye_right:
#
# 25_EP09_02-img114-eyebrow_left:
#
# 25_EP09_02-img114-eyebrow_right:
#
# 25_EP09_02-img114-nose_right:
#
# 25_EP09_02-img114-nose_left:
#
# 25_EP09_02-img115-mouth:
#
# 25_EP09_02-img115-eye_left:
#
# 25_EP09_02-img115-eye_right:
#
# 25_EP09_02-img115-eyebrow_left:
#
# 25_EP09_02-img115-eyebrow_right:
#
# 25_EP09_02-img115-nose_right:
#
# 25_EP09_02-img115-nose_left:
#
# 25_EP09_02-img116-mouth:
#
# 25_EP09_02-img116-eye_left:
#
# 25_EP09_02-img116-eye_right:
#
# 25_EP09_02-img116-eyebrow_left:
#
# 25_EP09_02-img116-eyebrow_right:
#
# 25_EP09_02-img116-nose_right:
#
# 25_EP09_02-img116-nose_left:
#
# 25_EP09_02-img117-mouth:
#
# 25_EP09_02-img117-eye_left:
#
# 25_EP09_02-img117-eye_right:
#
# 25_EP09_02-img117-eyebrow_left:
#
# 25_EP09_02-img117-eyebrow_right:
#
# 25_EP09_02-img117-nose_right:
#
# 25_EP09_02-img117-nose_left:
#
# 25_EP09_02-img118-mouth:
#
# 25_EP09_02-img118-eye_left:
#
# 25_EP09_02-img118-eye_right:
#
# 25_EP09_02-img118-eyebrow_left:
#
# 25_EP09_02-img118-eyebrow_right:
#
# 25_EP09_02-img118-nose_right:
#
# 25_EP09_02-img118-nose_left:
#
# 25_EP09_02-img119-mouth:
#
# 25_EP09_02-img119-eye_left:
#
# 25_EP09_02-img119-eye_right:
#
# 25_EP09_02-img119-eyebrow_left:
#
# 25_EP09_02-img119-eyebrow_right:
#
# 25_EP09_02-img119-nose_right:
#
# 25_EP09_02-img119-nose_left:
#
# 25_EP09_02-img120-mouth:
#
# 25_EP09_02-img120-eye_left:
#
# 25_EP09_02-img120-eye_right:
#
# 25_EP09_02-img120-eyebrow_left:
#
# 25_EP09_02-img120-eyebrow_right:
#
# 25_EP09_02-img120-nose_right:
#
# 25_EP09_02-img120-nose_left:
#
# 25_EP09_02-img121-mouth:
#
# 25_EP09_02-img121-eye_left:
#
# 25_EP09_02-img121-eye_right:
#
# 25_EP09_02-img121-eyebrow_left:
#
# 25_EP09_02-img121-eyebrow_right:
#
# 25_EP09_02-img121-nose_right:
#
# 25_EP09_02-img121-nose_left:
#
# 25_EP09_02-img122-mouth:
#
# 25_EP09_02-img122-eye_left:
#
# 25_EP09_02-img122-eye_right:
#
# 25_EP09_02-img122-eyebrow_left:
#
# 25_EP09_02-img122-eyebrow_right:
#
# 25_EP09_02-img122-nose_right:
#
# 25_EP09_02-img122-nose_left:
#
# 25_EP09_02-img123-mouth:
#
# 25_EP09_02-img123-eye_left:
#
# 25_EP09_02-img123-eye_right:
#
# 25_EP09_02-img123-eyebrow_left:
#
# 25_EP09_02-img123-eyebrow_right:
#
# 25_EP09_02-img123-nose_right:
#
# 25_EP09_02-img123-nose_left:
#
# 25_EP09_02-img124-mouth:
#
# 25_EP09_02-img124-eye_left:
#
# 25_EP09_02-img124-eye_right:
#
# 25_EP09_02-img124-eyebrow_left:
#
# 25_EP09_02-img124-eyebrow_right:
#
# 25_EP09_02-img124-nose_right:
#
# 25_EP09_02-img124-nose_left:
#
# 25_EP09_02-img125-mouth:
#
# 25_EP09_02-img125-eye_left:
#
# 25_EP09_02-img125-eye_right:
#
# 25_EP09_02-img125-eyebrow_left:
#
# 25_EP09_02-img125-eyebrow_right:
#
# 25_EP09_02-img125-nose_right:
#
# 25_EP09_02-img125-nose_left:
#
# 25_EP09_02-img126-mouth:
#
# 25_EP09_02-img126-eye_left:
#
# 25_EP09_02-img126-eye_right:
#
# 25_EP09_02-img126-eyebrow_left:
#
# 25_EP09_02-img126-eyebrow_right:
#
# 25_EP09_02-img126-nose_right:
#
# 25_EP09_02-img126-nose_left:
#
# 25_EP09_02-img127-mouth:
#
# 25_EP09_02-img127-eye_left:
#
# 25_EP09_02-img127-eye_right:
#
# 25_EP09_02-img127-eyebrow_left:
#
# 25_EP09_02-img127-eyebrow_right:
#
# 25_EP09_02-img127-nose_right:
#
# 25_EP09_02-img127-nose_left:
#
# 25_EP09_02-img128-mouth:
#
# 25_EP09_02-img128-eye_left:
#
# 25_EP09_02-img128-eye_right:
#
# 25_EP09_02-img128-eyebrow_left:
#
# 25_EP09_02-img128-eyebrow_right:
#
# 25_EP09_02-img128-nose_right:
#
# 25_EP09_02-img128-nose_left:
#
# 25_EP09_02-img129-mouth:
#
# 25_EP09_02-img129-eye_left:
#
# 25_EP09_02-img129-eye_right:
#
# 25_EP09_02-img129-eyebrow_left:
#
# 25_EP09_02-img129-eyebrow_right:
#
# 25_EP09_02-img129-nose_right:
#
# 25_EP09_02-img129-nose_left:
#
# 25_EP09_02-img130-mouth:
#
# 25_EP09_02-img130-eye_left:
#
# 25_EP09_02-img130-eye_right:
#
# 25_EP09_02-img130-eyebrow_left:
#
# 25_EP09_02-img130-eyebrow_right:
#
# 25_EP09_02-img130-nose_right:
#
# 25_EP09_02-img130-nose_left:
#
# 25_EP09_02-img131-mouth:
#
# 25_EP09_02-img131-eye_left:
#
# 25_EP09_02-img131-eye_right:
#
# 25_EP09_02-img131-eyebrow_left:
#
# 25_EP09_02-img131-eyebrow_right:
#
# 25_EP09_02-img131-nose_right:
#
# 25_EP09_02-img131-nose_left:
#
# 25_EP09_02-img132-mouth:
#
# 25_EP09_02-img132-eye_left:
#
# 25_EP09_02-img132-eye_right:
#
# 25_EP09_02-img132-eyebrow_left:
#
# 25_EP09_02-img132-eyebrow_right:
#
# 25_EP09_02-img132-nose_right:
#
# 25_EP09_02-img132-nose_left:
#
# 25_EP09_02-img133-mouth:
#
# 25_EP09_02-img133-eye_left:
#
# 25_EP09_02-img133-eye_right:
#
# 25_EP09_02-img133-eyebrow_left:
#
# 25_EP09_02-img133-eyebrow_right:
#
# 25_EP09_02-img133-nose_right:
#
# 25_EP09_02-img133-nose_left:
#
# 25_EP09_02-img134-mouth:
#
# 25_EP09_02-img134-eye_left:
#
# 25_EP09_02-img134-eye_right:
#
# 25_EP09_02-img134-eyebrow_left:
#
# 25_EP09_02-img134-eyebrow_right:
#
# 25_EP09_02-img134-nose_right:
#
# 25_EP09_02-img134-nose_left:
#
# 25_EP09_02-img135-mouth:
#
# 25_EP09_02-img135-eye_left:
#
# 25_EP09_02-img135-eye_right:
#
# 25_EP09_02-img135-eyebrow_left:
#
# 25_EP09_02-img135-eyebrow_right:
#
# 25_EP09_02-img135-nose_right:
#
# 25_EP09_02-img135-nose_left:
#
# 25_EP09_02-img136-mouth:
#
# 25_EP09_02-img136-eye_left:
#
# 25_EP09_02-img136-eye_right:
#
# 25_EP09_02-img136-eyebrow_left:
#
# 25_EP09_02-img136-eyebrow_right:
#
# 25_EP09_02-img136-nose_right:
#
# 25_EP09_02-img136-nose_left:
#
# 25_EP09_02-img137-mouth:
#
# 25_EP09_02-img137-eye_left:
#
# 25_EP09_02-img137-eye_right:
#
# 25_EP09_02-img137-eyebrow_left:
#
# 25_EP09_02-img137-eyebrow_right:
#
# 25_EP09_02-img137-nose_right:
#
# 25_EP09_02-img137-nose_left:
#
# 25_EP09_02-img138-mouth:
#
# 25_EP09_02-img138-eye_left:
#
# 25_EP09_02-img138-eye_right:
#
# 25_EP09_02-img138-eyebrow_left:
#
# 25_EP09_02-img138-eyebrow_right:
#
# 25_EP09_02-img138-nose_right:
#
# 25_EP09_02-img138-nose_left:
#
# 25_EP09_02-img139-mouth:
#
# 25_EP09_02-img139-eye_left:
#
# 25_EP09_02-img139-eye_right:
#
# 25_EP09_02-img139-eyebrow_left:
#
# 25_EP09_02-img139-eyebrow_right:
#
# 25_EP09_02-img139-nose_right:
#
# 25_EP09_02-img139-nose_left:
#
# 25_EP09_02-img140-mouth:
#
# 25_EP09_02-img140-eye_left:
#
# 25_EP09_02-img140-eye_right:
#
# 25_EP09_02-img140-eyebrow_left:
#
# 25_EP09_02-img140-eyebrow_right:
#
# 25_EP09_02-img140-nose_right:
#
# 25_EP09_02-img140-nose_left:
#
# 25_EP09_02-img141-mouth:
#
# 25_EP09_02-img141-eye_left:
#
# 25_EP09_02-img141-eye_right:
#
# 25_EP09_02-img141-eyebrow_left:
#
# 25_EP09_02-img141-eyebrow_right:
#
# 25_EP09_02-img141-nose_right:
#
# 25_EP09_02-img141-nose_left:
#
# 25_EP09_02-img142-mouth:
#
# 25_EP09_02-img142-eye_left:
#
# 25_EP09_02-img142-eye_right:
#
# 25_EP09_02-img142-eyebrow_left:
#
# 25_EP09_02-img142-eyebrow_right:
#
# 25_EP09_02-img142-nose_right:
#
# 25_EP09_02-img142-nose_left:
#
# 25_EP09_02-img143-mouth:
#
# 25_EP09_02-img143-eye_left:
#
# 25_EP09_02-img143-eye_right:
#
# 25_EP09_02-img143-eyebrow_left:
#
# 25_EP09_02-img143-eyebrow_right:
#
# 25_EP09_02-img143-nose_right:
#
# 25_EP09_02-img143-nose_left:
#
# 25_EP09_02-img144-mouth:
#
# 25_EP09_02-img144-eye_left:
#
# 25_EP09_02-img144-eye_right:
#
# 25_EP09_02-img144-eyebrow_left:
#
# 25_EP09_02-img144-eyebrow_right:
#
# 25_EP09_02-img144-nose_right:
#
# 25_EP09_02-img144-nose_left:
#
# 25_EP09_02-img145-mouth:
#
# 25_EP09_02-img145-eye_left:
#
# 25_EP09_02-img145-eye_right:
#
# 25_EP09_02-img145-eyebrow_left:
#
# 25_EP09_02-img145-eyebrow_right:
#
# 25_EP09_02-img145-nose_right:
#
# 25_EP09_02-img145-nose_left:
#
# 25_EP09_02-img146-mouth:
#
# 25_EP09_02-img146-eye_left:
#
# 25_EP09_02-img146-eye_right:
#
# 25_EP09_02-img146-eyebrow_left:
#
# 25_EP09_02-img146-eyebrow_right:
#
# 25_EP09_02-img146-nose_right:
#
# 25_EP09_02-img146-nose_left:
#
# 25_EP09_02-img147-mouth:
#
# 25_EP09_02-img147-eye_left:
#
# 25_EP09_02-img147-eye_right:
#
# 25_EP09_02-img147-eyebrow_left:
#
# 25_EP09_02-img147-eyebrow_right:
#
# 25_EP09_02-img147-nose_right:
#
# 25_EP09_02-img147-nose_left:
#
# 25_EP09_02-img148-mouth:
#
# 25_EP09_02-img148-eye_left:
#
# 25_EP09_02-img148-eye_right:
#
# 25_EP09_02-img148-eyebrow_left:
#
# 25_EP09_02-img148-eyebrow_right:
#
# 25_EP09_02-img148-nose_right:
#
# 25_EP09_02-img148-nose_left:
#
# 25_EP09_02-img149-mouth:
#
# 25_EP09_02-img149-eye_left:
#
# 25_EP09_02-img149-eye_right:
#
# 25_EP09_02-img149-eyebrow_left:
#
# 25_EP09_02-img149-eyebrow_right:
#
# 25_EP09_02-img149-nose_right:
#
# 25_EP09_02-img149-nose_left:
#
# 25_EP09_02-img150-mouth:
#
# 25_EP09_02-img150-eye_left:
#
# 25_EP09_02-img150-eye_right:
#
# 25_EP09_02-img150-eyebrow_left:
#
# 25_EP09_02-img150-eyebrow_right:
#
# 25_EP09_02-img150-nose_right:
#
# 25_EP09_02-img150-nose_left:
#
# 25_EP09_02-img151-mouth:
#
# 25_EP09_02-img151-eye_left:
#
# 25_EP09_02-img151-eye_right:
#
# 25_EP09_02-img151-eyebrow_left:
#
# 25_EP09_02-img151-eyebrow_right:
#
# 25_EP09_02-img151-nose_right:
#
# 25_EP09_02-img151-nose_left:
#
# 25_EP09_02-img152-mouth:
#
# 25_EP09_02-img152-eye_left:
#
# 25_EP09_02-img152-eye_right:
#
# 25_EP09_02-img152-eyebrow_left:
#
# 25_EP09_02-img152-eyebrow_right:
#
# 25_EP09_02-img152-nose_right:
#
# 25_EP09_02-img152-nose_left:
#
# 25_EP09_02-img153-mouth:
#
# 25_EP09_02-img153-eye_left:
#
# 25_EP09_02-img153-eye_right:
#
# 25_EP09_02-img153-eyebrow_left:
#
# 25_EP09_02-img153-eyebrow_right:
#
# 25_EP09_02-img153-nose_right:
#
# 25_EP09_02-img153-nose_left:
#
# 25_EP09_02-img154-mouth:
#
# 25_EP09_02-img154-eye_left:
#
# 25_EP09_02-img154-eye_right:
#
# 25_EP09_02-img154-eyebrow_left:
#
# 25_EP09_02-img154-eyebrow_right:
#
# 25_EP09_02-img154-nose_right:
#
# 25_EP09_02-img154-nose_left:
#
# 25_EP09_02-img155-mouth:
#
# 25_EP09_02-img155-eye_left:
#
# 25_EP09_02-img155-eye_right:
#
# 25_EP09_02-img155-eyebrow_left:
#
# 25_EP09_02-img155-eyebrow_right:
#
# 25_EP09_02-img155-nose_right:
#
# 25_EP09_02-img155-nose_left:
#
# 25_EP09_02-img156-mouth:
#
# 25_EP09_02-img156-eye_left:
#
# 25_EP09_02-img156-eye_right:
#
# 25_EP09_02-img156-eyebrow_left:
#
# 25_EP09_02-img156-eyebrow_right:
#
# 25_EP09_02-img156-nose_right:
#
# 25_EP09_02-img156-nose_left:
#
# 25_EP09_02-img157-mouth:
#
# 25_EP09_02-img157-eye_left:
#
# 25_EP09_02-img157-eye_right:
#
# 25_EP09_02-img157-eyebrow_left:
#
# 25_EP09_02-img157-eyebrow_right:
#
# 25_EP09_02-img157-nose_right:
#
# 25_EP09_02-img157-nose_left:
#
# 25_EP09_02-img158-mouth:
#
# 25_EP09_02-img158-eye_left:
#
# 25_EP09_02-img158-eye_right:
#
# 25_EP09_02-img158-eyebrow_left:
#
# 25_EP09_02-img158-eyebrow_right:
#
# 25_EP09_02-img158-nose_right:
#
# 25_EP09_02-img158-nose_left:
#
# 25_EP09_02-img159-mouth:
#
# 25_EP09_02-img159-eye_left:
#
# 25_EP09_02-img159-eye_right:
#
# 25_EP09_02-img159-eyebrow_left:
#
# 25_EP09_02-img159-eyebrow_right:
#
# 25_EP09_02-img159-nose_right:
#
# 25_EP09_02-img159-nose_left:
#
# 25_EP09_02-img160-mouth:
#
# 25_EP09_02-img160-eye_left:
#
# 25_EP09_02-img160-eye_right:
#
# 25_EP09_02-img160-eyebrow_left:
#
# 25_EP09_02-img160-eyebrow_right:
#
# 25_EP09_02-img160-nose_right:
#
# 25_EP09_02-img160-nose_left:
#
# 25_EP09_02-img161-mouth:
#
# 25_EP09_02-img161-eye_left:
#
# 25_EP09_02-img161-eye_right:
#
# 25_EP09_02-img161-eyebrow_left:
#
# 25_EP09_02-img161-eyebrow_right:
#
# 25_EP09_02-img161-nose_right:
#
# 25_EP09_02-img161-nose_left:
#
# 25_EP09_02-img162-mouth:
#
# 25_EP09_02-img162-eye_left:
#
# 25_EP09_02-img162-eye_right:
#
# 25_EP09_02-img162-eyebrow_left:
#
# 25_EP09_02-img162-eyebrow_right:
#
# 25_EP09_02-img162-nose_right:
#
# 25_EP09_02-img162-nose_left:
#
# 25_EP09_02-img163-mouth:
#
# 25_EP09_02-img163-eye_left:
#
# 25_EP09_02-img163-eye_right:
#
# 25_EP09_02-img163-eyebrow_left:
#
# 25_EP09_02-img163-eyebrow_right:
#
# 25_EP09_02-img163-nose_right:
#
# 25_EP09_02-img163-nose_left:
#
# 25_EP09_02-img164-mouth:
#
# 25_EP09_02-img164-eye_left:
#
# 25_EP09_02-img164-eye_right:
#
# 25_EP09_02-img164-eyebrow_left:
#
# 25_EP09_02-img164-eyebrow_right:
#
# 25_EP09_02-img164-nose_right:
#
# 25_EP09_02-img164-nose_left:
#
# 25_EP09_02-img165-mouth:
#
# 25_EP09_02-img165-eye_left:
#
# 25_EP09_02-img165-eye_right:
#
# 25_EP09_02-img165-eyebrow_left:
#
# 25_EP09_02-img165-eyebrow_right:
#
# 25_EP09_02-img165-nose_right:
#
# 25_EP09_02-img165-nose_left:
#
# 25_EP09_02-img166-mouth:
#
# 25_EP09_02-img166-eye_left:
#
# 25_EP09_02-img166-eye_right:
#
# 25_EP09_02-img166-eyebrow_left:
#
# 25_EP09_02-img166-eyebrow_right:
#
# 25_EP09_02-img166-nose_right:
#
# 25_EP09_02-img166-nose_left:
#
# 25_EP09_02-img167-mouth:
#
# 25_EP09_02-img167-eye_left:
#
# 25_EP09_02-img167-eye_right:
#
# 25_EP09_02-img167-eyebrow_left:
#
# 25_EP09_02-img167-eyebrow_right:
#
# 25_EP09_02-img167-nose_right:
#
# 25_EP09_02-img167-nose_left:
#
# 25_EP09_02-img168-mouth:
#
# 25_EP09_02-img168-eye_left:
#
# 25_EP09_02-img168-eye_right:
#
# 25_EP09_02-img168-eyebrow_left:
#
# 25_EP09_02-img168-eyebrow_right:
#
# 25_EP09_02-img168-nose_right:
#
# 25_EP09_02-img168-nose_left:
#
# 25_EP09_02-img169-mouth:
#
# 25_EP09_02-img169-eye_left:
#
# 25_EP09_02-img169-eye_right:
#
# 25_EP09_02-img169-eyebrow_left:
#
# 25_EP09_02-img169-eyebrow_right:
#
# 25_EP09_02-img169-nose_right:
#
# 25_EP09_02-img169-nose_left:
#
# 25_EP09_02-img170-mouth:
#
# 25_EP09_02-img170-eye_left:
#
# 25_EP09_02-img170-eye_right:
#
# 25_EP09_02-img170-eyebrow_left:
#
# 25_EP09_02-img170-eyebrow_right:
#
# 25_EP09_02-img170-nose_right:
#
# 25_EP09_02-img170-nose_left:
#
# 25_EP09_02-img171-mouth:
#
# 25_EP09_02-img171-eye_left:
#
# 25_EP09_02-img171-eye_right:
#
# 25_EP09_02-img171-eyebrow_left:
#
# 25_EP09_02-img171-eyebrow_right:
#
# 25_EP09_02-img171-nose_right:
#
# 25_EP09_02-img171-nose_left:
#
# 25_EP09_02-img172-mouth:
#
# 25_EP09_02-img172-eye_left:
#
# 25_EP09_02-img172-eye_right:
#
# 25_EP09_02-img172-eyebrow_left:
#
# 25_EP09_02-img172-eyebrow_right:
#
# 25_EP09_02-img172-nose_right:
#
# 25_EP09_02-img172-nose_left:
#
# 25_EP09_02-img173-mouth:
#
# 25_EP09_02-img173-eye_left:
#
# 25_EP09_02-img173-eye_right:
#
# 25_EP09_02-img173-eyebrow_left:
#
# 25_EP09_02-img173-eyebrow_right:
#
# 25_EP09_02-img173-nose_right:
#
# 25_EP09_02-img173-nose_left:
#
# 25_EP09_02-img174-mouth:
#
# 25_EP09_02-img174-eye_left:
#
# 25_EP09_02-img174-eye_right:
#
# 25_EP09_02-img174-eyebrow_left:
#
# 25_EP09_02-img174-eyebrow_right:
#
# 25_EP09_02-img174-nose_right:
#
# 25_EP09_02-img174-nose_left:
#
# 25_EP09_02-img175-mouth:
#
# 25_EP09_02-img175-eye_left:
#
# 25_EP09_02-img175-eye_right:
#
# 25_EP09_02-img175-eyebrow_left:
#
# 25_EP09_02-img175-eyebrow_right:
#
# 25_EP09_02-img175-nose_right:
#
# 25_EP09_02-img175-nose_left:
#
# 25_EP09_02-img176-mouth:
#
# 25_EP09_02-img176-eye_left:
#
# 25_EP09_02-img176-eye_right:
#
# 25_EP09_02-img176-eyebrow_left:
#
# 25_EP09_02-img176-eyebrow_right:
#
# 25_EP09_02-img176-nose_right:
#
# 25_EP09_02-img176-nose_left:
#
# 25_EP09_02-img177-mouth:
#
# 25_EP09_02-img177-eye_left:
#
# 25_EP09_02-img177-eye_right:
#
# 25_EP09_02-img177-eyebrow_left:
#
# 25_EP09_02-img177-eyebrow_right:
#
# 25_EP09_02-img177-nose_right:
#
# 25_EP09_02-img177-nose_left:
#
# 25_EP09_02-img178-mouth:
#
# 25_EP09_02-img178-eye_left:
#
# 25_EP09_02-img178-eye_right:
#
# 25_EP09_02-img178-eyebrow_left:
#
# 25_EP09_02-img178-eyebrow_right:
#
# 25_EP09_02-img178-nose_right:
#
# 25_EP09_02-img178-nose_left:
#
# 25_EP09_02-img179-mouth:
#
# 25_EP09_02-img179-eye_left:
#
# 25_EP09_02-img179-eye_right:
#
# 25_EP09_02-img179-eyebrow_left:
#
# 25_EP09_02-img179-eyebrow_right:
#
# 25_EP09_02-img179-nose_right:
#
# 25_EP09_02-img179-nose_left:
#
# 25_EP09_02-img180-mouth:
#
# 25_EP09_02-img180-eye_left:
#
# 25_EP09_02-img180-eye_right:
#
# 25_EP09_02-img180-eyebrow_left:
#
# 25_EP09_02-img180-eyebrow_right:
#
# 25_EP09_02-img180-nose_right:
#
# 25_EP09_02-img180-nose_left:
#
# 25_EP09_02-img181-mouth:
#
# 25_EP09_02-img181-eye_left:
#
# 25_EP09_02-img181-eye_right:
#
# 25_EP09_02-img181-eyebrow_left:
#
# 25_EP09_02-img181-eyebrow_right:
#
# 25_EP09_02-img181-nose_right:
#
# 25_EP09_02-img181-nose_left:
#
# 25_EP09_02-img182-mouth:
#
# 25_EP09_02-img182-eye_left:
#
# 25_EP09_02-img182-eye_right:
#
# 25_EP09_02-img182-eyebrow_left:
#
# 25_EP09_02-img182-eyebrow_right:
#
# 25_EP09_02-img182-nose_right:
#
# 25_EP09_02-img182-nose_left:
#
# 25_EP09_02-img183-mouth:
#
# 25_EP09_02-img183-eye_left:
#
# 25_EP09_02-img183-eye_right:
#
# 25_EP09_02-img183-eyebrow_left:
#
# 25_EP09_02-img183-eyebrow_right:
#
# 25_EP09_02-img183-nose_right:
#
# 25_EP09_02-img183-nose_left:
#
# 25_EP09_02-img184-mouth:
#
# 25_EP09_02-img184-eye_left:
#
# 25_EP09_02-img184-eye_right:
#
# 25_EP09_02-img184-eyebrow_left:
#
# 25_EP09_02-img184-eyebrow_right:
#
# 25_EP09_02-img184-nose_right:
#
# 25_EP09_02-img184-nose_left:
#
# 25_EP09_02-img185-mouth:
#
# 25_EP09_02-img185-eye_left:
#
# 25_EP09_02-img185-eye_right:
#
# 25_EP09_02-img185-eyebrow_left:
#
# 25_EP09_02-img185-eyebrow_right:
#
# 25_EP09_02-img185-nose_right:
#
# 25_EP09_02-img185-nose_left:
#
# 25_EP09_02-img186-mouth:
#
# 25_EP09_02-img186-eye_left:
#
# 25_EP09_02-img186-eye_right:
#
# 25_EP09_02-img186-eyebrow_left:
#
# 25_EP09_02-img186-eyebrow_right:
#
# 25_EP09_02-img186-nose_right:
#
# 25_EP09_02-img186-nose_left:
#
# 25_EP09_02-img187-mouth:
#
# 25_EP09_02-img187-eye_left:
#
# 25_EP09_02-img187-eye_right:
#
# 25_EP09_02-img187-eyebrow_left:
#
# 25_EP09_02-img187-eyebrow_right:
#
# 25_EP09_02-img187-nose_right:
#
# 25_EP09_02-img187-nose_left:
#
# 25_EP09_02-img188-mouth:
#
# 25_EP09_02-img188-eye_left:
#
# 25_EP09_02-img188-eye_right:
#
# 25_EP09_02-img188-eyebrow_left:
#
# 25_EP09_02-img188-eyebrow_right:
#
# 25_EP09_02-img188-nose_right:
#
# 25_EP09_02-img188-nose_left:
#
# 25_EP09_02-img189-mouth:
#
# 25_EP09_02-img189-eye_left:
#
# 25_EP09_02-img189-eye_right:
#
# 25_EP09_02-img189-eyebrow_left:
#
# 25_EP09_02-img189-eyebrow_right:
#
# 25_EP09_02-img189-nose_right:
#
# 25_EP09_02-img189-nose_left:
#
# 25_EP09_02-img190-mouth:
#
# 25_EP09_02-img190-eye_left:
#
# 25_EP09_02-img190-eye_right:
#
# 25_EP09_02-img190-eyebrow_left:
#
# 25_EP09_02-img190-eyebrow_right:
#
# 25_EP09_02-img190-nose_right:
#
# 25_EP09_02-img190-nose_left:
#
# 25_EP09_02-img191-mouth:
#
# 25_EP09_02-img191-eye_left:
#
# 25_EP09_02-img191-eye_right:
#
# 25_EP09_02-img191-eyebrow_left:
#
# 25_EP09_02-img191-eyebrow_right:
#
# 25_EP09_02-img191-nose_right:
#
# 25_EP09_02-img191-nose_left:
#
# 25_EP09_02-img192-mouth:
#
# 25_EP09_02-img192-eye_left:
#
# 25_EP09_02-img192-eye_right:
#
# 25_EP09_02-img192-eyebrow_left:
#
# 25_EP09_02-img192-eyebrow_right:
#
# 25_EP09_02-img192-nose_right:
#
# 25_EP09_02-img192-nose_left:
#
# 25_EP09_02-img193-mouth:
#
# 25_EP09_02-img193-eye_left:
#
# 25_EP09_02-img193-eye_right:
#
# 25_EP09_02-img193-eyebrow_left:
#
# 25_EP09_02-img193-eyebrow_right:
#
# 25_EP09_02-img193-nose_right:
#
# 25_EP09_02-img193-nose_left:
#
# 25_EP09_02-img194-mouth:
#
# 25_EP09_02-img194-eye_left:
#
# 25_EP09_02-img194-eye_right:
#
# 25_EP09_02-img194-eyebrow_left:
#
# 25_EP09_02-img194-eyebrow_right:
#
# 25_EP09_02-img194-nose_right:
#
# 25_EP09_02-img194-nose_left:
#
# 25_EP09_02-img195-mouth:
#
# 25_EP09_02-img195-eye_left:
#
# 25_EP09_02-img195-eye_right:
#
# 25_EP09_02-img195-eyebrow_left:
#
# 25_EP09_02-img195-eyebrow_right:
#
# 25_EP09_02-img195-nose_right:
#
# 25_EP09_02-img195-nose_left:
#
# 25_EP09_02-img196-mouth:
#
# 25_EP09_02-img196-eye_left:
#
# 25_EP09_02-img196-eye_right:
#
# 25_EP09_02-img196-eyebrow_left:
#
# 25_EP09_02-img196-eyebrow_right:
#
# 25_EP09_02-img196-nose_right:
#
# 25_EP09_02-img196-nose_left:
#
# 25_EP09_02-img197-mouth:
#
# 25_EP09_02-img197-eye_left:
#
# 25_EP09_02-img197-eye_right:
#
# 25_EP09_02-img197-eyebrow_left:
#
# 25_EP09_02-img197-eyebrow_right:
#
# 25_EP09_02-img197-nose_right:
#
# 25_EP09_02-img197-nose_left:
#
# 25_EP09_02-img198-mouth:
#
# 25_EP09_02-img198-eye_left:
#
# 25_EP09_02-img198-eye_right:
#
# 25_EP09_02-img198-eyebrow_left:
#
# 25_EP09_02-img198-eyebrow_right:
#
# 25_EP09_02-img198-nose_right:
#
# 25_EP09_02-img198-nose_left:
#
# 25_EP09_02-img199-mouth:
#
# 25_EP09_02-img199-eye_left:
#
# 25_EP09_02-img199-eye_right:
#
# 25_EP09_02-img199-eyebrow_left:
#
# 25_EP09_02-img199-eyebrow_right:
#
# 25_EP09_02-img199-nose_right:
#
# 25_EP09_02-img199-nose_left:
#
# 25_EP09_02-img200-mouth:
#
# 25_EP09_02-img200-eye_left:
#
# 25_EP09_02-img200-eye_right:
#
# 25_EP09_02-img200-eyebrow_left:
#
# 25_EP09_02-img200-eyebrow_right:
#
# 25_EP09_02-img200-nose_right:
#
# 25_EP09_02-img200-nose_left:
#
# 25_EP09_02-img201-mouth:
#
# 25_EP09_02-img201-eye_left:
#
# 25_EP09_02-img201-eye_right:
#
# 25_EP09_02-img201-eyebrow_left:
#
# 25_EP09_02-img201-eyebrow_right:
#
# 25_EP09_02-img201-nose_right:
#
# 25_EP09_02-img201-nose_left:
#
# 25_EP09_02-img202-mouth:
#
# 25_EP09_02-img202-eye_left:
#
# 25_EP09_02-img202-eye_right:
#
# 25_EP09_02-img202-eyebrow_left:
#
# 25_EP09_02-img202-eyebrow_right:
#
# 25_EP09_02-img202-nose_right:
#
# 25_EP09_02-img202-nose_left:
#
# 25_EP09_02-img203-mouth:
#
# 25_EP09_02-img203-eye_left:
#
# 25_EP09_02-img203-eye_right:
#
# 25_EP09_02-img203-eyebrow_left:
#
# 25_EP09_02-img203-eyebrow_right:
#
# 25_EP09_02-img203-nose_right:
#
# 25_EP09_02-img203-nose_left:
#
# 25_EP09_02-img204-mouth:
#
# 25_EP09_02-img204-eye_left:
#
# 25_EP09_02-img204-eye_right:
#
# 25_EP09_02-img204-eyebrow_left:
#
# 25_EP09_02-img204-eyebrow_right:
#
# 25_EP09_02-img204-nose_right:
#
# 25_EP09_02-img204-nose_left:
#
# 25_EP09_02-img205-mouth:
#
# 25_EP09_02-img205-eye_left:
#
# 25_EP09_02-img205-eye_right:
#
# 25_EP09_02-img205-eyebrow_left:
#
# 25_EP09_02-img205-eyebrow_right:
#
# 25_EP09_02-img205-nose_right:
#
# 25_EP09_02-img205-nose_left:
#
# 25_EP09_02-img206-mouth:
#
# 25_EP09_02-img206-eye_left:
#
# 25_EP09_02-img206-eye_right:
#
# 25_EP09_02-img206-eyebrow_left:
#
# 25_EP09_02-img206-eyebrow_right:
#
# 25_EP09_02-img206-nose_right:
#
# 25_EP09_02-img206-nose_left:
#
# 25_EP09_02-img207-mouth:
#
# 25_EP09_02-img207-eye_left:
#
# 25_EP09_02-img207-eye_right:
#
# 25_EP09_02-img207-eyebrow_left:
#
# 25_EP09_02-img207-eyebrow_right:
#
# 25_EP09_02-img207-nose_right:
#
# 25_EP09_02-img207-nose_left:
#
# 25_EP09_02-img208-mouth:
#
# 25_EP09_02-img208-eye_left:
#
# 25_EP09_02-img208-eye_right:
#
# 25_EP09_02-img208-eyebrow_left:
#
# 25_EP09_02-img208-eyebrow_right:
#
# 25_EP09_02-img208-nose_right:
#
# 25_EP09_02-img208-nose_left:
#
# 25_EP09_02-img209-mouth:
#
# 25_EP09_02-img209-eye_left:
#
# 25_EP09_02-img209-eye_right:
#
# 25_EP09_02-img209-eyebrow_left:
#
# 25_EP09_02-img209-eyebrow_right:
#
# 25_EP09_02-img209-nose_right:
#
# 25_EP09_02-img209-nose_left:
#
# 25_EP09_02-img210-mouth:
#
# 25_EP09_02-img210-eye_left:
#
# 25_EP09_02-img210-eye_right:
#
# 25_EP09_02-img210-eyebrow_left:
#
# 25_EP09_02-img210-eyebrow_right:
#
# 25_EP09_02-img210-nose_right:
#
# 25_EP09_02-img210-nose_left:
#
# 25_EP09_02-img211-mouth:
#
# 25_EP09_02-img211-eye_left:
#
# 25_EP09_02-img211-eye_right:
#
# 25_EP09_02-img211-eyebrow_left:
#
# 25_EP09_02-img211-eyebrow_right:
#
# 25_EP09_02-img211-nose_right:
#
# 25_EP09_02-img211-nose_left:
#
# 25_EP09_02-img212-mouth:
#
# 25_EP09_02-img212-eye_left:
#
# 25_EP09_02-img212-eye_right:
#
# 25_EP09_02-img212-eyebrow_left:
#
# 25_EP09_02-img212-eyebrow_right:
#
# 25_EP09_02-img212-nose_right:
#
# 25_EP09_02-img212-nose_left:
#
# 25_EP09_02-img213-mouth:
#
# 25_EP09_02-img213-eye_left:
#
# 25_EP09_02-img213-eye_right:
#
# 25_EP09_02-img213-eyebrow_left:
#
# 25_EP09_02-img213-eyebrow_right:
#
# 25_EP09_02-img213-nose_right:
#
# 25_EP09_02-img213-nose_left:
#
# 25_EP09_02-img214-mouth:
#
# 25_EP09_02-img214-eye_left:
#
# 25_EP09_02-img214-eye_right:
#
# 25_EP09_02-img214-eyebrow_left:
#
# 25_EP09_02-img214-eyebrow_right:
#
# 25_EP09_02-img214-nose_right:
#
# 25_EP09_02-img214-nose_left:
#
# 25_EP09_02-img215-mouth:
#
# 25_EP09_02-img215-eye_left:
#
# 25_EP09_02-img215-eye_right:
#
# 25_EP09_02-img215-eyebrow_left:
#
# 25_EP09_02-img215-eyebrow_right:
#
# 25_EP09_02-img215-nose_right:
#
# 25_EP09_02-img215-nose_left:
#
# 25_EP09_02-img216-mouth:
#
# 25_EP09_02-img216-eye_left:
#
# 25_EP09_02-img216-eye_right:
#
# 25_EP09_02-img216-eyebrow_left:
#
# 25_EP09_02-img216-eyebrow_right:
#
# 25_EP09_02-img216-nose_right:
#
# 25_EP09_02-img216-nose_left:
#
# 25_EP09_02-img217-mouth:
#
# 25_EP09_02-img217-eye_left:
#
# 25_EP09_02-img217-eye_right:
#
# 25_EP09_02-img217-eyebrow_left:
#
# 25_EP09_02-img217-eyebrow_right:
#
# 25_EP09_02-img217-nose_right:
#
# 25_EP09_02-img217-nose_left:
#
# 25_EP09_02-img218-mouth:
#
# 25_EP09_02-img218-eye_left:
#
# 25_EP09_02-img218-eye_right:
#
# 25_EP09_02-img218-eyebrow_left:
#
# 25_EP09_02-img218-eyebrow_right:
#
# 25_EP09_02-img218-nose_right:
#
# 25_EP09_02-img218-nose_left:
#
# 25_EP09_02-img219-mouth:
#
# 25_EP09_02-img219-eye_left:
#
# 25_EP09_02-img219-eye_right:
#
# 25_EP09_02-img219-eyebrow_left:
#
# 25_EP09_02-img219-eyebrow_right:
#
# 25_EP09_02-img219-nose_right:
#
# 25_EP09_02-img219-nose_left:
#
# 25_EP09_02-img220-mouth:
#
# 25_EP09_02-img220-eye_left:
#
# 25_EP09_02-img220-eye_right:
#
# 25_EP09_02-img220-eyebrow_left:
#
# 25_EP09_02-img220-eyebrow_right:
#
# 25_EP09_02-img220-nose_right:
#
# 25_EP09_02-img220-nose_left:
#
# 25_EP09_02-img221-mouth:
#
# 25_EP09_02-img221-eye_left:
#
# 25_EP09_02-img221-eye_right:
#
# 25_EP09_02-img221-eyebrow_left:
#
# 25_EP09_02-img221-eyebrow_right:
#
# 25_EP09_02-img221-nose_right:
#
# 25_EP09_02-img221-nose_left:
#
# 25_EP09_02-img222-mouth:
#
# 25_EP09_02-img222-eye_left:
#
# 25_EP09_02-img222-eye_right:
#
# 25_EP09_02-img222-eyebrow_left:
#
# 25_EP09_02-img222-eyebrow_right:
#
# 25_EP09_02-img222-nose_right:
#
# 25_EP09_02-img222-nose_left:
#
# 25_EP09_02-img223-mouth:
#
# 25_EP09_02-img223-eye_left:
#
# 25_EP09_02-img223-eye_right:
#
# 25_EP09_02-img223-eyebrow_left:
#
# 25_EP09_02-img223-eyebrow_right:
#
# 25_EP09_02-img223-nose_right:
#
# 25_EP09_02-img223-nose_left:
#
# 25_EP09_02-img224-mouth:
#
# 25_EP09_02-img224-eye_left:
#
# 25_EP09_02-img224-eye_right:
#
# 25_EP09_02-img224-eyebrow_left:
#
# 25_EP09_02-img224-eyebrow_right:
#
# 25_EP09_02-img224-nose_right:
#
# 25_EP09_02-img224-nose_left:
#
# 25_EP09_02-img225-mouth:
#
# 25_EP09_02-img225-eye_left:
#
# 25_EP09_02-img225-eye_right:
#
# 25_EP09_02-img225-eyebrow_left:
#
# 25_EP09_02-img225-eyebrow_right:
#
# 25_EP09_02-img225-nose_right:
#
# 25_EP09_02-img225-nose_left:
#
# 25_EP09_02-img226-mouth:
#
# 25_EP09_02-img226-eye_left:
#
# 25_EP09_02-img226-eye_right:
#
# 25_EP09_02-img226-eyebrow_left:
#
# 25_EP09_02-img226-eyebrow_right:
#
# 25_EP09_02-img226-nose_right:
#
# 25_EP09_02-img226-nose_left:
#
# 25_EP09_02-img227-mouth:
#
# 25_EP09_02-img227-eye_left:
#
# 25_EP09_02-img227-eye_right:
#
# 25_EP09_02-img227-eyebrow_left:
#
# 25_EP09_02-img227-eyebrow_right:
#
# 25_EP09_02-img227-nose_right:
#
# 25_EP09_02-img227-nose_left:
#
# 25_EP09_02-img228-mouth:
#
# 25_EP09_02-img228-eye_left:
#
# 25_EP09_02-img228-eye_right:
#
# 25_EP09_02-img228-eyebrow_left:
#
# 25_EP09_02-img228-eyebrow_right:
#
# 25_EP09_02-img228-nose_right:
#
# 25_EP09_02-img228-nose_left:
#
# 25_EP09_02-img229-mouth:
#
# 25_EP09_02-img229-eye_left:
#
# 25_EP09_02-img229-eye_right:
#
# 25_EP09_02-img229-eyebrow_left:
#
# 25_EP09_02-img229-eyebrow_right:
#
# 25_EP09_02-img229-nose_right:
#
# ...
#
# 24_EP18_03-img247-mouth:
#
# 24_EP18_03-img247-eye_left:
#
# 24_EP18_03-img247-eye_right:
#
# 24_EP18_03-img247-eyebrow_left:
#
# 24_EP18_03-img247-eyebrow_right:
#
# 24_EP18_03-img247-nose_right:
#
# 24_EP18_03-img247-nose_left:
#
# 24_EP18_03-img248-mouth:
#
# 24_EP18_03-img248-eye_left:
#
# 24_EP18_03-img248-eye_right:
#
# 24_EP18_03-img248-eyebrow_left:
#
# 24_EP18_03-img248-eyebrow_right:
#
# 24_EP18_03-img248-nose_right:
#
# 24_EP18_03-img248-nose_left:
#
# 24_EP18_03-img249-mouth:
#
# 24_EP18_03-img249-eye_left:
#
# 24_EP18_03-img249-eye_right:
#
# 24_EP18_03-img249-eyebrow_left:
#
# 24_EP18_03-img249-eyebrow_right:
#
# 24_EP18_03-img249-nose_right:
#
# 24_EP18_03-img249-nose_left:
#
# 24_EP18_03-img250-mouth:
#
# 24_EP18_03-img250-eye_left:
#
# 24_EP18_03-img250-eye_right:
#
# 24_EP18_03-img250-eyebrow_left:
#
# 24_EP18_03-img250-eyebrow_right:
#
# 24_EP18_03-img250-nose_right:
#
# 24_EP18_03-img250-nose_left:
#
# 24_EP18_03-img251-mouth:
#
# 24_EP18_03-img251-eye_left:
#
# 24_EP18_03-img251-eye_right:
#
# 24_EP18_03-img251-eyebrow_left:
#
# 24_EP18_03-img251-eyebrow_right:
#
# 24_EP18_03-img251-nose_right:
#
# 24_EP18_03-img251-nose_left:
#
# 24_EP18_03-img252-mouth:
#
# 24_EP18_03-img252-eye_left:
#
# 24_EP18_03-img252-eye_right:
#
# 24_EP18_03-img252-eyebrow_left:
#
# 24_EP18_03-img252-eyebrow_right:
#
# 24_EP18_03-img252-nose_right:
#
# 24_EP18_03-img252-nose_left:
#
# 24_EP18_03-img253-mouth:
#
# 24_EP18_03-img253-eye_left:
#
# 24_EP18_03-img253-eye_right:
#
# 24_EP18_03-img253-eyebrow_left:
#
# 24_EP18_03-img253-eyebrow_right:
#
# 24_EP18_03-img253-nose_right:
#
# 24_EP18_03-img253-nose_left:
#
# 24_EP18_03-img254-mouth:
#
# 24_EP18_03-img254-eye_left:
#
# 24_EP18_03-img254-eye_right:
#
# 24_EP18_03-img254-eyebrow_left:
#
# 24_EP18_03-img254-eyebrow_right:
#
# 24_EP18_03-img254-nose_right:
#
# 24_EP18_03-img254-nose_left:
#
# 24_EP18_03-img255-mouth:
#
# 24_EP18_03-img255-eye_left:
#
# 24_EP18_03-img255-eye_right:
#
# 24_EP18_03-img255-eyebrow_left:
#
# 24_EP18_03-img255-eyebrow_right:
#
# 24_EP18_03-img255-nose_right:
#
# 24_EP18_03-img255-nose_left:
#
# 24_EP18_03-img256-mouth:
#
# 24_EP18_03-img256-eye_left:
#
# 24_EP18_03-img256-eye_right:
#
# 24_EP18_03-img256-eyebrow_left:
#
# 24_EP18_03-img256-eyebrow_right:
#
# 24_EP18_03-img256-nose_right:
#
# 24_EP18_03-img256-nose_left:
#
# 24_EP18_03-img257-mouth:
#
# 24_EP18_03-img257-eye_left:
#
# 24_EP18_03-img257-eye_right:
#
# 24_EP18_03-img257-eyebrow_left:
#
# 24_EP18_03-img257-eyebrow_right:
#
# 24_EP18_03-img257-nose_right:
#
# 24_EP18_03-img257-nose_left:
#
# 24_EP18_03-img258-mouth:
#
# 24_EP18_03-img258-eye_left:
#
# 24_EP18_03-img258-eye_right:
#
# 24_EP18_03-img258-eyebrow_left:
#
# 24_EP18_03-img258-eyebrow_right:
#
# 24_EP18_03-img258-nose_right:
#
# 24_EP18_03-img258-nose_left:
#
# 24_EP18_03-img259-mouth:
#
# 24_EP18_03-img259-eye_left:
#
# 24_EP18_03-img259-eye_right:
#
# 24_EP18_03-img259-eyebrow_left:
#
# 24_EP18_03-img259-eyebrow_right:
#
# 24_EP18_03-img259-nose_right:
#
# 24_EP18_03-img259-nose_left:
#
# 24_EP18_03-img260-mouth:
#
# 24_EP18_03-img260-eye_left:
#
# 24_EP18_03-img260-eye_right:
#
# 24_EP18_03-img260-eyebrow_left:
#
# 24_EP18_03-img260-eyebrow_right:
#
# 24_EP18_03-img260-nose_right:
#
# 24_EP18_03-img260-nose_left:
#
# 24_EP18_03-img261-mouth:
#
# 24_EP18_03-img261-eye_left:
#
# 24_EP18_03-img261-eye_right:
#
# 24_EP18_03-img261-eyebrow_left:
#
# 24_EP18_03-img261-eyebrow_right:
#
# 24_EP18_03-img261-nose_right:
#
# 24_EP18_03-img261-nose_left:
#
# 24_EP18_03-img262-mouth:
#
# 24_EP18_03-img262-eye_left:
#
# 24_EP18_03-img262-eye_right:
#
# 24_EP18_03-img262-eyebrow_left:
#
# 24_EP18_03-img262-eyebrow_right:
#
# 24_EP18_03-img262-nose_right:
#
# 24_EP18_03-img262-nose_left:
#
# 24_EP18_03-img263-mouth:
#
# 24_EP18_03-img263-eye_left:
#
# 24_EP18_03-img263-eye_right:
#
# 24_EP18_03-img263-eyebrow_left:
#
# 24_EP18_03-img263-eyebrow_right:
#
# 24_EP18_03-img263-nose_right:
#
# 24_EP18_03-img263-nose_left:
#
# 24_EP18_03-img264-mouth:
#
# 24_EP18_03-img264-eye_left:
#
# 24_EP18_03-img264-eye_right:
#
# 24_EP18_03-img264-eyebrow_left:
#
# 24_EP18_03-img264-eyebrow_right:
#
# 24_EP18_03-img264-nose_right:
#
# 24_EP18_03-img264-nose_left:
#
# 24_EP18_03-img265-mouth:
#
# 24_EP18_03-img265-eye_left:
#
# 24_EP18_03-img265-eye_right:
#
# 24_EP18_03-img265-eyebrow_left:
#
# 24_EP18_03-img265-eyebrow_right:
#
# 24_EP18_03-img265-nose_right:
#
# 24_EP18_03-img265-nose_left:
#
# 24_EP18_03-img266-mouth:
#
# 24_EP18_03-img266-eye_left:
#
# 24_EP18_03-img266-eye_right:
#
# 24_EP18_03-img266-eyebrow_left:
#
# 24_EP18_03-img266-eyebrow_right:
#
# 24_EP18_03-img266-nose_right:
#
# 24_EP18_03-img266-nose_left:
#
# 24_EP18_03-img267-mouth:
#
# 24_EP18_03-img267-eye_left:
#
# 24_EP18_03-img267-eye_right:
#
# 24_EP18_03-img267-eyebrow_left:
#
# 24_EP18_03-img267-eyebrow_right:
#
# 24_EP18_03-img267-nose_right:
#
# 24_EP18_03-img267-nose_left:
#
# 24_EP18_03-img268-mouth:
#
# 24_EP18_03-img268-eye_left:
#
# 24_EP18_03-img268-eye_right:
#
# 24_EP18_03-img268-eyebrow_left:
#
# 24_EP18_03-img268-eyebrow_right:
#
# 24_EP18_03-img268-nose_right:
#
# 24_EP18_03-img268-nose_left:
#
# 24_EP18_03-img269-mouth:
#
# 24_EP18_03-img269-eye_left:
#
# 24_EP18_03-img269-eye_right:
#
# 24_EP18_03-img269-eyebrow_left:
#
# 24_EP18_03-img269-eyebrow_right:
#
# 24_EP18_03-img269-nose_right:
#
# 24_EP18_03-img269-nose_left:
#
# 24_EP18_03-img270-mouth:
#
# 24_EP18_03-img270-eye_left:
#
# 24_EP18_03-img270-eye_right:
#
# 24_EP18_03-img270-eyebrow_left:
#
# 24_EP18_03-img270-eyebrow_right:
#
# 24_EP18_03-img270-nose_right:
#
# 24_EP18_03-img270-nose_left:
#
# 24_EP18_03-img271-mouth:
#
# 24_EP18_03-img271-eye_left:
#
# 24_EP18_03-img271-eye_right:
#
# 24_EP18_03-img271-eyebrow_left:
#
# 24_EP18_03-img271-eyebrow_right:
#
# 24_EP18_03-img271-nose_right:
#
# 24_EP18_03-img271-nose_left:
#
# 24_EP18_03-img272-mouth:
#
# 24_EP18_03-img272-eye_left:
#
# 24_EP18_03-img272-eye_right:
#
# 24_EP18_03-img272-eyebrow_left:
#
# 24_EP18_03-img272-eyebrow_right:
#
# 24_EP18_03-img272-nose_right:
#
# 24_EP18_03-img272-nose_left:
#
# 24_EP18_03-img273-mouth:
#
# 24_EP18_03-img273-eye_left:
#
# 24_EP18_03-img273-eye_right:
#
# 24_EP18_03-img273-eyebrow_left:
#
# 24_EP18_03-img273-eyebrow_right:
#
# 24_EP18_03-img273-nose_right:
#
# 24_EP18_03-img273-nose_left:
#
# 24_EP18_03-img274-mouth:
#
# 24_EP18_03-img274-eye_left:
#
# 24_EP18_03-img274-eye_right:
#
# 24_EP18_03-img274-eyebrow_left:
#
# 24_EP18_03-img274-eyebrow_right:
#
# 24_EP18_03-img274-nose_right:
#
# 24_EP18_03-img274-nose_left:
#
# 24_EP18_03-img275-mouth:
#
# 24_EP18_03-img275-eye_left:
#
# 24_EP18_03-img275-eye_right:
#
# 24_EP18_03-img275-eyebrow_left:
#
# 24_EP18_03-img275-eyebrow_right:
#
# 24_EP18_03-img275-nose_right:
#
# 24_EP18_03-img275-nose_left:
#
# 24_EP18_03-img276-mouth:
#
# 24_EP18_03-img276-eye_left:
#
# 24_EP18_03-img276-eye_right:
#
# 24_EP18_03-img276-eyebrow_left:
#
# 24_EP18_03-img276-eyebrow_right:
#
# 24_EP18_03-img276-nose_right:
#
# 24_EP18_03-img276-nose_left:
#
# 24_EP18_03-img277-mouth:
#
# 24_EP18_03-img277-eye_left:
#
# 24_EP18_03-img277-eye_right:
#
# 24_EP18_03-img277-eyebrow_left:
#
# 24_EP18_03-img277-eyebrow_right:
#
# 24_EP18_03-img277-nose_right:
#
# 24_EP18_03-img277-nose_left:
#
# 24_EP18_03-img278-mouth:
#
# 24_EP18_03-img278-eye_left:
#
# 24_EP18_03-img278-eye_right:
#
# 24_EP18_03-img278-eyebrow_left:
#
# 24_EP18_03-img278-eyebrow_right:
#
# 24_EP18_03-img278-nose_right:
#
# 24_EP18_03-img278-nose_left:
#
# 24_EP18_03-img279-mouth:
#
# 24_EP18_03-img279-eye_left:
#
# 24_EP18_03-img279-eye_right:
#
# 24_EP18_03-img279-eyebrow_left:
#
# 24_EP18_03-img279-eyebrow_right:
#
# 24_EP18_03-img279-nose_right:
#
# 24_EP18_03-img279-nose_left:
#
# 24_EP18_03-img280-mouth:
#
# 24_EP18_03-img280-eye_left:
#
# 24_EP18_03-img280-eye_right:
#
# 24_EP18_03-img280-eyebrow_left:
#
# 24_EP18_03-img280-eyebrow_right:
#
# 24_EP18_03-img280-nose_right:
#
# 24_EP18_03-img280-nose_left:
#
# 24_EP18_03-img281-mouth:
#
# 24_EP18_03-img281-eye_left:
#
# 24_EP18_03-img281-eye_right:
#
# 24_EP18_03-img281-eyebrow_left:
#
# 24_EP18_03-img281-eyebrow_right:
#
# 24_EP18_03-img281-nose_right:
#
# 24_EP18_03-img281-nose_left:
#
# 24_EP18_03-img282-mouth:
#
# 24_EP18_03-img282-eye_left:
#
# 24_EP18_03-img282-eye_right:
#
# 24_EP18_03-img282-eyebrow_left:
#
# 24_EP18_03-img282-eyebrow_right:
#
# 24_EP18_03-img282-nose_right:
#
# 24_EP18_03-img282-nose_left:
#
# 24_EP18_03-img283-mouth:
#
# 24_EP18_03-img283-eye_left:
#
# 24_EP18_03-img283-eye_right:
#
# 24_EP18_03-img283-eyebrow_left:
#
# 24_EP18_03-img283-eyebrow_right:
#
# 24_EP18_03-img283-nose_right:
#
# 24_EP18_03-img283-nose_left:
#
# 24_EP18_03-img284-mouth:
#
# 24_EP18_03-img284-eye_left:
#
# 24_EP18_03-img284-eye_right:
#
# 24_EP18_03-img284-eyebrow_left:
#
# 24_EP18_03-img284-eyebrow_right:
#
# 24_EP18_03-img284-nose_right:
#
# 24_EP18_03-img284-nose_left:
#
# 24_EP18_03-img285-mouth:
#
# 24_EP18_03-img285-eye_left:
#
# 24_EP18_03-img285-eye_right:
#
# 24_EP18_03-img285-eyebrow_left:
#
# 24_EP18_03-img285-eyebrow_right:
#
# 24_EP18_03-img285-nose_right:
#
# 24_EP18_03-img285-nose_left:
#
# 24_EP18_03-img286-mouth:
#
# 24_EP18_03-img286-eye_left:
#
# 24_EP18_03-img286-eye_right:
#
# 24_EP18_03-img286-eyebrow_left:
#
# 24_EP18_03-img286-eyebrow_right:
#
# 24_EP18_03-img286-nose_right:
#
# 24_EP18_03-img286-nose_left:
#
# 24_EP18_03-img287-mouth:
#
# 24_EP18_03-img287-eye_left:
#
# 24_EP18_03-img287-eye_right:
#
# 24_EP18_03-img287-eyebrow_left:
#
# 24_EP18_03-img287-eyebrow_right:
#
# 24_EP18_03-img287-nose_right:
#
# 24_EP18_03-img287-nose_left:
#
# 24_EP18_03-img288-mouth:
#
# 24_EP18_03-img288-eye_left:
#
# 24_EP18_03-img288-eye_right:
#
# 24_EP18_03-img288-eyebrow_left:
#
# 24_EP18_03-img288-eyebrow_right:
#
# 24_EP18_03-img288-nose_right:
#
# 24_EP18_03-img288-nose_left:
#
# 24_EP18_03-img289-mouth:
#
# 24_EP18_03-img289-eye_left:
#
# 24_EP18_03-img289-eye_right:
#
# 24_EP18_03-img289-eyebrow_left:
#
# 24_EP18_03-img289-eyebrow_right:
#
# 24_EP18_03-img289-nose_right:
#
# 24_EP18_03-img289-nose_left:
#
# 24_EP18_03-img290-mouth:
#
# 24_EP18_03-img290-eye_left:
#
# 24_EP18_03-img290-eye_right:
#
# 24_EP18_03-img290-eyebrow_left:
#
# 24_EP18_03-img290-eyebrow_right:
#
# 24_EP18_03-img290-nose_right:
#
# 24_EP18_03-img290-nose_left:
#
# 24_EP18_03-img291-mouth:
#
# 24_EP18_03-img291-eye_left:
#
# 24_EP18_03-img291-eye_right:
#
# 24_EP18_03-img291-eyebrow_left:
#
# 24_EP18_03-img291-eyebrow_right:
#
# 24_EP18_03-img291-nose_right:
#
# 24_EP18_03-img291-nose_left:
#
# 24_EP18_03-img292-mouth:
#
# 24_EP18_03-img292-eye_left:
#
# 24_EP18_03-img292-eye_right:
#
# 24_EP18_03-img292-eyebrow_left:
#
# 24_EP18_03-img292-eyebrow_right:
#
# 24_EP18_03-img292-nose_right:
#
# 24_EP18_03-img292-nose_left:
#
# 24_EP18_03-img293-mouth:
#
# 24_EP18_03-img293-eye_left:
#
# 24_EP18_03-img293-eye_right:
#
# 24_EP18_03-img293-eyebrow_left:
#
# 24_EP18_03-img293-eyebrow_right:
#
# 24_EP18_03-img293-nose_right:
#
# 24_EP18_03-img293-nose_left:
#
# 24_EP18_03-img294-mouth:
#
# 24_EP18_03-img294-eye_left:
#
# 24_EP18_03-img294-eye_right:
#
# 24_EP18_03-img294-eyebrow_left:
#
# 24_EP18_03-img294-eyebrow_right:
#
# 24_EP18_03-img294-nose_right:
#
# 24_EP18_03-img294-nose_left:
#
# 24_EP18_03-img295-mouth:
#
# 24_EP18_03-img295-eye_left:
#
# 24_EP18_03-img295-eye_right:
#
# 24_EP18_03-img295-eyebrow_left:
#
# 24_EP18_03-img295-eyebrow_right:
#
# 24_EP18_03-img295-nose_right:
#
# 24_EP18_03-img295-nose_left:
#
# 24_EP18_03-img296-mouth:
#
# 24_EP18_03-img296-eye_left:
#
# 24_EP18_03-img296-eye_right:
#
# 24_EP18_03-img296-eyebrow_left:
#
# 24_EP18_03-img296-eyebrow_right:
#
# 24_EP18_03-img296-nose_right:
#
# 24_EP18_03-img296-nose_left:
#
# 24_EP18_03-img297-mouth:
#
# 24_EP18_03-img297-eye_left:
#
# 24_EP18_03-img297-eye_right:
#
# 24_EP18_03-img297-eyebrow_left:
#
# 24_EP18_03-img297-eyebrow_right:
#
# 24_EP18_03-img297-nose_right:
#
# 24_EP18_03-img297-nose_left:
#
# 24_EP18_03-img298-mouth:
#
# 24_EP18_03-img298-eye_left:
#
# 24_EP18_03-img298-eye_right:
#
# 24_EP18_03-img298-eyebrow_left:
#
# 24_EP18_03-img298-eyebrow_right:
#
# 24_EP18_03-img298-nose_right:
#
# 24_EP18_03-img298-nose_left:
#
# 24_EP18_03-img299-mouth:
#
# 24_EP18_03-img299-eye_left:
#
# 24_EP18_03-img299-eye_right:
#
# 24_EP18_03-img299-eyebrow_left:
#
# 24_EP18_03-img299-eyebrow_right:
#
# 24_EP18_03-img299-nose_right:
#
# 24_EP18_03-img299-nose_left:
#
# 24_EP18_03-img300-mouth:
#
# 24_EP18_03-img300-eye_left:
#
# 24_EP18_03-img300-eye_right:
#
# 24_EP18_03-img300-eyebrow_left:
#
# 24_EP18_03-img300-eyebrow_right:
#
# 24_EP18_03-img300-nose_right:
#
# 24_EP18_03-img300-nose_left:
#
# 24_EP18_03-img301-mouth:
#
# 24_EP18_03-img301-eye_left:
#
# 24_EP18_03-img301-eye_right:
#
# 24_EP18_03-img301-eyebrow_left:
#
# 24_EP18_03-img301-eyebrow_right:
#
# 24_EP18_03-img301-nose_right:
#
# 24_EP18_03-img301-nose_left:
#
# 24_EP18_03-img302-mouth:
#
# 24_EP18_03-img302-eye_left:
#
# 24_EP18_03-img302-eye_right:
#
# 24_EP18_03-img302-eyebrow_left:
#
# 24_EP18_03-img302-eyebrow_right:
#
# 24_EP18_03-img302-nose_right:
#
# 24_EP18_03-img302-nose_left:
#
# 24_EP18_03-img303-mouth:
#
# 24_EP18_03-img303-eye_left:
#
# 24_EP18_03-img303-eye_right:
#
# 24_EP18_03-img303-eyebrow_left:
#
# 24_EP18_03-img303-eyebrow_right:
#
# 24_EP18_03-img303-nose_right:
#
# 24_EP18_03-img303-nose_left:
#
# 24_EP18_03-img304-mouth:
#
# 24_EP18_03-img304-eye_left:
#
# 24_EP18_03-img304-eye_right:
#
# 24_EP18_03-img304-eyebrow_left:
#
# 24_EP18_03-img304-eyebrow_right:
#
# 24_EP18_03-img304-nose_right:
#
# 24_EP18_03-img304-nose_left:
#
# 24_EP18_03-img305-mouth:
#
# 24_EP18_03-img305-eye_left:
#
# 24_EP18_03-img305-eye_right:
#
# 24_EP18_03-img305-eyebrow_left:
#
# 24_EP18_03-img305-eyebrow_right:
#
# 24_EP18_03-img305-nose_right:
#
# 24_EP18_03-img305-nose_left:
#
# 24_EP18_03-img306-mouth:
#
# 24_EP18_03-img306-eye_left:
#
# 24_EP18_03-img306-eye_right:
#
# 24_EP18_03-img306-eyebrow_left:
#
# 24_EP18_03-img306-eyebrow_right:
#
# 24_EP18_03-img306-nose_right:
#
# 24_EP18_03-img306-nose_left:
#
# 24_EP18_03-img307-mouth:
#
# 24_EP18_03-img307-eye_left:
#
# 24_EP18_03-img307-eye_right:
#
# 24_EP18_03-img307-eyebrow_left:
#
# 24_EP18_03-img307-eyebrow_right:
#
# 24_EP18_03-img307-nose_right:
#
# 24_EP18_03-img307-nose_left:
#
# 24_EP18_03-img308-mouth:
#
# 24_EP18_03-img308-eye_left:
#
# 24_EP18_03-img308-eye_right:
#
# 24_EP18_03-img308-eyebrow_left:
#
# 24_EP18_03-img308-eyebrow_right:
#
# 24_EP18_03-img308-nose_right:
#
# 24_EP18_03-img308-nose_left:
#
# 24_EP18_03-img309-mouth:
#
# 24_EP18_03-img309-eye_left:
#
# 24_EP18_03-img309-eye_right:
#
# 24_EP18_03-img309-eyebrow_left:
#
# 24_EP18_03-img309-eyebrow_right:
#
# 24_EP18_03-img309-nose_right:
#
# 24_EP18_03-img309-nose_left:
#
# 24_EP18_03-img310-mouth:
#
# 24_EP18_03-img310-eye_left:
#
# 24_EP18_03-img310-eye_right:
#
# 24_EP18_03-img310-eyebrow_left:
#
# 24_EP18_03-img310-eyebrow_right:
#
# 24_EP18_03-img310-nose_right:
#
# 24_EP18_03-img310-nose_left:
#
# 24_EP18_03-img311-mouth:
#
# 24_EP18_03-img311-eye_left:
#
# 24_EP18_03-img311-eye_right:
#
# 24_EP18_03-img311-eyebrow_left:
#
# 24_EP18_03-img311-eyebrow_right:
#
# 24_EP18_03-img311-nose_right:
#
# 24_EP18_03-img311-nose_left:
#
# 24_EP18_03-img312-mouth:
#
# 24_EP18_03-img312-eye_left:
#
# 24_EP18_03-img312-eye_right:
#
# 24_EP18_03-img312-eyebrow_left:
#
# 24_EP18_03-img312-eyebrow_right:
#
# 24_EP18_03-img312-nose_right:
#
# 24_EP18_03-img312-nose_left:
#
# 24_EP18_03-img313-mouth:
#
# 24_EP18_03-img313-eye_left:
#
# 24_EP18_03-img313-eye_right:
#
# 24_EP18_03-img313-eyebrow_left:
#
# 24_EP18_03-img313-eyebrow_right:
#
# 24_EP18_03-img313-nose_right:
#
# 24_EP18_03-img313-nose_left:
#
# 24_EP18_03-img314-mouth:
#
# 24_EP18_03-img314-eye_left:
#
# 24_EP18_03-img314-eye_right:
#
# 24_EP18_03-img314-eyebrow_left:
#
# 24_EP18_03-img314-eyebrow_right:
#
# 24_EP18_03-img314-nose_right:
#
# 24_EP18_03-img314-nose_left:
#
# 24_EP18_03-img315-mouth:
#
# 24_EP18_03-img315-eye_left:
#
# 24_EP18_03-img315-eye_right:
#
# 24_EP18_03-img315-eyebrow_left:
#
# 24_EP18_03-img315-eyebrow_right:
#
# 24_EP18_03-img315-nose_right:
#
# 24_EP18_03-img315-nose_left:
#
# 24_EP18_03-img316-mouth:
#
# 24_EP18_03-img316-eye_left:
#
# 24_EP18_03-img316-eye_right:
#
# 24_EP18_03-img316-eyebrow_left:
#
# 24_EP18_03-img316-eyebrow_right:
#
# 24_EP18_03-img316-nose_right:
#
# 24_EP18_03-img316-nose_left:
#
# 24_EP18_03-img317-mouth:
#
# 24_EP18_03-img317-eye_left:
#
# 24_EP18_03-img317-eye_right:
#
# 24_EP18_03-img317-eyebrow_left:
#
# 24_EP18_03-img317-eyebrow_right:
#
# 24_EP18_03-img317-nose_right:
#
# 24_EP18_03-img317-nose_left:
#
# 24_EP18_03-img318-mouth:
#
# 24_EP18_03-img318-eye_left:
#
# 24_EP18_03-img318-eye_right:
#
# 24_EP18_03-img318-eyebrow_left:
#
# 24_EP18_03-img318-eyebrow_right:
#
# 24_EP18_03-img318-nose_right:
#
# 24_EP18_03-img318-nose_left:
#
# 24_EP18_03-img319-mouth:
#
# 24_EP18_03-img319-eye_left:
#
# 24_EP18_03-img319-eye_right:
#
# 24_EP18_03-img319-eyebrow_left:
#
# 24_EP18_03-img319-eyebrow_right:
#
# 24_EP18_03-img319-nose_right:
#
# 24_EP18_03-img319-nose_left:
#
# 24_EP18_03-img320-mouth:
#
# 24_EP18_03-img320-eye_left:
#
# 24_EP18_03-img320-eye_right:
#
# 24_EP18_03-img320-eyebrow_left:
#
# 24_EP18_03-img320-eyebrow_right:
#
# 24_EP18_03-img320-nose_right:
#
# 24_EP18_03-img320-nose_left:
#
# 24_EP18_03-img321-mouth:
#
# 24_EP18_03-img321-eye_left:
#
# 24_EP18_03-img321-eye_right:
#
# 24_EP18_03-img321-eyebrow_left:
#
# 24_EP18_03-img321-eyebrow_right:
#
# 24_EP18_03-img321-nose_right:
#
# 24_EP18_03-img321-nose_left:

# %% [markdown]
# #### Pemisah #####

# %%
# Import module yang digunakan
from preprocessing.scarpping_component import extract_component_by_images
from feature_extraction.poc import POC
from feature_extraction.vektor import Vektor
from feature_extraction.quadran import Quadran
import re

def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split('(\d+)', s)]

# load model dan shape predictor untuk deteksi wajah
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")

components_setup = {
    'mulut': {
        'object_name': 'mouth',
        'object_rectangle': {"x_right": 54, "x_left": 48, "y_highest": 52, "y_lowest": 57},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 5},
        'object_dimension': {'width': 140, 'height': 40}
    },
    'mata_kiri': {
        'object_name': 'eye_left',
        'object_rectangle': {"x_right": 39, "x_left": 36, "y_highest": 38, "y_lowest": 41},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'mata_kanan': {
        'object_name': 'eye_right',
        'object_rectangle': {"x_right": 45, "x_left": 42, "y_highest": 43, "y_lowest": 47},
        'pixel_shifting': {"pixel_x": 25, "pixel_y": 25},
        'object_dimension': {'width': 90, 'height': 55}
    },
    'alis_kiri': {
        'object_name': 'eyebrow_left',
        'object_rectangle': {"x_right": 21, "x_left": 17, "y_highest": 18, "y_lowest": 21},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
    'alis_kanan': {
        'object_name': 'eyebrow_right',
        'object_rectangle': {"x_right": 26, "x_left": 22, "y_highest": 25, "y_lowest": 22},
        'pixel_shifting': {"pixel_x": 15, "pixel_y": 15},
        'object_dimension': {'width': 110, 'height': 40}
    },
}

# Inisialisasi variabel untuk path url dan blok size
blockSize = 5
pathDirectory = {
    "base_path_dataset": "dataset",
    # "base_dataset_input" : "dataset/casme_custom_from_one",
    "base_dataset_input" : "dataset/casme_dua_terbaru",
    "result_dataset" : "output-baru-tanpa-hidung", 
    "component_image" : "component_to_images", 
    "video_frame" :"video_to_images"
}

# Inisialisasi variabel untuk menyimpan data dari masing-masing komponen
frames_data_quadran = []
frames_data_all_component = []
frames_data_quadran_column = ['sumX', 'sumY', 'Tetha', 'Magnitude', 'JumlahQuadran']
quadran_dimensions = ['Q1', 'Q2', 'Q3', 'Q4']
frames_data = {component_name: [] for component_name in components_setup}
total_blocks_components = {component_name: 0 for component_name in components_setup}
data_blocks_first_image = {component_name: None for component_name in components_setup}
index = {component_name: 0 for component_name in components_setup}

# Hitung total blok dari masing-masing komponen lalu disetup kedalam total_blocks_components
for component_name, component_info in components_setup.items():
    total_blocks_components[component_name] = int((component_info['object_dimension']['width'] / blockSize) * (component_info['object_dimension']['height'] / blockSize))

# Loop melalui setiap kunci dan nilai di pathDirectory dan hapus direktorinya
for key, value in pathDirectory.items():
    # Jika tidak mengandung base, hapus direktori sesuai dengan nilai yang ada
    if not "base" in key:
        shutil.rmtree(value, ignore_errors=True)

# Looping folder label didalam base_dataset_input
for foldername_label in os.listdir(pathDirectory['base_dataset_input']):
    foldername_label_join_basepath = os.path.join(pathDirectory['base_dataset_input'], foldername_label)
    # Jika folder nya tidak ada skip looping ini
    if not os.path.isdir(foldername_label_join_basepath):
        continue
    
    # Looping folder label didalam foldername_label_join_basepath 
    for foldername in os.listdir(foldername_label_join_basepath):
        foldername_join_basepath = os.path.join(foldername_label_join_basepath, foldername)
        # Jika folder nya tidak ada skip looping ini
        if not os.path.isdir(foldername_join_basepath):
            continue

        # Reset variabel setiap kali mulai looping folder baru
        data_blocks_first_image = {component_name: None for component_name in components_setup}
        index = {component_name: 0 for component_name in components_setup}

        # looping semua file yang ada didalam
        for filename in sorted(os.listdir(foldername_join_basepath), key=natural_sort_key):
            if filename.endswith(".jpg") or filename.endswith(".png"): 

                # Read path sesuai dengan foldername_join_basepath dijoin path dengan filename
                image = cv2.imread(os.path.join(foldername_join_basepath, filename))
                # Resize image ke ukuran yang diinginkan
                # image = cv2.resize(image, (600, 500))
                # Cpmvert image ke grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Deteksi shape muka didalam grayscale image
                rects = detector(gray)

                if not index[component_name] == 0:
                    # Buat variabel frames_data_all_component untuk menampung data current frame
                    frame_data_all_component = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}
                    # Buat variabel frame_data_quadran untuk menampung data current frame
                    frame_data_quadran = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                # Memproses rects untuk setiap bentuk wajah yang terdeteksi
                for rect in rects:
                    # Ambil bentuk wajah dalam bentuk shape sesuai dengan model predictor
                    shape = predictor(gray, rect)
                    # Memproses setiap komponen wajah
                    for component_name, component_info in components_setup.items():
                        # print(f"\n{foldername}-{filename.split('.')[0]}-{component_info['object_name']}:")
                        # Inisialisasi variabel sum_data_by_quadran untuk menyimpan data hasil quadran
                        sum_data_by_quadran = {}
                        # Buat variabel frame_data untuk menampung data current frame
                        frame_data = {'Frame': f"{index[component_name] + 1}({filename.split('.')[0]})"}

                        # Looping untuk setiap atribut dalam frames_data_quadran_column
                        for column in frames_data_quadran_column:
                            # Inisialisasi sub-dictionary untuk setiap atribut dalam frames_data_quadran_column yang defaultnya 0
                            sum_data_by_quadran[column] = {quadrant: 0 for quadrant in quadran_dimensions}

                        # Ambil data blok image dari return fungsi extract_component_by_images
                        data_blocks_image_current = extract_component_by_images(
                            image=image,
                            shape=shape,
                            frameName=filename.split(".")[0],
                            objectName=component_info['object_name'],
                            objectRectangle=component_info['object_rectangle'],
                            pixelShifting=component_info['pixel_shifting'],
                            objectDimension=component_info['object_dimension']
                        )
                        
                        # Ambil frame pertama dari perulangan lalu simpan di variabel dan skip (lanjutkan ke frame berikut)
                        if data_blocks_first_image[component_name] is None:
                            # --- Setup bagian 4qmv Dataset ---
                            # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                            # for quadrant in quadran_dimensions:
                            #     for feature in frames_data_quadran_column:
                            #         # Buat nama kolom dengan menggunakan template yang diberikan
                            #         column_name = f"{component_name}_{feature}_{quadrant}"
                            #         # Set value sum_data_by_quadran[feature][quadrant] ke frame_data_quadran sesuai column_name nya
                            #         frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadrant]

                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Inisialisasi data untuk setiap blok
                            # for i in range(total_blocks_components[component_name]):
                                # Tambahkan data ke frame_data sesuai dengan indexnya
                                # frame_data[f'X{i+1}'] = 0
                                # frame_data[f'Y{i+1}'] = 0
                                # frame_data[f'Tetha{i+1}'] = 0
                                # frame_data[f'Magnitude{i+1}'] = 0
                                # # Tambahkan data ke frame_data_all_component sesuai dengan indexnya
                                # frame_data_all_component[f'{component_name}-X{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Y{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Tetha{i+1}'] = 0
                                # frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = 0

                            # Append data frame ke list frames_data sesuai dengan component_name
                            frames_data[component_name].append(frame_data)
                            # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                            frame_data['Folder Path'] = foldername
                            # Tambahkan kolom "Label" dengan nilai label saat ini
                            frame_data['Label'] = foldername_label
                            # Set value data_blocks_first_image[component_name] ke data_blocks_image_current
                            data_blocks_first_image[component_name] = data_blocks_image_current
                            # Skip looping nya ke looping selanjutnya
                            continue

                        # # Tampilkan data block image current ke matplotlib
                        # plt.imshow(np.uint8(data_blocks_image_current), cmap="gray")

                        # Inisiasi class POC
                        initPOC = POC(data_blocks_first_image[component_name], data_blocks_image_current, blockSize) 
                        # Pemanggilan fungsi pocCalc() untuk menghitung nilai POC disetiap gambar
                        valPOC = initPOC.getPOC() 

                        # Pemanggilan class dan method untuk menampilkan quiver / gambar panah
                        initQuiv = Vektor(valPOC, blockSize)
                        quivData = initQuiv.getVektor() 

                        # plt.quiver(quivData[:, 0], quivData[:, 1], quivData[:, 2], quivData[:, 3], scale=1, scale_units='xy', angles='xy', color="r")    

                        # # num = 0
                        # for rect_def in valPOC[2]:
                        #     x, y, width, height = rect_def
                            
                        #     rects = patches.Rectangle((x,y), width,height, edgecolor='r', facecolor='none') 
                        #     plt.gca().add_patch(rects)
                            
                        #     # plt.text(x,y,f'({num})', color="blue") 
                        #     # num += 1

                        # Pemanggilan class untuk mengeluarkan nilai karakteristik vektor
                        # blok ke, x,y,tetha, magnitude, dan quadran ke
                        initQuadran = Quadran(quivData) 
                        quadran = initQuadran.getQuadran()

                        # print(tabulate(quadran, headers=['Blok Ke', 'X', 'Y', 'Tetha', 'Magnitude', 'Quadran Ke']))
                        # plt.axis('on') 
                        # plt.show() 

                        # Update frame_data dengan data quadran
                        for i, quad in enumerate(quadran):
                            # --- Setup bagian Nilai Fitur Dataset ---
                            # Set data kedalam frame_data sesuai column nya
                            frame_data[f'X{i+1}'] = quad[1]
                            frame_data[f'Y{i+1}'] = quad[2]
                            frame_data[f'Tetha{i+1}'] = quad[3]
                            frame_data[f'Magnitude{i+1}'] = quad[4]

                            # Set data kedalam frame_data_all_component sesuai columnnya
                            frame_data_all_component[f'{component_name}-X{i+1}'] = quad[1]
                            frame_data_all_component[f'{component_name}-Y{i+1}'] = quad[2]
                            frame_data_all_component[f'{component_name}-Tetha{i+1}'] = quad[3]
                            frame_data_all_component[f'{component_name}-Magnitude{i+1}'] = quad[4]

                            # --- Setup bagian 4qmv Dataset ---
                            # Cek apakah quad[5] ada didalam array quadran_dimensions
                            if quad[5] in quadran_dimensions:
                                # Tambahkan nilai quad[1] ke sumX pada kuadran yang sesuai
                                sum_data_by_quadran['sumX'][quad[5]] += quad[1]
                                # Tambahkan nilai quad[2] ke sumY pada kuadran yang sesuai
                                sum_data_by_quadran['sumY'][quad[5]] += quad[2]
                                # Tambahkan nilai quad[3] ke Tetha pada kuadran yang sesuai
                                sum_data_by_quadran['Tetha'][quad[5]] += quad[3]
                                # Tambahkan nilai quad[4] ke Magnitude pada kuadran yang sesuai
                                sum_data_by_quadran['Magnitude'][quad[5]] += quad[4]
                                # Tambahkan jumlah quadran sesuai dengan quad[5] ke JumlahQuadran pada kuadran yang sesuai
                                sum_data_by_quadran['JumlahQuadran'][quad[5]] += 1
                        
                        # --- Setup bagian Nilai Fitur Dataset ---
                        # Append data frame ke list
                        frames_data[component_name].append(frame_data)
                        # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                        frame_data['Folder Path'] = foldername
                        # Tambahkan kolom "Label" dengan nilai label saat ini
                        frame_data['Label'] = foldername_label

                        # --- Setup bagian 4qmv Dataset ---
                        # Inisialisasi data untuk setiap blok dan setiap kuadran dengan nilai sesuai sum_data_by_quadran
                        for quadran in quadran_dimensions:
                            for feature in frames_data_quadran_column:
                                # Buat nama kolom dengan menggunakan template yang diberikan
                                column_name = f"{component_name}_{feature}_{quadran}"
                                # Set value sum_data_by_quadran[feature][quadran] ke frame_data_quadran sesuai column_name nya
                                frame_data_quadran[column_name] = sum_data_by_quadran[feature][quadran]

                # --- Setup bagian 4qmv Dataset ---
                if not index[component_name] == 0:
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_quadran.append(frame_data_quadran)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_quadran['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_quadran['Label'] = foldername_label

                if not index[component_name] == 0:
                    # --- Setup bagian frames data all component Dataset ---
                    # Append data frame ke list frames_data_quadran untuk 4qmv
                    frames_data_all_component.append(frame_data_all_component)
                    # print("Frame Quadran", frame_data_quadran)
                    # Tambahkan kolom "Folder Path" dengan nilai folder saat ini
                    frame_data_all_component['Folder Path'] = foldername
                    # Tambahkan kolom "Label" dengan nilai label saat ini
                    frame_data_all_component['Label'] = foldername_label

                # Update index per component_name
                index[component_name] += 1

# Membuat direktori jika belum ada untuk outputnya
output_csv_dir = os.path.join(pathDirectory['result_dataset'], 'csv')
output_excel_dir = os.path.join(pathDirectory['result_dataset'], 'excel')
os.makedirs(output_csv_dir, exist_ok=True)
os.makedirs(output_excel_dir, exist_ok=True)

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (Nilai fitur)
for component_name in components_setup:
    csv_file_path = os.path.join(pathDirectory['result_dataset'], 'csv', f'{component_name}.csv')
    xlsx_file_path = os.path.join(pathDirectory['result_dataset'], 'excel', f'{component_name}.xlsx')
    if os.path.exists(csv_file_path):
        os.remove(csv_file_path)
    if os.path.exists(xlsx_file_path):
        os.remove(xlsx_file_path)

# Export dataframe ke dalam file csv dan xlsx sesuai dengan masing-masing component untuk fitur ekstrasi biasa
for component_name, data_frame in frames_data.items():
    # Initialisasi dataframe dengan pandas
    df = pd.DataFrame(data_frame)
    
    # Simpan ke file CSV
    nama_file_csv = f'{output_csv_dir}/{component_name}.csv'
    df.to_csv(nama_file_csv, index=False, float_format=None)
    
    # Simpan ke file Excel
    nama_file_xlsx = f'{output_excel_dir}/{component_name}.xlsx'
    # df.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_quadran untuk fitur ekstraksi 4qmv
# Initialisasi dataframe dengan pandas
df_4qmv = pd.DataFrame(frames_data_quadran)

# Inisialisasi nama file untuk dataset 4qmv
nama_file_csv = f'{output_csv_dir}/4qmv-all-component.csv'
nama_file_xlsx = f'{output_excel_dir}/4qmv-all-component.xlsx'

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
if os.path.exists(nama_file_csv):
    os.remove(nama_file_csv)
if os.path.exists(nama_file_xlsx):
    os.remove(nama_file_xlsx)

# Simpan ke file CSV
df_4qmv.to_csv(nama_file_csv, index=False, float_format=None)

# Simpan ke file Excel
# df_4qmv.to_excel(nama_file_xlsx, index=False, float_format=None)

# Export dataframe ke dalam file csv dan xlsx sesuai frames_data_all_component untuk fitur ekstraksi nilai fiturnya
# Initialisasi dataframe dengan pandas
df_fitur_all = pd.DataFrame(frames_data_all_component)

# Inisialisasi nama file untuk dataset 4qmv
nama_file_csv = f'{output_csv_dir}/nilai-fitur-all-component.csv'
nama_file_xlsx = f'{output_excel_dir}/nilai-fitur-all-component.xlsx'

# Hapus file output dari semua tipe dataset baik csv dan xlsx jika ada (4qmv)
if os.path.exists(nama_file_csv):
    os.remove(nama_file_csv)
if os.path.exists(nama_file_xlsx):
    os.remove(nama_file_xlsx)

# Simpan ke file CSV
df_fitur_all.to_csv(nama_file_csv, index=False, float_format=None)

# Simpan ke file Excel
# df_fitur_all.to_excel(nama_file_xlsx, index=False, float_format=None)
