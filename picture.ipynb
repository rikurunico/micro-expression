# %%
import cv2
import dlib

# load the face detector and shape predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
image = cv2.imread("images/cina.jpg")
image = cv2.resize(image, (600, 500))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# detect the faces
rects = detector(gray)

# go through the face bounding boxes
for rect in rects:
    # apply the shape predictor to the face ROI
    shape = predictor(gray, rect)

    for n in range(0, 68):
        x = shape.part(n).x
        y = shape.part(n).y
        cv2.circle(image, (x, y), 4, (255, 0, 0), -1)

    # Extract and print coordinates for each point of interest
    print("Left eye")
    for i in range(36, 42):
        x = shape.part(i).x
        y = shape.part(i).y
        print("Point {}: ({}, {})".format(i, x, y))


    print("\nRight eye")
    for i in range(42, 48):
        x = shape.part(i).x
        y = shape.part(i).y
        print("Point {}: ({}, {})".format(i, x, y))


    print("\nLeft eyebrow")
    for i in range(17, 22):
        x = shape.part(i).x
        y = shape.part(i).y
        print("Point {}: ({}, {})".format(i, x, y))


    print("\nRight eyebrow")
    for i in range(22, 27):
        x = shape.part(i).x
        y = shape.part(i).y
        print("Point {}: ({}, {})".format(i, x, y))
        

    print("\nMouth")
    for i in range(48, 68):
        x = shape.part(i).x
        y = shape.part(i).y
        print("Point {}: ({}, {})".format(i, x, y))

cv2.imshow("Frame", image)
cv2.waitKey(0)
# Out:
# Left eye
# Point 36: (120, 134)
# Point 37: (155, 131)
# Point 38: (189, 133)
# Point 39: (221, 145)
# Point 40: (186, 153)
# Point 41: (151, 150)
#
# Right eye
# Point 42: (382, 146)
# Point 43: (412, 133)
# Point 44: (446, 133)
# Point 45: (482, 136)
# Point 46: (450, 152)
# Point 47: (414, 154)
#
# Left eyebrow
# Point 17: (57, 65)
# Point 18: (103, 45)
# Point 19: (156, 48)
# Point 20: (207, 62)
# Point 21: (259, 80)
#
# Right eyebrow
# Point 22: (347, 84)
# Point 23: (395, 66)
# Point 24: (444, 53)
# Point 25: (494, 49)
# Point 26: (538, 69)
#
# Mouth
# Point 48: (198, 359)
# Point 49: (236, 346)
# Point 50: (273, 338)
# Point 51: (302, 346)
# Point 52: (330, 337)
# Point 53: (365, 346)
# Point 54: (405, 360)
# Point 55: (368, 379)
# Point 56: (333, 389)
# Point 57: (305, 391)
# Point 58: (275, 389)
# Point 59: (238, 379)
# Point 60: (212, 360)
# Point 61: (273, 358)
# Point 62: (303, 362)
# Point 63: (331, 357)
# Point 64: (390, 360)
# Point 65: (332, 356)
# Point 66: (304, 360)
# Point 67: (275, 356)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Nico\Documents\BerbagaiCode\Python\pcvk-dlib\picture.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/Nico/Documents/BerbagaiCode/Python/pcvk-dlib/picture.ipynb#W1sZmlsZQ%3D%3D?line=50'>51</a>         print("Point {}: ({}, {})".format(i, x, y))
#      <a href='vscode-notebook-cell:/c%3A/Users/Nico/Documents/BerbagaiCode/Python/pcvk-dlib/picture.ipynb#W1sZmlsZQ%3D%3D?line=52'>53</a> cv2.imshow("Frame", image)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Nico/Documents/BerbagaiCode/Python/pcvk-dlib/picture.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a> cv2.waitKey(0)
#
# KeyboardInterrupt:
