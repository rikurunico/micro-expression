# %%
# Classifikasi Menggunakan KNN - Dataset Dengan Hidung
from clasification.knn import KNNClassifier

# Load the dataset and initialize the classifier
dataset_file = 'output-baru-dengan-hidung/csv/nilai-fitur-all-component.csv'
label_column = 'Label'
except_feature_columns = ['Frame', 'Folder Path', 'Label']  # Columns to exclude

# # Initialize the classifier
# classifier = KNNClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)

# # Load, split, train, evaluate and save the model
# classifier.load_data()
# classifier.split_data(test_size=0.2)
# # Train with auto parameter tuning
# classifier.train_model(autoParams=True)
# classifier.evaluate_model()
# # classifier.save_model('knn_model_dengan_hidung.joblib',label_encoder_filename='label_encoder_dengan_hidung.joblib')

knn_classifier = KNNClassifier(dataset_file=dataset_file, label_column=label_column, except_feature_column=except_feature_columns,directory='output-baru-dengan-hidung/data')
knn_classifier.load_data()
knn_classifier.split_data()
knn_classifier.train_model(autoParams=True)
knn_classifier.evaluate_model()
# Out:
# Loaded dataset from output-baru-dengan-hidung/csv/nilai-fitur-all-component.csv
#
# Model saved to output-baru-dengan-hidung/data/euclidean/knn_model_n_neighbors_3_metric_euclidean.joblib
# Label encoder saved to output-baru-dengan-hidung/data/euclidean/label_encoder_n_neighbors_3_metric_euclidean.joblib
# Trained with n_neighbors=3, metric=euclidean, accuracy=0.9898, precision=0.9875, recall=0.9909, f1-score=0.9890, AUC=0.998238115920972
# Model saved to output-baru-dengan-hidung/data/manhattan/knn_model_n_neighbors_3_metric_manhattan.joblib
# Label encoder saved to output-baru-dengan-hidung/data/manhattan/label_encoder_n_neighbors_3_metric_manhattan.joblib
# Trained with n_neighbors=3, metric=manhattan, accuracy=0.9968, precision=0.9959, recall=0.9973, f1-score=0.9966, AUC=0.9993762204512633
# Model saved to output-baru-dengan-hidung/data/minkowski/knn_model_n_neighbors_3_metric_minkowski.joblib
# ...

# %%
# Classifikasi Menggunakan KNN - Dataset Dengan Hidung
from clasification.knn import KNNClassifier

# Load the dataset and initialize the classifier
dataset_file = 'output-baru-tanpa-hidung/csv/nilai-fitur-all-component.csv'
label_column = 'Label'
except_feature_columns = ['Frame', 'Folder Path', 'Label']  # Columns to exclude

# # Initialize the classifier
# classifier = KNNClassifier(dataset_file, label_column, except_feature_column=except_feature_columns)

# # Load, split, train, evaluate and save the model
# classifier.load_data()
# classifier.split_data(test_size=0.2)
# # Train with auto parameter tuning
# classifier.train_model(autoParams=True)
# classifier.evaluate_model()
# # classifier.save_model('knn_model_dengan_hidung.joblib',label_encoder_filename='label_encoder_dengan_hidung.joblib')

knn_classifier = KNNClassifier(dataset_file=dataset_file, label_column=label_column, except_feature_column=except_feature_columns,directory='output-baru-tanpa-hidung/data')
knn_classifier.load_data()
knn_classifier.split_data()
knn_classifier.train_model(autoParams=True)
knn_classifier.evaluate_model()
# Out:
# Loaded dataset from output-baru-tanpa-hidung/csv/nilai-fitur-all-component.csv
#
# Model saved to output-baru-tanpa-hidung/data/euclidean/knn_model_n_neighbors_3_metric_euclidean.joblib
# Label encoder saved to output-baru-tanpa-hidung/data/euclidean/label_encoder_n_neighbors_3_metric_euclidean.joblib
# Trained with n_neighbors=3, metric=euclidean, accuracy=0.9873, precision=0.9843, recall=0.9881, f1-score=0.9860, AUC=0.9982160459501086
# Model saved to output-baru-tanpa-hidung/data/manhattan/knn_model_n_neighbors_3_metric_manhattan.joblib
# Label encoder saved to output-baru-tanpa-hidung/data/manhattan/label_encoder_n_neighbors_3_metric_manhattan.joblib
# Trained with n_neighbors=3, metric=manhattan, accuracy=0.9975, precision=0.9968, recall=0.9977, f1-score=0.9972, AUC=0.9993765586034913
# Model saved to output-baru-tanpa-hidung/data/minkowski/knn_model_n_neighbors_3_metric_minkowski.joblib
# ...

# %%
# Read File CSV check panjang kolom dan barisnya menggunakan pandas
import pandas as pd
df = pd.read_csv('output-baru-tanpa-hidung/csv/nilai-fitur-all-component.csv')
print('Panjang Kolom dan Baris Data Test:', df.shape)
# Out:
# Panjang Kolom dan Baris Data Test: (7873, 3891)

# %%
# Read File CSV check panjang kolom dan barisnya menggunakan pandas
df = pd.read_csv('output-baru-dengan-hidung/csv/nilai-fitur-all-component.csv')
print('Panjang Kolom dan Baris Data Test:', df.shape)
# Out:
# Panjang Kolom dan Baris Data Test: (7873, 4787)
